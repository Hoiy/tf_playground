# %%
import pandas as pd

FILE = "/Users/Shared/data/HN_posts_year_to_Sep_26_2016.csv"

data = pd.read_csv(FILE)
data = data[["id", "title"]]
# Out:
#          id                                              title
# 0  12579008  You have two days to comment if you want stem ...
# 1  12579005                         SQLAR  the SQLite Archiver
# 2  12578997  What if we just printed a flatscreen televisio...
# 3  12578989                                  algorithmic music
# 4  12578979  How the Data Vault Enables the Next-Gen Data W...
# 5  12578975                      Saving the Hassle of Shopping
# 6  12578954  Macalifa  A new open-source music app for UWP ...
# 7  12578942  GitHub  theweavrs/Macalifa: A music player wri...
# 8  12578919                      Google Allo  first Impression
# 9  12578918      Advanced Multimedia on the Linux Command Line

# %%
from nltk.tokenize import StanfordTokenizer
import numpy as np

def tokenize(x):
    print(x)
    return pd.Series(StanfordTokenizer().tokenize(x))

title = data["title"].apply(lambda x: tokenize(x))
# Out:
# You have two days to comment if you want stem cells to be classified as your own
# SQLAR  the SQLite Archiver
# What if we just printed a flatscreen television on the side of our boxes?
# algorithmic music
# How the Data Vault Enables the Next-Gen Data Warehouse and Data Lake
# Saving the Hassle of Shopping
# Macalifa  A new open-source music app for UWP that won't suck
# GitHub  theweavrs/Macalifa: A music player written for UWP
# Google Allo  first Impression
# Advanced Multimedia on the Linux Command Line
#             0                   1       2            3         4        5   \
# 0          You                have     two         days        to  comment
# 1        SQLAR                 the  SQLite     Archiver       NaN      NaN
# 2         What                  if      we         just   printed        a
# 3  algorithmic               music     NaN          NaN       NaN      NaN
# 4          How                 the    Data        Vault   Enables      the
# 5       Saving                 the  Hassle           of  Shopping      NaN
# 6     Macalifa                   A     new  open-source     music      app
# 7       GitHub  theweavrs/Macalifa       :            A     music   player
# 8       Google                Allo   first   Impression       NaN      NaN
# 9     Advanced          Multimedia      on          the     Linux  Command
#
#            6           7          8     9      10    11   12          13   14  \
# 0          if         you       want  stem  cells    to   be  classified   as
# 1         NaN         NaN        NaN   NaN    NaN   NaN  NaN         NaN  NaN
# 2  flatscreen  television         on   the   side    of  our       boxes    ?
# 3         NaN         NaN        NaN   NaN    NaN   NaN  NaN         NaN  NaN
# 4    Next-Gen        Data  Warehouse   and   Data  Lake  NaN         NaN  NaN
# 5         NaN         NaN        NaN   NaN    NaN   NaN  NaN         NaN  NaN
# 6         for         UWP       that    wo    n't  suck  NaN         NaN  NaN
# 7     written         for        UWP   NaN    NaN   NaN  NaN         NaN  NaN
# 8         NaN         NaN        NaN   NaN    NaN   NaN  NaN         NaN  NaN
# 9        Line         NaN        NaN   NaN    NaN   NaN  NaN         NaN  NaN
#
#      15   16
# 0  your  own
# 1   NaN  NaN
# 2   NaN  NaN
# 3   NaN  NaN
# 4   NaN  NaN
# 5   NaN  NaN
# 6   NaN  NaN
# 7   NaN  NaN
# 8   NaN  NaN
# 9   NaN  NaN

# %%
result = pd.concat([data["id"], title], axis=1)
# Out:
#          id            0                   1       2            3         4  \
# 0  12579008          You                have     two         days        to
# 1  12579005        SQLAR                 the  SQLite     Archiver       NaN
# 2  12578997         What                  if      we         just   printed
# 3  12578989  algorithmic               music     NaN          NaN       NaN
# 4  12578979          How                 the    Data        Vault   Enables
# 5  12578975       Saving                 the  Hassle           of  Shopping
# 6  12578954     Macalifa                   A     new  open-source     music
# 7  12578942       GitHub  theweavrs/Macalifa       :            A     music
# 8  12578919       Google                Allo   first   Impression       NaN
# 9  12578918     Advanced          Multimedia      on          the     Linux
#
#          5           6           7          8     9     10    11   12  \
# 0  comment          if         you       want  stem  cells    to   be
# 1      NaN         NaN         NaN        NaN   NaN    NaN   NaN  NaN
# 2        a  flatscreen  television         on   the   side    of  our
# 3      NaN         NaN         NaN        NaN   NaN    NaN   NaN  NaN
# 4      the    Next-Gen        Data  Warehouse   and   Data  Lake  NaN
# 5      NaN         NaN         NaN        NaN   NaN    NaN   NaN  NaN
# 6      app         for         UWP       that    wo    n't  suck  NaN
# 7   player     written         for        UWP   NaN    NaN   NaN  NaN
# 8      NaN         NaN         NaN        NaN   NaN    NaN   NaN  NaN
# 9  Command        Line         NaN        NaN   NaN    NaN   NaN  NaN
#
#            13   14    15   16
# 0  classified   as  your  own
# 1         NaN  NaN   NaN  NaN
# 2       boxes    ?   NaN  NaN
# 3         NaN  NaN   NaN  NaN
# 4         NaN  NaN   NaN  NaN
# 5         NaN  NaN   NaN  NaN
# 6         NaN  NaN   NaN  NaN
# 7         NaN  NaN   NaN  NaN
# 8         NaN  NaN   NaN  NaN
# 9         NaN  NaN   NaN  NaN

# %%
result.to_csv('./tokens.csv', header=False, index=False)
