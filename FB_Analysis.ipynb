# %%
import pandas as pd

NROWS = None

posts = pd.read_csv('/Users/Shared/fb/link_posts.csv', nrows=NROWS, quotechar='"', escapechar='\\')

# %%
posts['share_ratio'] = posts['share'] / posts['fan_count']
posts['like_ratio'] = posts['like'] / posts['fan_count']
posts['comment_ratio'] = posts['comment'] / posts['fan_count']
posts
# Out:
#              id  page_id                        facebook_id  \
# 0        177964     1885   142474049098533_1474788722533719
# 1       1940645    20163     131180673952_10155037642073953
# 2        645038     6729      52107727250_10154120507997251
# 3        269158     2860       9124187907_10155660939257908
# 4        269195     2860       9124187907_10155626886227908
# 5        269214     2860       9124187907_10155614787412908
# 6       2805234    29142   165205036869225_1380796198643430
# 7        269235     2860       9124187907_10155597953617908
# 8       1472865    15354  1371996966150726_1582954265054994
# 9        661976     6901   332968243416537_1398127326900618
# 10       267907     2847    199870617084581_214145832323726
# 11      2202482    22890   104438892938868_1395905253792219
# 12       269148     2860       9124187907_10155667100922908
# 13      2601628    27035   110177082404435_1265112300244235
# 14      2532554    26319   997108126967413_1509679769043577
# 15      2678567    27831   169528479736063_1357156890973210
# 16        71088      790       5281959998_10151094045534999
# 17        40629      470   346937065399354_1439187546174295
# 18      2438596    25361   131201286936061_1390301541026023
# 19      1926916    20021   111415578911214_1867516903301064
# 20        39376      458      24085780715_10158181697205716
# 21       161407     1716   367116489976035_1649023648451973
# 22      2601024    27029  1742306959430702_1746046362390095
# 23       269224     2860       9124187907_10155605794117908
# 24      1263129     3566     208421665712_10158551640350713
# 25      2532480    26319   997108126967413_1522487217762832
# 26        41724      482       5550296508_10156134811176509
# 27       161361     1716   367116489976035_1658198047534533
# 28      2438574    25361   131201286936061_1406133962776114
# 29       269145     2860       9124187907_10155670306072908
# ...         ...      ...                                ...
# 317668  2807039    29160     316449433298_10154517397403299
# 317669   120319     1297       6654472378_10154379232217379
# 317670    55039      620   632729473453216_1331043880288435
# 317671  1956095    20321   147384458624178_1562946923734584
# 317672  2414847    25114    251934468302503_772753476220597
# 317673   121855     1312     252062638385_10154559744913386
# 317674   449535     4729       8684858250_10154443986778251
# 317675  2153471    22374     168619349359_10154978151134360
# 317676  2153727    22376   157671354275436_1488857234490168
# 317677  1826559    18984   159163487447469_1447022521994886
# 317678  2154239    22382   270813539617588_1426211830744414
# 317679  2285311    23751      68463351073_10154296078011074
# 317680  2350847    24444   145019618847447_1643076752375052
# 317681  1827327    18992      36841737921_10155151180622922
# 317682   320255     3390   310387089028039_1349644481768956
# 317683   255231     2716      27124644923_10155116134784924
# 317684  2483711    25824      60265161373_10154538703786374
# 317685  2222335    23091      50842855867_10154234591625868
# 317686  1960447    20368      57356766562_10155040253031563
# 317687  2223103    23099   210152225666581_1663647563650366
# 317688  1765887    18360   196329073799810_1184851578280883
# 317689   455423     4789      56969128673_10155033242658674
# 317690  1438975    14988   176835515721658_1383679228370608
# 317691  2749695    28564    150458898489106_620828468118811
# 317692  2554111    26542      81592120902_10154917001160903
# 317693   260607     2772     168926019255_10155730437064256
# 317694   588287     6154   122147017804101_1414935258525264
# 317695  2095615    21771      54394619188_10155092938129189
# 317696  2358271    24522   127784247269485_1208121299235769
# 317697  1637887    17047   108237029260557_1237793119638270
#
#                                                      name   share  comment  \
# 0       Boeing's 787 Dreamliner Is Made Of Parts From ...  110196    10514
# 1       Papa sugere que é “melhor ser ateu do que cató...   96104     3426
# 2       Fallece Pablo Ráez tras una lucha titánica con...   92376     5999
# 3       House bill would scale back number of free sch...   90349     9684
# 4       Dakota Access Pipeline Approved a Week After C...   86984     4644
# 5       After Trump moves to undo financial regulation...   74276     9754
# 6       Prefeito destina verba que seria do Carnaval p...   71010     4150
# 7       After meeting with pharma lobbyists, Trump dro...   69586    10346
# 8       People Want To Shoot Hibernating Bear Families...   65809     1272
# 9       REPORT: Aaron Hernandez Says He Too Will Skip ...   61975     3791
# 10      Republicans begin effort to gut the Endangered...   61145     4824
# 11      La televisión italiana difunde el drama argent...   57748      827
# 12      The Trump administration just handed the priva...   56783     5552
# 13      El mismo juzgado que ha absuelto a la infanta ...   55405     1394
# 14      Big Pharma Finally Admits Cannabis Kills Cance...   54969     2612
# 15           Robert Englund Back for One Last Freddy Film   54699     3737
# 16      White House Bars Times and 2 Other News Outlet...   51022     8454
# 17      Militarized Police Just Evicted The Sioux Trib...   50985     4854
# 18      News from The Associated Press: "Doomsday Cloc...   49870    10389
# 19      ¡Compartan! Les revelo la increíble fórmula pa...   49771      993
# 20      The mysterious disappearance of the biggest sc...   49287     5608
# 21      Republicans Launch Attempt To Repeal Endangere...   48292     5382
# 22      House Moves to Encourage Drilling in National ...   47070     3371
# 23      Trump Vows to ‘Destroy’ Law Banning Political ...   46326    10290
# 24                                 Bill Paxton Dead at 61   46208     3528
# 25      This MAN Healed 5000 People from Cancer: This ...   45983     2063
# 26      White House blocks news organizations from pre...   45764    15119
# 27      Breakthrough In Search For Life As Seven Earth...   45659     4261
# 28      Trump won't immediately appeal travel ban halt...   45581     7023
# 29      Republican lawmakers introduce bills to curb p...   45461     5624
# ...                                                   ...     ...      ...
# 317668    TEMPO REAL: Mirassol vs Corinthians - Paulistão       0        4
# 317669  Romantic place names from around the world | S...       0        0
# 317670                                          Blumhouse       0        0
# 317671                                  Sunday Times Food       0        2
# 317672  Eva Herzigova flaunts her age-defying beauty a...       0        4
# 317673  Jim Cantore (@JimCantore) posted a photo on Tw...       0        3
# 317674                                          Nova 96.9       0        4
# 317675  Ayesha Takia on makeover: Some vicious people ...       0        2
# 317676  Live in green neighbourhood to cut depression,...       0        0
# 317677  Sydney go 11 clear with City A-League romp - F...       0        0
# 317678    Fichardt wins Joburg Open with last-hole birdie       0        0
# 317679                     Los últimos serán los primeros       0        0
# 317680  Video:  Dating-Portal deckt auf - So sieht für...       0        0
# 317681                        Sydney Comedy Festival 2017       0        0
# 317682  Riverdales Trevor Stines Wants In On a Certain...       0        7
# 317683  Who Made the Cut? James Wrights Sets the Crew ...       0        2
# 317684                                             gph.is       0        0
# 317685  Óscar Ibáñez es el nuevo técnico de Comerciant...       0        2
# 317686  All the It Girls Are Embracing This "Faux Pas"...       0        1
# 317687                GANA UN DESAYUNO GRATIS DE KeBurros       0        0
# 317688  Receita: ovos gratinados são opção delícia par...       0        0
# 317689  Scientists Warn Parents To Keep Children Away ...       0        0
# 317690                      Dark and Purple by Jennifer E       0        0
# 317691                                          YRF Music       0        3
# 317692                                           ABP Live       0        1
# 317693  A Romantic Valentine's Day Dinner for 2 That's...       0        3
# 317694  Jessa Duggar's New Baby Henry Is So Cute, We C...       0        0
# 317695                                          giphy.com       0        1
# 317696                                        Like a Lord       0        1
# 317697                                                TV8       0       47
#
#           like  love     haha     wow      ...       source  \
# 0       114884   NaN      NaN  9105.0      ...          NaN
# 1        86598   NaN   2352.0     NaN      ...          NaN
# 2         3824   NaN      NaN  1034.0      ...          NaN
# 3        39706   NaN    156.0     NaN      ...          NaN
# 4        63378   NaN    251.0     NaN      ...          NaN
# 5       239914   NaN    743.0     NaN      ...          NaN
# 6       163415   NaN    276.0     NaN      ...          NaN
# 7        76792   NaN   1309.0     NaN      ...          NaN
# 8         1603   NaN      9.0     NaN      ...          NaN
# 9        40526   NaN  22322.0     NaN      ...          NaN
# 10        2907   NaN     26.0     NaN      ...          NaN
# 11       20158   NaN     25.0     NaN      ...          NaN
# 12       42038   NaN    162.0     NaN      ...          NaN
# 13        3860   NaN    530.0     NaN      ...          NaN
# 14       88968   NaN    364.0     NaN      ...          NaN
# 15       59160   NaN    127.0     NaN      ...          NaN
# 16        9038   NaN    882.0     NaN      ...          NaN
# 17        6613   NaN     98.0     NaN      ...          NaN
# 18      112315   NaN   1295.0     NaN      ...          NaN
# 19       26835   NaN     87.0     NaN      ...          NaN
# 20       66793   NaN    118.0     NaN      ...          NaN
# 21       12554   NaN    368.0     NaN      ...          NaN
# 22       13759   NaN     24.0     NaN      ...          NaN
# 23       72385   NaN    403.0     NaN      ...          NaN
# 24        5224   NaN     47.0     NaN      ...          NaN
# 25       55254   NaN     80.0     NaN      ...          NaN
# 26       13356   NaN   4232.0     NaN      ...          NaN
# 27      120886   NaN    167.0     NaN      ...          NaN
# 28       98154   NaN     54.0     NaN      ...          NaN
# 29       63092   NaN    249.0     NaN      ...          NaN
# ...        ...   ...      ...     ...      ...          ...
# 317668     138   NaN      0.0     NaN      ...          NaN
# 317669       0   NaN      0.0     NaN      ...          NaN
# 317670       5   NaN      NaN     0.0      ...          NaN
# 317671       9   NaN      0.0     NaN      ...          NaN
# 317672      49   NaN      0.0     NaN      ...          NaN
# 317673      30   NaN      NaN    11.0      ...          NaN
# 317674      10   NaN      0.0     NaN      ...          NaN
# 317675     248   NaN      1.0     NaN      ...          NaN
# 317676      18   NaN      0.0     NaN      ...          NaN
# 317677       7   NaN      0.0     NaN      ...          NaN
# 317678      18   NaN      0.0     NaN      ...          NaN
# 317679      11   NaN      0.0     NaN      ...          NaN
# 317680       3   NaN      0.0     NaN      ...          NaN
# 317681       3   NaN      0.0     NaN      ...          NaN
# 317682       5   NaN      NaN     0.0      ...          NaN
# 317683      34   NaN      NaN     0.0      ...          NaN
# 317684      24   NaN      0.0     NaN      ...          NaN
# 317685      40   NaN      2.0     NaN      ...          NaN
# 317686      15   NaN      0.0     NaN      ...          NaN
# 317687       0   NaN      0.0     NaN      ...          NaN
# 317688      10   NaN      0.0     NaN      ...          NaN
# 317689       4   NaN      NaN     0.0      ...          NaN
# 317690       6   NaN      0.0     NaN      ...          NaN
# 317691      31   NaN      0.0     NaN      ...          NaN
# 317692     206   NaN      2.0     NaN      ...          NaN
# 317693      16   NaN      NaN     0.0      ...          NaN
# 317694      25   NaN      NaN     1.0      ...          NaN
# 317695      95   NaN      1.0     NaN      ...          NaN
# 317696      17   NaN      0.0     NaN      ...          NaN
# 317697     750   NaN     52.0     NaN      ...          NaN
#
#                created_time         updated_time            createdAt  \
# 0       2017-02-17 19:28:36  2017-02-25 22:51:41  2017-02-26 12:49:55
# 1       2017-02-26 08:59:00  2017-02-26 16:15:01  2017-02-26 16:18:01
# 2       2017-02-25 18:11:45  2017-02-26 14:09:17  2017-02-26 14:11:12
# 3       2017-02-21 18:47:41  2017-02-26 11:49:56  2017-02-26 13:06:18
# 4       2017-02-10 21:51:23  2017-02-22 21:52:41  2017-02-26 13:06:18
# 5       2017-02-06 15:25:21  2017-02-22 16:26:19  2017-02-26 13:06:18
# 6       2017-02-22 18:00:34  2017-02-26 16:07:07  2017-02-26 16:39:00
# 7       2017-01-31 22:33:22  2017-02-23 18:58:51  2017-02-26 13:06:18
# 8       2017-02-17 18:43:00  2017-02-23 01:10:50  2017-02-26 16:07:38
# 9       2017-02-10 03:12:57  2017-02-22 13:03:33  2017-02-26 14:14:05
# 10      2017-02-16 14:05:00  2017-02-25 13:27:59  2017-02-26 13:06:04
# 11      2017-02-25 00:02:00  2017-02-26 16:19:35  2017-02-26 16:24:04
# 12      2017-02-24 01:45:06  2017-02-26 12:31:59  2017-02-26 13:06:18
# 13      2017-02-17 18:46:56  2017-02-23 23:36:20  2017-02-26 16:33:07
# 14      2017-02-12 22:31:47  2017-02-21 04:37:39  2017-02-26 16:31:31
# 15      2017-02-01 22:50:40  2017-02-10 23:57:22  2017-02-26 16:36:12
# 16      2017-02-24 19:33:08  2017-02-26 12:26:14  2017-02-26 12:31:32
# 17      2017-02-23 19:50:00  2017-02-26 10:42:58  2017-02-26 12:26:10
# 18      2017-01-28 11:45:00  2017-02-24 12:33:20  2017-02-26 16:29:26
# 19      2017-02-14 01:30:07  2017-02-21 16:51:56  2017-02-26 16:17:42
# 20      2017-02-09 16:53:01  2017-02-24 19:23:44  2017-02-26 12:25:58
# 21      2017-02-15 22:15:26  2017-02-23 06:57:40  2017-02-26 12:47:05
# 22      2017-02-01 03:04:34  2017-02-08 02:05:29  2017-02-26 16:33:07
# 23      2017-02-03 18:05:00  2017-02-25 17:58:57  2017-02-26 13:06:18
# 24      2017-02-26 15:19:50  2017-02-26 16:02:43  2017-02-26 16:02:45
# 25      2017-02-24 19:13:29  2017-02-26 16:20:36  2017-02-26 16:31:31
# 26      2017-02-24 19:25:36  2017-02-26 12:25:12  2017-02-26 12:26:22
# 27      2017-02-22 18:08:46  2017-02-25 22:57:23  2017-02-26 12:47:05
# 28      2017-02-11 21:28:20  2017-02-26 12:53:53  2017-02-26 16:29:26
# 29      2017-02-25 01:57:46  2017-02-26 13:05:31  2017-02-26 13:06:18
# ...                     ...                  ...                  ...
# 317668  2017-02-25 22:01:01  2017-02-26 02:04:46  2017-02-26 16:39:03
# 317669  2017-02-14 15:38:00  2017-02-14 15:38:00  2017-02-26 12:40:02
# 317670  2017-02-16 21:33:01  2017-02-16 21:33:01  2017-02-26 12:28:41
# 317671  2017-02-23 11:50:25  2017-02-26 13:02:57  2017-02-26 16:18:21
# 317672  2017-02-26 13:00:16  2017-02-26 13:28:58  2017-02-26 16:29:03
# 317673  2017-02-16 18:49:32  2017-02-17 06:07:30  2017-02-26 12:40:17
# 317674  2017-02-16 07:48:32  2017-02-16 12:49:26  2017-02-26 13:37:40
# 317675  2017-02-26 04:46:46  2017-02-26 06:04:06  2017-02-26 16:22:56
# 317676  2017-02-26 06:26:00  2017-02-26 06:26:00  2017-02-26 16:22:57
# 317677  2017-02-24 21:19:00  2017-02-24 21:19:00  2017-02-26 16:15:28
# 317678  2017-02-26 15:54:35  2017-02-26 15:54:35  2017-02-26 16:22:57
# 317679  2017-02-25 19:00:02  2017-02-25 19:00:02  2017-02-26 16:25:56
# 317680  2017-02-26 12:33:00  2017-02-26 12:33:00  2017-02-26 16:27:26
# 317681  2017-02-22 01:30:02  2017-02-22 01:30:02  2017-02-26 16:15:29
# 317682  2017-02-20 15:00:04  2017-02-21 18:38:50  2017-02-26 13:15:13
# 317683  2017-02-07 19:00:00  2017-02-09 22:00:24  2017-02-26 13:03:53
# 317684  2017-02-26 03:14:00  2017-02-26 03:14:00  2017-02-26 16:30:27
# 317685  2017-02-26 04:38:21  2017-02-26 04:59:34  2017-02-26 16:24:30
# 317686  2017-02-25 03:00:00  2017-02-25 03:00:00  2017-02-26 16:18:28
# 317687  2017-02-24 17:26:29  2017-02-24 17:26:29  2017-02-26 16:24:31
# 317688  2017-02-26 00:00:02  2017-02-26 00:00:02  2017-02-26 16:14:06
# 317689  2017-02-25 14:44:24  2017-02-25 14:44:24  2017-02-26 13:38:41
# 317690  2017-02-23 21:00:02  2017-02-23 21:00:02  2017-02-26 16:06:50
# 317691  2017-02-09 07:48:51  2017-02-13 14:49:38  2017-02-26 16:37:46
# 317692  2017-02-24 12:23:39  2017-02-25 13:26:29  2017-02-26 16:32:00
# 317693  2017-02-12 06:04:50  2017-02-13 03:30:06  2017-02-26 13:04:49
# 317694  2017-02-20 13:09:24  2017-02-20 13:09:24  2017-02-26 14:01:35
# 317695  2017-02-07 16:00:05  2017-02-12 16:15:07  2017-02-26 16:21:36
# 317696  2017-02-17 10:30:00  2017-02-17 18:38:09  2017-02-26 16:27:36
# 317697  2017-02-18 16:40:08  2017-02-24 21:22:01  2017-02-26 16:11:16
#
#                   updatedAt   id.1 fan_count share_ratio like_ratio  \
# 0       2017-02-26 12:49:55   1885   2096549    0.052561   0.054797
# 1       2017-02-26 16:18:01  20163   4035108    0.023817   0.021461
# 2       2017-02-26 14:11:12   6729    239639    0.385480   0.015957
# 3       2017-02-26 13:06:18   2860   6684171    0.013517   0.005940
# 4       2017-02-26 13:06:18   2860   6684171    0.013013   0.009482
# 5       2017-02-26 13:06:18   2860   6684171    0.011112   0.035893
# 6       2017-02-26 16:39:00  29142   6745116    0.010528   0.024227
# 7       2017-02-26 13:06:18   2860   6684171    0.010411   0.011489
# 8       2017-02-26 16:07:38  15354   1177625    0.055883   0.001361
# 9       2017-02-26 14:14:05   6901   2793744    0.022183   0.014506
# 10      2017-02-26 13:06:04   2847   1101432    0.055514   0.002639
# 11      2017-02-26 16:24:04  22890  16633846    0.003472   0.001212
# 12      2017-02-26 13:06:18   2860   6684171    0.008495   0.006289
# 13      2017-02-26 16:33:07  27035    871655    0.063563   0.004428
# 14      2017-02-26 16:31:31  26319   6885736    0.007983   0.012921
# 15      2017-02-26 16:36:12  27831    667995    0.081885   0.088564
# 16      2017-02-26 12:31:32    790  13464157    0.003789   0.000671
# 17      2017-02-26 12:26:10    470   5915082    0.008619   0.001118
# 18      2017-02-26 16:29:26  25361   5403968    0.009228   0.020784
# 19      2017-02-26 16:17:42  20021   8699306    0.005721   0.003085
# 20      2017-02-26 12:25:58    458   1908514    0.025825   0.034997
# 21      2017-02-26 12:47:05   1716  25581111    0.001888   0.000491
# 22      2017-02-26 16:33:07  27029   1434940    0.032803   0.009589
# 23      2017-02-26 13:06:18   2860   6684171    0.006931   0.010829
# 24      2017-02-26 16:02:45   3566   6902151    0.006695   0.000757
# 25      2017-02-26 16:31:31  26319   6885736    0.006678   0.008024
# 26      2017-02-26 12:26:22    482  26716165    0.001713   0.000500
# 27      2017-02-26 12:47:05   1716  25581111    0.001785   0.004726
# 28      2017-02-26 16:29:26  25361   5403968    0.008435   0.018163
# 29      2017-02-26 13:06:18   2860   6684171    0.006801   0.009439
# ...                     ...    ...       ...         ...        ...
# 317668  2017-02-26 16:39:03  29160    998597    0.000000   0.000138
# 317669  2017-02-26 12:40:02   1297   1210743    0.000000   0.000000
# 317670  2017-02-26 12:28:41    620    455125    0.000000   0.000011
# 317671  2017-02-26 16:18:21  20321    608617    0.000000   0.000015
# 317672  2017-02-26 16:29:03  25114   1015465    0.000000   0.000048
# 317673  2017-02-26 12:40:17   1312    261084    0.000000   0.000115
# 317674  2017-02-26 13:37:40   4729    957151    0.000000   0.000010
# 317675  2017-02-26 16:22:56  22374   2464533    0.000000   0.000101
# 317676  2017-02-26 16:22:57  22376   1427983    0.000000   0.000013
# 317677  2017-02-26 16:15:28  18984    702450    0.000000   0.000010
# 317678  2017-02-26 16:22:57  22382   1482682    0.000000   0.000012
# 317679  2017-02-26 16:25:56  23751   1657326    0.000000   0.000007
# 317680  2017-02-26 16:27:26  24444    710181    0.000000   0.000004
# 317681  2017-02-26 16:15:29  18992    660576    0.000000   0.000005
# 317682  2017-02-26 13:15:13   3390    229782    0.000000   0.000022
# 317683  2017-02-26 13:03:53   2716    442470    0.000000   0.000077
# 317684  2017-02-26 16:30:27  25824   3542032    0.000000   0.000007
# 317685  2017-02-26 16:24:30  23091    838039    0.000000   0.000048
# 317686  2017-02-26 16:18:28  20368   1978250    0.000000   0.000008
# 317687  2017-02-26 16:24:31  23099    637499    0.000000   0.000000
# 317688  2017-02-26 16:14:06  18360    576546    0.000000   0.000017
# 317689  2017-02-26 13:38:41   4789    384580    0.000000   0.000010
# 317690  2017-02-26 16:06:50  14988   1702744    0.000000   0.000004
# 317691  2017-02-26 16:37:46  28564   1113958    0.000000   0.000028
# 317692  2017-02-26 16:32:00  26542    959177    0.000000   0.000215
# 317693  2017-02-26 13:04:49   2772    240909    0.000000   0.000066
# 317694  2017-02-26 14:01:35   6154   1467173    0.000000   0.000017
# 317695  2017-02-26 16:21:36  21771  14193439    0.000000   0.000007
# 317696  2017-02-26 16:27:36  24522    876148    0.000000   0.000019
# 317697  2017-02-26 16:11:16  17047    792533    0.000000   0.000946
#
#        comment_ratio
# 0       5.014908e-03
# 1       8.490479e-04
# 2       2.503349e-02
# 3       1.448796e-03
# 4       6.947758e-04
# 5       1.459268e-03
# 6       6.152600e-04
# 7       1.547836e-03
# 8       1.080140e-03
# 9       1.356960e-03
# 10      4.379753e-03
# 11      4.971791e-05
# 12      8.306191e-04
# 13      1.599257e-03
# 14      3.793349e-04
# 15      5.594353e-03
# 16      6.278893e-04
# 17      8.206142e-04
# 18      1.922476e-03
# 19      1.141470e-04
# 20      2.938412e-03
# 21      2.103896e-04
# 22      2.349227e-03
# 23      1.539458e-03
# 24      5.111450e-04
# 25      2.996049e-04
# 26      5.659121e-04
# 27      1.665682e-04
# 28      1.299601e-03
# 29      8.413908e-04
# ...              ...
# 317668  4.005620e-06
# 317669  0.000000e+00
# 317670  0.000000e+00
# 317671  3.286139e-06
# 317672  3.939082e-06
# 317673  1.149055e-05
# 317674  4.179069e-06
# 317675  8.115128e-07
# 317676  0.000000e+00
# 317677  0.000000e+00
# 317678  0.000000e+00
# 317679  0.000000e+00
# 317680  0.000000e+00
# 317681  0.000000e+00
# 317682  3.046366e-05
# 317683  4.520080e-06
# 317684  0.000000e+00
# 317685  2.386524e-06
# 317686  5.054973e-07
# 317687  0.000000e+00
# 317688  0.000000e+00
# 317689  0.000000e+00
# 317690  0.000000e+00
# 317691  2.693100e-06
# 317692  1.042560e-06
# 317693  1.245283e-05
# 317694  0.000000e+00
# 317695  7.045509e-08
# 317696  1.141360e-06
# 317697  5.930352e-05
#
# [317698 rows x 30 columns]

# %%
import matplotlib.pyplot as plt
import numpy as np
from numpy.random import normal

x = np.linspace(0.0000001, 0.0002, 1000)
plt.hist(posts['share_ratio'], bins=x)
plt.show()

# %%
x = np.linspace(0.0000001, 0.002, 1000)
plt.hist(posts['like_ratio'], bins=x)
plt.show()

# %%
x = np.linspace(0.0000001, 0.0002, 1000)
plt.hist(posts['comment_ratio'], bins=x)
plt.show()

# %%
link_posts = posts[posts['type'] == 'link']
link_posts.shape
# Out:
# (317698, 30)

# %%
import langid

def isEng(x):
    try:
        return langid.classify(x['message'])[0] == 'en'
    except:
        try:
            return detect(x['description'])[0] == 'en'
        except:
            try:
                return detect(x['name'])[0] == 'en'
            except:
                return False
    

eng_link_posts = link_posts[link_posts.apply(isEng, axis=1)]

# %%
eng_link_posts.shape
backup = eng_link_posts
data = eng_link_posts
eng_link_posts.iloc[0]['message']
# Out:
# 'I just watched Trump give a speech at South Carolina\'s Boeing facility where the new 787 “Dreamliner" is being unveiled. Trump said it was “built right here” in South Carolina, and that “our goal as a nation must be to rely less on imports and more on products made here in the U.S.A." \n\nHe also called for "a very substantial penalty to be paid when they fire their people and move to another country, make the product, and think that they are going to sell it back.” And said he\'ll lower taxes and get rid of regulations that send our jobs to those other countries. "We want products made by our workers in our factories stamped by those four magnificent words, \'Made in the U.S.A.\'"\n\nAll fantasy. In fact, almost a third of Boeing’s Dreamliner comes from abroad -- from countries with high taxes and high regulations, good wages, strong unions, excellent schools including technical education, and universally-available health care. \n\n1.The Italian firm Alenia Aeronautica makes the center fuselage. \n\n2. French firm Messier-Dowty makes the aircraft\'s landing-gear system.\n\n3. German firm Diehl Luftfahrt Elektronik supplies the main cabin lighting. \n\n4. Swedish firm Saab Aerostructures manufactures the access doors.\n\n5. Japanese company Jamco makes parts for the lavatories, flight deck interiors and galleys. \n\n6. French firm Thales makes its electrical power conversion system. \n\n7. Thales selected GS Yuasa, a Japanese firm, in 2005 to supply it with the system\'s lithium-ion batteries. \n\nOh, and the first delivery of the Dreamliner is scheduled to take place next year – to Singapore Airlines. Currently there are 149 orders for it from worldwide customers including British Airways and Air France. \n\nIn other words, contrary to Trump, the Boeing Dreamliner is made all over the world and will be sold all over the world. \n\nHis "America First" economics is total demagoguery. We get a first-class workforce by investing in their education, training, infrastructure, and healthcare -- not xenophobic grandstanding. \n\nWhat do you think?'

# %%
from langdetect import detect

def isEng(x):
    try:
        return detect(x['message']) == 'en'
    except:
        try:
            return detect(x['description']) == 'en'
        except:
            try:
                return detect(x['name']) == 'en'
            except:
                return False

eng_link_posts = link_posts[link_posts.apply(isEng, axis=1)]

# %%
import csv
eng_link_posts.to_csv('/Users/Shared/fb/eng_link_posts.csv', doublequote=False, quotechar='"', escapechar='\\')

# %%
test = pd.read_csv('/Users/Shared/fb/eng_link_posts.csv', nrows=10000, error_bad_lines=False, doublequote=False, quotechar='"', escapechar='\\')

# %%
eng_link_posts[['name']].to_csv('/Users/Shared/fb/eng_link_posts_name.csv', index=False, header=False)

# %%
eng_link_posts['data'] = eng_link_posts['name'].astype(str)
eng_link_posts['share_ratio'].describe()
eng_link_posts['good'] = eng_link_posts['share_ratio'].apply(lambda x: 1 if x >= 0.0001 else 0)
eng_link_posts['good'].describe()
data = eng_link_posts

# %%
from codeDump.testHeadline import tokenize
tokenize(data['data'])
#test_data(data)

# %%
# train word vector by fasttext

# %%
data = eng_link_posts[['like', 'facebook_id', 'name', 'like_ratio']]
data['like_ratio'].describe()

# %%
data['good'] = data['like_ratio'].apply(lambda x: 1 if x > 0.0005 else 0)
data['good'].describe()

# %%
data["name"].describe()

# %%
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences

data["name"] = data["name"].astype('str')

tokenizer = Tokenizer()
tokenizer.fit_on_texts(data["name"])
word_index = tokenizer.word_index
print('Found %s unique tokens.' % len(word_index))

# %%
import os
import numpy as np

embeddings_index = {}
f = open(os.path.join('/Users/Shared/fb/eng_link_posts_name_model.vec'))
for line in f:
    values = line.split()
    word = values[0]
    coefs = np.asarray(values[1:], dtype='float32')
    embeddings_index[word] = coefs
f.close()

print('Found %s word vectors.' % len(embeddings_index))

# %%
EMBEDDING_DIM = 100

embedding_matrix = np.zeros((len(word_index) + 1, EMBEDDING_DIM))
for word, i in word_index.items():
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None:
        # words not found in embedding index will be all-zeros.
        embedding_matrix[i] = embedding_vector

# %%
def prepareData(df):    
    good = df[df["good"] == 1]
    bad = df[df["good"] == 0]
    bad = bad.sample(n=good.shape[0])
    data = good.append(bad)
    data = data.sample(frac=1).reset_index(drop=True)
    
    y_train = np.zeros((data.shape[0], 2), dtype=int)
    for i in range(0, data.shape[0]):
        y_train[i, 1] = 1 if data.iloc[i]['good'] == 1 else 0
        y_train[i, 0] = 1 if data.iloc[i]['good'] == 0 else 0
        
    sequences = tokenizer.texts_to_sequences(data["name"])
    x_train = pad_sequences(sequences, maxlen=25)

    return x_train, y_train, data['good'].values

# %%
x_full, y_full, y2_full = prepareData(eng_link_posts)
x_train, y_train, y2_train = prepareData(train)
x_test, y_test, y2_test = prepareData(test)

print(y2_full)

# %%
from sklearn.metrics import precision_score, recall_score

def validate(model, x_test, y_test):
    test_truth = np.apply_along_axis(lambda x: np.argmax(x), 1, y_test)
    test_pred = model.predict(x_test)
    test_pred = np.apply_along_axis(lambda x: np.argmax(x), 1, test_pred)
    precision = precision_score(test_truth, test_pred)
    recall = recall_score(test_truth, test_pred)
    print(precision)
    print(recall)
    return precision, recall

def validate_2(truth, pred):
    truth = np.apply_along_axis(lambda x: np.argmax(x), 1, truth)
    pred = np.apply_along_axis(lambda x: np.argmax(x), 1, pred)
    precision = precision_score(truth, pred)
    recall = recall_score(truth, pred)
    print(precision)
    print(recall)
    return precision, recall

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(n_estimators=500, n_jobs=-1, criterion="entropy", random_state=1)
rf.fit(x_train, y2_train)

res = rf.predict(x_test)

#validate_2(y_test, res)
precision = precision_score(y2_test, res)
recall = recall_score(y2_test, res)
print(precision)
print(recall)

# %%
origin = pd.read_csv('/Users/Shared/data/HN_posts_year_to_Sep_26_2016.csv')
origin_1 = origin[['id', 'num_points']]
data = pd.merge(title_vec, origin_1, how='inner', on=['id'])

# %%
origin

# %%
'''
sentence_length = pd.read_csv('sentence_length.csv', header=None, )
sentence_length.rename(columns={0: 'id', 1:'length'}, inplace=True)
data = pd.merge(data, sentence_length, how='inner', on=['id'])
'''

# %%
GOOD_THRESHOLD = 10

data['good'] = data['num_points'].apply(lambda x: 1 if x >= GOOD_THRESHOLD else 0)
data['good'].describe()

# %%
data = data.drop(['id', 'num_points'], 1)

# %%
train = data.sample(frac=0.8)
test = data.drop(train.index)

abnormal = data.loc[data['good'] == 1]
abnormal

# %%
import numpy as np
import matplotlib.pyplot as plt

m = train[list(range(0, 1200))].as_matrix()
u, s, v = np.linalg.svd(m, full_matrices=False)
plt.plot(s[0:400])
plt.show()

print(u.shape, s.shape, v.shape)
print(m[0].shape, v.transpose().shape)

transform = np.delete(v, range(2, v.shape[0]), 0)
print(transform.shape)

def reduce(vec):
    return np.dot(vec, transform.transpose())

def to_coor(matrix):
    coor = np.apply_along_axis(reduce, 1, matrix).transpose()
    print(matrix.shape, coor.shape)
    return (coor[0], coor[1])
    
normal_x, normal_y = to_coor(m)

m2 = abnormal[list(range(0,1200))].as_matrix()

ab_x, ab_y = to_coor(m2)

print(ab_x.shape)
print(ab_y.shape)

plt.scatter(normal_x, normal_y)
plt.scatter(ab_x, ab_y, color = 'red')
plt.show()

# %%
m2 = abnormal.as_matrix()
u, s, v = np.linalg.svd(m2)
plt.plot(s[0:400])
plt.show()

# %%
origin['num_points']

plot_data = origin[origin['num_points'] >= 0 ]['num_points'].values

x = np.array(list(range(100, 1001)))
y, x = np.histogram(plot_data, bins=x)
x_bin = np.delete(x, 0)

import matplotlib.pyplot as plt
plt.plot(x_bin, y)
plt.show()

# %%
import numpy as np
from scipy.optimize import curve_fit
def func(x, a, b):
    return a * np.exp(-b * x)

xdata = x_bin
ydata = y

print(xdata.shape)
print(ydata.shape)

popt, pcov = curve_fit(func, xdata, ydata, p0=[0.0007, 0.0004])

print(popt)
print(pcov)
plt.plot(x_bin, func(x_bin,*popt), color='g', linewidth=10)
plt.plot(x_bin, y, color='r')
plt.show()

# %% [markdown]
# from scipy.stats import expon
# loc, lamb = expon.fit(plot_data)

# %%
import matplotlib.pyplot as plt
import numpy as np
from numpy.random import normal

plt.hist(plot_data, bins=x_bin)
plt.plot(x_bin, func(x_bin,*popt), color='g', linewidth=3)
plt.show()

# %%
a = np.array([1,2,3,4,5])
a[(a>1) & (a<5)]=0
a

np.log(1)

# %%
#Study double / triple exponential behaviour of the distribution

x = np.linspace(0.0000001, 1, 100000)

def log_tower(plot_data, k):
    for i in range(0, k):
        plot_data[plot_data < 1] = 1.
        plot_data = np.log(plot_data)
    #plot_data[plot_data < 1] = 0.
    return plot_data

ln_plot_data = log_tower(np.array(plot_data), 3)

print(ln_plot_data.shape)

y, x = np.histogram(ln_plot_data, bins=x)
x_bin = np.delete(x, 0)

import matplotlib.pyplot as plt
plt.plot(x_bin, y)
plt.show()

# %%
#Compute the elbow of exponential curve

x = np.linspace(0, 100, 10000)
y, x = np.histogram(plot_data, bins=x)
x_bin = np.delete(x, 0)

import matplotlib.pyplot as plt
plt.plot(x_bin, y)
plt.show()

# %%
#1. Compute the derivative

def derivative(np_array):
    a = np.delete(np_array, len(np_array)-1)
    b = np.delete(np_array, 0)
    return a-b

d_y = derivative(derivative(y))
d_x_bin = np.linspace(0, len(d_y), len(d_y))

print(x_bin.shape)
print(d_y.shape)
print(d_x_bin.shape)

import matplotlib.pyplot as plt
plt.plot(d_x_bin, d_y)
plt.show()

print(np.argmax(d_y))

# %%
# Find elbow from curve estimate

origin['num_points']

plot_data = origin[origin['num_points'] >= 0 ]['num_points'].values

x = np.linspace(0, 20, 20)
y, x = np.histogram(plot_data, bins=x)
x_bin = np.delete(x, 0)

import matplotlib.pyplot as plt
plt.plot(x_bin, y)
plt.show()

import numpy as np
from scipy.optimize import curve_fit
def func(x, a, b):
    return a * np.exp(-b * x)

xdata = x_bin
ydata = y

print(xdata.shape)
print(ydata.shape)

popt, pcov = curve_fit(func, xdata, ydata, p0=[0.0007, 0.0004])

print(popt)
print(pcov)
plt.plot(x_bin, func(x_bin,*popt), color='g', linewidth=10)
plt.plot(x_bin, y, color='r')
plt.show()

# %%
a, b = popt
print(a)
print(b)

# second derivative of a * e^(-bx) is ab^2e^(-bx)

def firstD(a,b,x):
    return - a * b * np.exp(-b * x)


def secondD(a,b,x):
    return a * np.square(b) * np.exp(-b * x)

plt.plot(x_bin, secondD(a,b,x_bin))
plt.plot(x_bin, firstD(a,b,x_bin))
plt.show()

# %% [markdown]
# from keras.layers import Input, LSTM, RepeatVector, Dense
# from keras.models import Model, Sequential
#
# input_dim = 50
# timesteps = 24
# latent_dim = 200
#
# predictor = Sequential()
# predictor.add(LSTM(100, input_shape=(timesteps, input_dim)))
# predictor.add(Dense(100, init='normal', activation='tanh'))
# predictor.add(Dense(1, init='normal', activation='sigmoid'))
#
# '''
# decoded = RepeatVector(timesteps)(encoded)
# #decoded = LSTM(input_dim, return_sequences=True)(encoded)
# decoded = LSTM(input_dim, return_sequences=True)(decoded)
#
# sequence_autoencoder = Model(inputs, decoded)
# encoder = Model(inputs, encoded)
# '''

# %% [markdown]
# X = train.drop(['good'], axis=1)
# Y = test.drop(['good'], axis=1)
#
# X = X.as_matrix().reshape(train.shape[0], 24, 50)
# Y = Y.as_matrix().reshape(test.shape[0], 24, 50)

# %% [markdown]
# predictor.compile(loss='binary_crossentropy', optimizer='Adam', metrics=['accuracy', 'precision', 'recall', 'fmeasure'])
# predictor.fit(X, train['good'], validation_data=(Y, test['good']))

# %% [markdown]
# sequence_autoencoder.evaluate(Y,test['good'])
