# %%
#import Corpus.gutenberg as corpus
#from TextPreprocess.Tokenizer.Stanford import tokenize
#from Utils.visual import hist, tally
#from Utils.debug import dump
from DataLoader import GloVe
from Utils.generator import sliding_window_random_access, transform
#from Utils.FS.file import save, load
#from Utils.keras import compact_embedding
from Utils.misc import batch
#from Utils.indexer import build_index, index_2_one_hot
from Utils.indexer import build_index
#from keras.preprocessing.sequence import pad_sequences
from keras_tqdm import TQDMNotebookCallback
import numpy as np
from random import randint
# Out:
# Using TensorFlow backend.

# %%
from nltk.corpus import gutenberg
#sents = gutenberg.sents(['austen-emma.txt', 'austen-persuasion.txt', 'austen-sense.txt'])
words = gutenberg.words(['austen-emma.txt', 'austen-persuasion.txt', 'austen-sense.txt'])
#words = gutenberg.words()
words = batch(lambda s: s.lower())(words)
print(len(words))
#sents = batch(batch(toLower))(sents)
# Out:
# 432174

# %%
def words_generator():
    for word in words:
        yield word

# %%
# build index for all words
o2i, i2o, size = build_index(words_generator())
print(size)
print(o2i('a'))
print(o2i('and'))
print(o2i('the'))
# Out:
# 10650
# 17
# 14
# 27

# %%
#WORD_EMB_DIM = 300
#glove = GloVe.load2('./data/GloVe/glove.840B.{}d.txt'.format(WORD_EMB_DIM), WORD_EMB_DIM)

#WORD_EMB_DIM = 50
#glove = GloVe.load2('./data/GloVe/glove.6B.{}d.txt'.format(WORD_EMB_DIM), WORD_EMB_DIM)

#WORD_EMB_DIM = 50
#glove, orig_glove = GloVe.selective_load('./data/GloVe/glove.6B.{}d.txt'.format(WORD_EMB_DIM), WORD_EMB_DIM, o2i, i2o, size)

WORD_EMB_DIM = 300
glove, orig_glove = GloVe.selective_load('./data/GloVe/glove.6B.{}d.txt'.format(WORD_EMB_DIM), WORD_EMB_DIM, o2i, i2o, size)
# Out:
# Start: Loading Glove Model
# End: Loaded 400000 rows.

# %%
#print(np.average([len(sent) for sent in sents]))
SEQ_LENGTH = 16

# %%
from keras.layers import Activation, dot, add, MaxPooling1D, MaxPooling2D, Bidirectional, Input, GRU, LSTM, SimpleRNN, Conv1D, Conv2D, Conv2DTranspose, Dense, Flatten, Dropout, Reshape, Embedding, Concatenate
from keras.models import Model, Sequential
from keras.regularizers import l2
from keras.optimizers import Adam
from keras.constraints import unit_norm
from keras.initializers import Identity
from keras import backend as K
from keras.engine.topology import Layer
import numpy as np
import tensorflow as tf

POS_EMB_SIZE = 50    

def create_encoder(inp):
    sem_emb = Embedding(glove.shape[0], glove.shape[1], weights=[glove], input_length=SEQ_LENGTH, trainable=False )(inp)
    query_emb = Embedding(glove.shape[0], POS_EMB_SIZE, embeddings_constraint=unit_norm())(inp)
    
    x = Bidirectional(GRU(POS_EMB_SIZE // 2, activation='selu', return_sequences=True))(sem_emb)
    query = Bidirectional(GRU(POS_EMB_SIZE // 2, activation='selu'))(x)
    
    return query, query_emb, sem_emb

def attention(query, query_emb, sem_emb):
    att = dot([query, query_emb], (1,2))
    att = Activation('softmax')(att)
    att = dot([att, sem_emb], (1,1))
    return att

def VanillaCNN(source, layer, dim):
    for l in range(layer): 
        dim = dim // 2
    for l in range(layer):
        dim *= 2
        source = Reshape((source.shape[1].value, source.shape[2].value, 1))(source)
        source = Conv2D(dim, (2, source.shape[2].value), strides=(2, 1), activation='selu', padding='valid', use_bias=True)(source)
        source = Reshape((source.shape[1].value, source.shape[3].value))(source)
        #x = MaxPooling2D(pool_size=(2, 1), padding=padding)(x)        
    
    return source

class ReverseEmbedding(Layer):
    def __init__(self, layer, **kwargs):
        self.emb_layer = layer
        super(ReverseEmbedding, self).__init__(**kwargs)

    def build(self, input_shape):
        super(ReverseEmbedding, self).build(input_shape)  # Be sure to call this somewhere!

    def call(self, x):
        return K.dot(x, K.transpose(self.emb_layer.get_weights()[0]))

    def compute_output_shape(self, input_shape):
        return (input_shape[0], self.emb_layer.get_weights()[0].shape[0])


def create_baseline():
    
    GRU_DIM = 256
        
    inp = Input(shape=(SEQ_LENGTH,))
    embeddingLayer = Embedding(glove.shape[0], glove.shape[1], weights=[glove], input_length=SEQ_LENGTH, trainable=False)
    sem_emb = embeddingLayer(inp)
    query_emb = Embedding(glove.shape[0], glove.shape[1], input_length=SEQ_LENGTH, trainable=True)(inp)
    print(sem_emb)
    query = VanillaCNN(sem_emb, 2, 256)
    #att = attention(query, query_emb, sem_emb)
    
    predict = Flatten()(query)
    #predict = Concatenate()([query, att1])
    predict = Dense(glove.shape[0], activation='softmax')(predict)
    model = Model(inp, predict)
    model.compile(loss='sparse_categorical_crossentropy',
              optimizer='adam')
    return model

# %%
model = create_baseline()
model.summary()
# Out:
# Tensor("embedding_39/Gather:0", shape=(?, 16, 300), dtype=float32)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_26 (InputLayer)        (None, 16)                0
# _________________________________________________________________
# embedding_39 (Embedding)     (None, 16, 300)           3195000
# _________________________________________________________________
# reshape_135 (Reshape)        (None, 16, 300, 1)        0
# _________________________________________________________________
# conv2d_69 (Conv2D)           (None, 8, 1, 128)         76928
# _________________________________________________________________
# reshape_136 (Reshape)        (None, 8, 128)            0
# _________________________________________________________________
# reshape_137 (Reshape)        (None, 8, 128, 1)         0
# _________________________________________________________________
# conv2d_70 (Conv2D)           (None, 4, 1, 256)         65792
# _________________________________________________________________
# reshape_138 (Reshape)        (None, 4, 256)            0
# _________________________________________________________________
# flatten_12 (Flatten)         (None, 1024)              0
# _________________________________________________________________
# dense_21 (Dense)             (None, 10650)             10916250
# =================================================================
# Total params: 14,253,970
# Trainable params: 11,058,970
# Non-trainable params: 3,195,000
# _________________________________________________________________

# %%
from keras.utils.np_utils import to_categorical

def decode_word(one_hot):
    return i2s( np.random.choice(list(range(NUM_SYMBOL)), p = one_hot)  )

def decode_word_2(one_hot):
    return i2s( np.argmax(one_hot) )


# last char is used as output
# so set it like gen = sliding_window(SEQ_LENGTH + 1)(data)
def sample_generator(sliding_window_generator, batch_size = 64):
    data = []
    label = []
    for window in sliding_window_generator:
        data.append(batch(o2i)(window[:-1]))
        label.append(o2i(window[-1]))
        if len(data) == batch_size:
            yield (np.array(data), np.array(label))
            data = []
            label = []

# %%
gen = {}
size = {}
gen['train'], gen['test'], size['train'], size['test'] = sliding_window_random_access(words, SEQ_LENGTH + 1)
print(next(sample_generator(gen['train'], 2))[0].shape)
print(next(sample_generator(gen['test'], 3))[1].shape)
# Out:
# Training data size: 345726
# Testing data size: 86432
# (2, 16)
# (3,)

# %%
from keras.callbacks import Callback, ModelCheckpoint

def sample(a, temperature=1.0):
    # helper function to sample an index from a probability array
    a = np.log(a) / temperature
    a = np.exp(a) / np.sum(np.exp(a))
    return np.random.choice(glove.shape[0], p=a)

def testing(model):
    #seed = """Your child comes home and presents you with a drawing of your house . There is a blue house , a yellow sun , and a green sky . What else do you want ?"""
    #words = seed.lower().split(' ')
    #for i in range(50):
    #    predict = model.predict(np.array([batch(o2i)(words[-SEQ_LENGTH:])]))[0]
    #    i = np.argmax(predict)
    #    words.append(i2o(i))
        
    #print(' '.join(words))
        
    seed = """Your child comes home and presents you with a drawing of your house . There is a blue house , a yellow sun , and a green sky . What else do you want ?"""
    words = seed.lower().split(' ')
    for i in range(200):
        predict = model.predict(np.array([batch(o2i)(words[-SEQ_LENGTH:])]))[0]
        i = sample(predict, 0.5)
        words.append(i2o(i))
        
    print(' '.join(words))
    
class testSample(Callback):
    def on_epoch_end(self, batch, logs={}):
        testing(model)

# %%
from keras_tqdm import TQDMNotebookCallback

mc = ModelCheckpoint('./model/word_model.hdf5', monitor='val_loss', verbose=0, save_best_only=True, save_weights_only=False, mode='auto', period=1)

BATCH_SIZE = 2048
model.fit_generator(
    sample_generator(gen['train'], BATCH_SIZE),
    size['train'] // BATCH_SIZE,
    validation_data = sample_generator(gen['test'], BATCH_SIZE),
    validation_steps = size['test'] // BATCH_SIZE,
    epochs=200000,
    callbacks = [testSample(), mc]
    #verbose=0, callbacks=[TQDMNotebookCallback(), testSample()]
)
# Out:
# Epoch 1/200000
# your child comes home and presents you with a drawing of your house . there is a blue house , a yellow sun , and a green sky . what else do you want ? i am have to be me . i do not be be i am me you me can be all you is you have to be to you to me . i have do be not have you been . your thing . i do i be be you . i do not be be be be ." to my ." ; " i have be have not not you should she to be be miss . " i have have have i have me i you will you you to be me . but . i have be have be all you you be have say i have i have have have have be be thing . i have be be not , and you be have a of the family of his , and the the carriage of the mother , and the house of the his of the being friend , and in the hand of the quarter being in badness . he had absolutely " not not not to be to be little , and , she am a have to not your own . her . and forwards of a room . i had been
# 168/168 [==============================] - 73s - loss: 6.2004 - val_loss: 5.6431
# Epoch 2/200000
# your child comes home and presents you with a drawing of your house . there is a blue house , a yellow sun , and a green sky . what else do you want ? you do be much that i do you do you my ," ?" " i will you do you i you you i ?-- you you you you are i you you you ." ." " i am sure you you i i do you , i do you are i will you you i i you you you you -- i do you i will you will you you ." you will you you will you you . you you think you can i shall i shall you you i do you ." you i do you your , i am sure you is i are very that i will have ." " i ! you !" me you are to you ." , i know you can have i think i have i do you ," " yes i do you you will have you i shall i do you you you ." ." i can do you you you i know i do you you ." you ." my father -- i will you know you do not have been quite .-- " i am sure you . i have not you ." . i am very
# 168/168 [==============================] - 70s - loss: 5.3460 - val_loss: 5.2779
# Epoch 3/200000
# your child comes home and presents you with a drawing of your house . there is a blue house , a yellow sun , and a green sky . what else do you want ? that is is very sure , i am sure you are you my own , i am sure you will i have i am sure you will you ." me . i am sure to do you you ," you you will you do do you you will be my father ," " my dear you will do you you are you ," i am sure you will you have not you to be made the world , since i am to you what to you to hear ." , to be an time of the same of any thing , and he was very much to be the great of the room , and but , the most of the year , and the the same of the latter , and , , was little in the wife , and when he had been been in the room , the most of the most deal of the world , as the little of of , and the first of the room , and a few of the manner , and she had not been a little couple , and , and had been been able to be much to
# 168/168 [==============================] - 70s - loss: 4.9662 - val_loss: 5.2055
# Epoch 4/200000
# your child comes home and presents you with a drawing of your house . there is a blue house , a yellow sun , and a green sky . what else do you want 