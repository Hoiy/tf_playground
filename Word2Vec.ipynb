# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import collections
import math
import os
import random
import zipfile

import numpy as np
from six.moves import urllib
from six.moves import xrange  # pylint: disable=redefined-builtin
import tensorflow as tf

# %%
# Step 1: Download the data.
url = 'http://mattmahoney.net/dc/'


def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urllib.request.urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified', filename)
  else:
    print(statinfo.st_size)
    raise Exception(
        'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %%
# Read the data into a list of strings.
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words."""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data

vocabulary = read_data(filename)
print('Data size', len(vocabulary))

# Step 2: Build the dictionary and replace rare words with UNK token.
vocabulary_size = 50000
# Out:
# Data size 17005207

# %%
def build_dataset(words, n_words):
  """Process raw inputs into a dataset."""
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(n_words - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count += 1
    data.append(index)
  count[0][1] = unk_count
  reversed_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
  return data, count, dictionary, reversed_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(vocabulary,
                                                            vocabulary_size)
del vocabulary  # Hint to reduce memory.
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10], [reverse_dictionary[i] for i in data[:10]])

data_index = 0
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5238, 3083, 12, 6, 195, 2, 3134, 46, 59, 156] ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']

# %%
# Step 3: Function to generate a training batch for the skip-gram model.
def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1  # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [skip_window]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  # Backtrack a little bit to avoid skipping words in the end of a batch
  data_index = (data_index + len(data) - span) % len(data)
  return batch, labels# Step 4: Build and train a skip-gram model.

batch_size = 128
embedding_size = 128  # Dimension of the embedding vector.
skip_window = 1       # How many words to consider left and right.
num_skips = 2         # How many times to reuse an input to generate a label.

# We pick a random validation set to sample nearest neighbors. Here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent.
valid_size = 16     # Random set of words to evaluate similarity on.
valid_window = 100  # Only pick dev samples in the head of the distribution.
valid_examples = np.random.choice(valid_window, valid_size, replace=False)
num_sampled = 64    # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default():

  # Input data.
  train_inputs = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

  # Ops and variables pinned to the CPU because of missing GPU implementation
  with tf.device('/cpu:0'):
    # Look up embeddings for inputs.
    embeddings = tf.Variable(
        tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    embed = tf.nn.embedding_lookup(embeddings, train_inputs)

    # Construct the variables for the NCE loss
    nce_weights = tf.Variable(
        tf.truncated_normal([vocabulary_size, embedding_size],
                            stddev=1.0 / math.sqrt(embedding_size)))
    nce_biases = tf.Variable(tf.zeros([vocabulary_size]))

  # Compute the average NCE loss for the batch.
  # tf.nce_loss automatically draws a new sample of the negative labels each
  # time we evaluate the loss.
  loss = tf.reduce_mean(
      tf.nn.nce_loss(weights=nce_weights,
                     biases=nce_biases,
                     labels=train_labels,
                     inputs=embed,
                     num_sampled=num_sampled,
                     num_classes=vocabulary_size))

  # Construct the SGD optimizer using a learning rate of 1.0.
  optimizer = tf.train.GradientDescentOptimizer(1.0).minimize(loss)

  # Compute the cosine similarity between minibatch examples and all embeddings.
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
      normalized_embeddings, valid_dataset)
  similarity = tf.matmul(
      valid_embeddings, normalized_embeddings, transpose_b=True)

  # Add variable initializer.
  init = tf.global_variables_initializer()

batch, labels = generate_batch(batch_size=8, num_skips=2, skip_window=1)
for i in range(8):
  print(batch[i], reverse_dictionary[batch[i]],
        '->', labels[i, 0], reverse_dictionary[labels[i, 0]])
# Out:
# 3083 originated -> 12 as
# 3083 originated -> 5238 anarchism
# 12 as -> 3083 originated
# 12 as -> 6 a
# 6 a -> 195 term
# 6 a -> 12 as
# 195 term -> 6 a
# 195 term -> 2 of

# %%
# Step 5: Begin training.
num_steps = 100001

with tf.Session(graph=graph) as session:
  # We must initialize all variables before we use them.
  init.run()
  print('Initialized')

  average_loss = 0
  for step in xrange(num_steps):
    batch_inputs, batch_labels = generate_batch(
        batch_size, num_skips, skip_window)
    feed_dict = {train_inputs: batch_inputs, train_labels: batch_labels}

    # We perform one update step by evaluating the optimizer op (including it
    # in the list of returned values for session.run()
    _, loss_val = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += loss_val

    if step % 2000 == 0:
      if step > 0:
        average_loss /= 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step ', step, ': ', average_loss)
      average_loss = 0

    # Note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in xrange(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8  # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k + 1]
        log_str = 'Nearest to %s:' % valid_word
        for k in xrange(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log_str = '%s %s,' % (log_str, close_word)
        print(log_str)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step  0 :  264.148071289
# Nearest to were: misskelley, penance, halicarnassus, implantation, bosniaks, tackle, finkelstein, seleucids,
# Nearest to this: ideological, flagella, unicorn, saskatoon, patanjali, tao, textbook, traveller,
# Nearest to three: highs, amber, glues, tupelo, invoke, beneficial, bonzo, whyte,
# Nearest to at: ohrid, islet, fournier, disgrace, cetaceans, playable, formic, regains,
# Nearest to about: zeppo, dielectric, xiongnu, protagonist, amigaos, nothing, jeffery, philibert,
# Nearest to zero: paleontologist, dry, bulwark, leadership, fantastically, available, gambeson, yardbirds,
# Nearest to by: mcconnell, flu, xp, tae, emphasizes, manhunter, proofing, carlisle,
# Nearest to six: velarized, vijayanagara, mahler, tyson, multihulls, necropolis, quackery, seater,
# Nearest to with: hyacinthus, adheres, agesilaus, magnetically, phosphates, rommel, deuterostomes, petal,
# Nearest to see: facilitating, shirow, consulates, muriel, fulda, vert, af, pashto,
# Nearest to in: lux, khanate, magnification, acting, boarded, boney, novelty, pounder,
# Nearest to however: accentuated, meetings, submission, vernon, combative, epicenter, greaves, classmates,
# Nearest to of: jam, mst, transcribe, bev, spring, coinage, humorists, lin,
# Nearest to between: servicio, interjections, acclaim, sanctioning, digests, weicker, nitrogenous, suggested,
# Nearest to some: falciparum, carrel, miguel, rajah, tylor, purposes, colbert, battering,
# Nearest to eight: huns, pollutants, pretenders, pirin, calculator, bergson, novi, operetta,
# Average loss at step  2000 :  113.057215813
# Average loss at step  4000 :  52.4066080613
# Average loss at step  6000 :  33.4171557051
# Average loss at step  8000 :  23.4486941286
# Average loss at step  10000 :  18.3764740803
# Nearest to were: nine, referenced, ataxia, murdered, are, and, camus, anteaters,
# Nearest to this: the, a, deke, recorder, wiesenthal, canaris, goods, his,
# Nearest to three: nine, zero, bckgr, gland, jpg, four, alien, eight,
# Nearest to at: in, and, of, sanctuary, proven, aries, schopenhauer, ry,
# Nearest to about: nothing, armenian, phi, essay, recovered, steadily, ada, severity,
# Nearest to zero: nine, one, eight, archie, bckgr, four, gb, six,
# Nearest to by: and, in, bckgr, as, on, of, semitic, is,
# Nearest to six: nine, eight, zero, one, gb, bckgr, five, agave,
# Nearest to with: in, of, and, while, on, from, speculative, babylon,
# Nearest to see: larger, muriel, facilitating, wehrmacht, treaties, nevertheless, electric, controlling,
# Nearest to in: and, of, with, on, for, by, at, bckgr,
# Nearest to however: cultures, meetings, submission, tells, gb, midrash, inventor, surface,
# Nearest to of: and, in, for, with, conformation, from, the, basins,
# Nearest to between: suggested, servicio, sanctioning, pleas, sketching, doctrine, confirmation, proof,
# Nearest to some: the, bckgr, carrel, canaris, asian, purposes, ambiguity, raphael,
# Nearest to eight: nine, zero, six, archie, bckgr, five, vs, gb,
# Average loss at step  12000 :  14.0628016417
# Average loss at step  14000 :  11.8371818731
# Average loss at step  16000 :  9.99553228796
# Average loss at step  18000 :  8.49352560484
# Average loss at step  20000 :  8.02788849163
# Nearest to were: are, was, is, and, been, referenced, at, had,
# Nearest to this: the, a, his, it, dasyprocta, recorder, agouti, which,
# Nearest to three: nine, eight, four, zero, five, two, agouti, seven,
# Nearest to at: in, and, dasyprocta, of, on, ulyanov, circ, islet,
# Nearest to about: armenian, nine, nothing, phi, steadily, philibert, essay, recovered,
# Nearest to zero: nine, eight, five, four, dasyprocta, three, six, seven,
# Nearest to by: in, was, is, and, for, as, from, with,
# Nearest to six: nine, eight, five, zero, dasyprocta, four, three, seven,
# Nearest to with: in, for, and, of, from, dasyprocta, circ, while,
# Nearest to see: and, muriel, or, drummer, larger, cite, treaties, facilitating,
# Nearest to in: and, of, with, on, for, at, from, by,
# Nearest to however: meetings, cultures, submission, vernon, tells, abort, agouti, threat,
# Nearest to of: in, and, for, dasyprocta, from, nine, circ, agouti,
# Nearest to between: sanctioning, gollancz, of, acclaim, servicio, sketching, georges, with,
# Nearest to some: the, agouti, canaris, bckgr, other, dasyprocta, yang, asian,
# Nearest to eight: nine, six, five, zero, three, four, seven, circ,
# Average loss at step  22000 :  7.09684090936
# Average loss at step  24000 :  6.91314987671
# Average loss at step  26000 :  6.78305805278
# Average loss at step  28000 :  6.39617328918
# Average loss at step  30000 :  5.87618122959
# Nearest to were: are, was, is, been, have, had, referenced, by,
# Nearest to this: the, which, it, dasyprocta, a, his, agouti, that,
# Nearest to three: four, five, seven, eight, six, two, nine, zero,
# Nearest to at: in, and, on, dasyprocta, periodical, ulyanov, seven, circ,
# Nearest to about: armenian, abet, phi, steadily, philibert, nine, nothing, recovered,
# Nearest to zero: five, six, eight, nine, four, dasyprocta, seven, three,
# Nearest to by: in, was, as, for, and, with, from, is,
# Nearest to six: eight, five, nine, four, seven, zero, three, dasyprocta,
# Nearest to with: for, in, dasyprocta, circ, from, while, and, by,
# Nearest to see: muriel, two, and, five, or, alligators, agi, otimes,
# Nearest to in: on, at, and, for, of, from, with, dasyprocta,
# Nearest to however: meetings, crematoria, cultures, vernon, submission, boot, agouti, tells,
# Nearest to of: and, in, for, dasyprocta, from, nine, circ, eight,
# Nearest to between: sanctioning, gollancz, acclaim, with, while, from, sketching, of,
# Nearest to some: many, the, agouti, other, canaris, their, abet, bckgr,
# Nearest to eight: nine, six, five, four, seven, zero, three, dasyprocta,
# Average loss at step  32000 :  5.94283014518
# Average loss at step  34000 :  5.65884267974
# Average loss at step  36000 :  5.8073898946
# Average loss at step  38000 :  5.51311587846
# Average loss at step  40000 :  5.25727033973
# Nearest to were: are, was, is, have, been, had, zero, referenced,
# Nearest to this: which, it, the, that, dasyprocta, a, agouti, his,
# Nearest to three: four, five, six, seven, eight, two, zero, nine,
# Nearest to at: in, on, dasyprocta, and, ulyanov, periodical, circ, abet,
# Nearest to about: armenian, abet, philibert, steadily, phi, four, recovered, nothing,
# Nearest to zero: dasyprocta, eight, five, four, circ, agouti, six, seven,
# Nearest to by: was, as, in, is, be, zero, from, marple,
# Nearest to six: eight, four, seven, five, nine, three, zero, dasyprocta,
# Nearest to with: for, in, circ, dasyprocta, from, while, and, on,
# Nearest to see: muriel, eucalyptus, otimes, resign, and, nevertheless, cite, agi,
# Nearest to in: on, and, at, of, from, dasyprocta, circ, zero,
# Nearest to however: crematoria, meetings, vernon, but, cultures, submission, tells, agouti,
# Nearest to of: in, dasyprocta, and, for, from, zero, agouti, circ,
# Nearest to between: sanctioning, gollancz, with, while, from, acclaim, servicio, sketching,
# Nearest to some: many, the, these, agouti, their, other, abet, canaris,
# Nearest to eight: nine, six, seven, four, five, zero, three, dasyprocta,
# Average loss at step  42000 :  5.38237993753
# Average loss at step  44000 :  5.24131191111
# Average loss at step  46000 :  5.20664945877
# Average loss at step  48000 :  5.21875496757
# Average loss at step  50000 :  4.99192153251
# Nearest to were: are, was, is, have, had, been, cem, referenced,
# Nearest to this: which, it, the, that, dasyprocta, agouti, four, franchisee,
# Nearest to three: four, five, six, seven, two, eight, dasyprocta, agouti,
# Nearest to at: in, on, dasyprocta, during, and, from, ulyanov, abet,
# Nearest to about: armenian, abet, steadily, philibert, four, phi, three, recovered,
# Nearest to zero: eight, seven, six, five, four, nine, dasyprocta, three,
# Nearest to by: was, as, for, is, be, from, in, and,
# Nearest to six: eight, four, five, seven, three, nine, dasyprocta, zero,
# Nearest to with: for, in, while, circ, from, dasyprocta, and, between,
# Nearest to see: and, nevertheless, parodied, cite, eucalyptus, muriel, resign, otimes,
# Nearest to in: at, on, during, from, of, dasyprocta, with, circ,
# Nearest to however: but, crematoria, that, submission, cultures, vernon, meetings, agouti,
# Nearest to of: in, dasyprocta, kapoor, agouti, for, from, circ, recitative,
# Nearest to between: with, sanctioning, gollancz, in, while, acclaim, from, seven,
# Nearest to some: many, these, the, other, agouti, abet, their, canaris,
# Nearest to eight: six, seven, nine, five, four, three, zero, dasyprocta,
# Average loss at step  52000 :  5.02076400352
# Average loss at step  54000 :  5.16656351316
# Average loss at step  56000 :  5.05862770116
# Average loss at step  58000 :  5.0447307843
# Average loss at step  60000 :  4.9410968895
# Nearest to were: are, was, had, have, been, is, cem, be,
# Nearest to this: which, it, that, dasyprocta, the, agouti, four, one,
# Nearest to three: five, four, two, six, seven, eight, dasyprocta, one,
# Nearest to at: in, on, dasyprocta, during, pulau, periodical, three, ulyanov,
# Nearest to about: armenian, abet, four, philibert, steadily, recovered, six, freiburg,
# Nearest to zero: seven, eight, six, five, nine, four, dasyprocta, pulau,
# Nearest to by: was, be, as, marple, from, for, using, dasyprocta,
# Nearest to six: eight, five, four, seven, nine, three, zero, dasyprocta,
# Nearest to with: while, circ, for, in, dasyprocta, between, pulau, suffrage,
# Nearest to see: nevertheless, eucalyptus, muriel, parodied, resign, and, andes, cite,
# Nearest to in: on, during, at, and, from, dasyprocta, of, circ,
# Nearest to however: but, crematoria, agouti, vernon, that, submission, although, cultures,
# Nearest to of: dasyprocta, and, in, nine, kapoor, ursus, pulau, for,
# Nearest to between: with, sanctioning, gollancz, while, in, from, acclaim, against,
# Nearest to some: many, these, other, several, the, their, abet, agouti,
# Nearest to eight: nine, six, seven, five, four, zero, three, pulau,
# Average loss at step  62000 :  5.01124776018
# Average loss at step  64000 :  4.84457837427
# Average loss at step  66000 :  4.58663791108
# Average loss at step  68000 :  4.97712003136
# Average loss at step  70000 :  4.88583243811
# Nearest to were: are, was, have, had, been, cem, is, alphorn,
# Nearest to this: which, it, the, that, dasyprocta, agouti, krone, franchisee,
# Nearest to three: five, four, six, two, seven, eight, dasyprocta, one,
# Nearest to at: in, during, on, dasyprocta, microcebus, ulyanov, pulau, three,
# Nearest to about: armenian, abet, philibert, steadily, four, recovered, freiburg, wct,
# Nearest to zero: eight, five, six, seven, nine, four, three, dasyprocta,
# Nearest to by: was, be, as, marple, using, upanija, from, through,
# Nearest to six: eight, four, five, seven, three, nine, two, zero,
# Nearest to with: while, between, suffrage, circ, in, for, dasyprocta, pulau,
# Nearest to see: thaler, but, nevertheless, andes, eucalyptus, muriel, parodied, schneier,
# Nearest to in: during, at, on, gollancz, and, from, dasyprocta, circ,
# Nearest to however: but, although, crematoria, agouti, vernon, michelob, callithrix, submission,
# Nearest to of: dasyprocta, kapoor, and, ursus, agouti, pulau, in, recitative,
# Nearest to between: with, while, sanctioning, servicio, gollancz, acclaim, in, from,
# Nearest to some: many, these, other, several, their, abet, the, canaris,
# Nearest to eight: six, seven, nine, five, four, three, zero, pulau,
# Average loss at step  72000 :  4.76296605062
# Average loss at step  74000 :  4.80229045379
# Average loss at step  76000 :  4.72856537783
# Average loss at step  78000 :  4.786683667
# Average loss at step  80000 :  4.78154509747
# Nearest to were: are, was, had, have, been, cem, is, be,
# Nearest to this: which, it, that, dasyprocta, agouti, the, ursus, krone,
# Nearest to three: five, four, two, six, seven, eight, one, dasyprocta,
# Nearest to at: in, during, on, microcebus, dasyprocta, pulau, ulyanov, periodical,
# Nearest to about: armenian, steadily, abet, philibert, recovered, freiburg, four, wct,
# Nearest to zero: four, five, six, eight, seven, nine, dasyprocta, three,
# Nearest to by: was, be, from, as, through, upanija, using, with,
# Nearest to six: seven, five, four, eight, three, nine, two, zero,
# Nearest to with: while, between, suffrage, in, circ, agave, dasyprocta, pulau,
# Nearest to see: manure, thaler, nevertheless, andes, but, muriel, eucalyptus, meridians,
# Nearest to in: during, at, dasyprocta, on, circ, marek, of, from,
# Nearest to however: but, although, agouti, that, crematoria, ursus, michelob, callithrix,
# Nearest to of: dasyprocta, kapoor, in, ursus, agouti, pulau, abet, circ,
# Nearest to between: with, gollancz, sanctioning, servicio, while, in, from, acclaim,
# Nearest to some: many, these, several, other, the, abet, their, all,
# Nearest to eight: seven, nine, six, five, four, zero, three, pulau,
# Average loss at step  82000 :  4.77707640243
# Average loss at step  84000 :  4.75861860955
# Average loss at step  86000 :  4.76861948216
# Average loss at step  88000 :  4.73929598916
# Average loss at step  90000 :  4.71401345253
# Nearest to were: are, was, had, have, been, be, cem, is,
# Nearest to this: which, it, the, that, dasyprocta, agouti, another, ursus,
# Nearest to three: four, five, seven, six, two, eight, one, nine,
# Nearest to at: in, during, on, dasyprocta, pulau, microcebus, ulyanov, with,
# Nearest to about: armenian, steadily, abet, philibert, freiburg, recovered, over, around,
# Nearest to zero: five, eight, seven, six, four, nine, dasyprocta, circ,
# Nearest to by: was, as, be, through, upanija, with, using, from,
# Nearest to six: seven, five, eight, four, three, nine, zero, two,
# Nearest to with: while, between, in, suffrage, globemaster, circ, dasyprocta, pulau,
# Nearest to see: manure, nevertheless, thaler, and, but, andes, eucalyptus, resign,
# Nearest to in: during, at, on, and, dasyprocta, gollancz, of, marek,
# Nearest to however: but, although, that, while, agouti, ursus, michelob, dasyprocta,
# Nearest to of: dasyprocta, in, including, kapoor, pulau, ursus, and, globemaster,
# Nearest to between: with, in, while, sanctioning, gollancz, servicio, from, acclaim,
# Nearest to some: many, these, several, other, the, abet, their, all,
# Nearest to eight: seven, nine, six, five, four, zero, three, pulau,
# Average loss at step  92000 :  4.68137923014
# Average loss at step  94000 :  4.74364101338
# Average loss at step  96000 :  4.68910433424
# Average loss at step  98000 :  4.58926851642
# Average loss at step  100000 :  4.68104738629
# Nearest to were: are, was, have, had, been, is, be, while,
# Nearest to this: which, it, the, that, dasyprocta, agouti, krone, ursus,
# Nearest to three: four, five, seven, six, two, eight, nine, dasyprocta,
# Nearest to at: in, during, on, pulau, dasyprocta, microcebus, ulyanov, from,
# Nearest to about: armenian, steadily, freiburg, abet, philibert, over, three, recovered,
# Nearest to zero: five, eight, seven, nine, six, four, dasyprocta, three,
# Nearest to by: be, was, through, as, using, marple, upanija, tamarin,
# Nearest to six: seven, eight, four, five, nine, three, dasyprocta, two,
# Nearest to with: between, while, in, circ, globemaster, suffrage, pulau, dasyprocta,
# Nearest to see: four, thaler, manure, but, eucalyptus, meridians, nevertheless, and,
# Nearest to in: during, at, on, from, dasyprocta, since, circ, with,
# Nearest to however: but, although, that, while, ursus, agouti, dasyprocta, callithrix,
# Nearest to of: dasyprocta, kapoor, including, in, globemaster, dmd, ursus, pulau,
# Nearest to between: with, gollancz, from, while, sanctioning, servicio, in, acclaim,
# Nearest to some: many, these, several, their, other, all, abet, the,
# Nearest to eight: seven, six, nine, five, four, zero, three, pulau,

# %%
# Step 6: Visualize the embeddings.


def plot_with_labels(low_dim_embs, labels, filename='tsne.png'):
  assert low_dim_embs.shape[0] >= len(labels), 'More labels than embeddings'
  plt.figure(figsize=(18, 18))  # in inches
  for i, label in enumerate(labels):
    x, y = low_dim_embs[i, :]
    plt.scatter(x, y)
    plt.annotate(label,
                 xy=(x, y),
                 xytext=(5, 2),
                 textcoords='offset points',
                 ha='right',
                 va='bottom')
  plt.savefig(filename)

try:
  # pylint: disable=g-import-not-at-top
  from sklearn.manifold import TSNE
  import matplotlib.pyplot as plt

  tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
  plot_only = 500
  low_dim_embs = tsne.fit_transform(final_embeddings[:plot_only, :])
  labels = [reverse_dictionary[i] for i in xrange(plot_only)]
  plot_with_labels(low_dim_embs, labels)

except ImportError:
  print('Please install sklearn, matplotlib, and scipy to show embeddings.')
