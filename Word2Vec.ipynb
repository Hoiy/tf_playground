# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import collections
import math
import os
import random
import zipfile

import numpy as np
from six.moves import urllib
from six.moves import xrange  # pylint: disable=redefined-builtin
import tensorflow as tf

# %%
# Step 1: Download the data.
url = 'http://mattmahoney.net/dc/'


def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urllib.request.urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified', filename)
  else:
    print(statinfo.st_size)
    raise Exception(
        'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %%
# Read the data into a list of strings.
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words."""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data

vocabulary = read_data(filename)
print('Data size', len(vocabulary))

# Step 2: Build the dictionary and replace rare words with UNK token.
vocabulary_size = 50000
# Out:
# Data size 17005207

# %%
def build_dataset(words, n_words):
  """Process raw inputs into a dataset."""
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(n_words - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count += 1
    data.append(index)
  count[0][1] = unk_count
  reversed_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
  return data, count, dictionary, reversed_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(vocabulary,
                                                            vocabulary_size)
del vocabulary  # Hint to reduce memory.
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10], [reverse_dictionary[i] for i in data[:10]])

data_index = 0
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5243, 3082, 12, 6, 195, 2, 3135, 46, 59, 156] ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']

# %%
# Step 3: Function to generate a training batch for the skip-gram model.
def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1  # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [skip_window]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  # Backtrack a little bit to avoid skipping words in the end of a batch
  data_index = (data_index + len(data) - span) % len(data)
  return batch, labels# Step 4: Build and train a skip-gram model.

batch_size = 128
embedding_size = 128  # Dimension of the embedding vector.
skip_window = 1       # How many words to consider left and right.
num_skips = 2         # How many times to reuse an input to generate a label.

# We pick a random validation set to sample nearest neighbors. Here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent.
valid_size = 16     # Random set of words to evaluate similarity on.
valid_window = 100  # Only pick dev samples in the head of the distribution.
valid_examples = np.random.choice(valid_window, valid_size, replace=False)
num_sampled = 64    # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default():

  # Input data.
  train_inputs = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

  # Ops and variables pinned to the CPU because of missing GPU implementation
  with tf.device('/cpu:0'):
    # Look up embeddings for inputs.
    embeddings = tf.Variable(
        tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    embed = tf.nn.embedding_lookup(embeddings, train_inputs)

    # Construct the variables for the NCE loss
    nce_weights = tf.Variable(
        tf.truncated_normal([vocabulary_size, embedding_size],
                            stddev=1.0 / math.sqrt(embedding_size)))
    nce_biases = tf.Variable(tf.zeros([vocabulary_size]))

  # Compute the average NCE loss for the batch.
  # tf.nce_loss automatically draws a new sample of the negative labels each
  # time we evaluate the loss.
  loss = tf.reduce_mean(
      tf.nn.nce_loss(weights=nce_weights,
                     biases=nce_biases,
                     labels=train_labels,
                     inputs=embed,
                     num_sampled=num_sampled,
                     num_classes=vocabulary_size))

  # Construct the SGD optimizer using a learning rate of 1.0.
  optimizer = tf.train.GradientDescentOptimizer(1.0).minimize(loss)

  # Compute the cosine similarity between minibatch examples and all embeddings.
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
      normalized_embeddings, valid_dataset)
  similarity = tf.matmul(
      valid_embeddings, normalized_embeddings, transpose_b=True)

  # Add variable initializer.
  init = tf.global_variables_initializer()

batch, labels = generate_batch(batch_size=8, num_skips=2, skip_window=1)
for i in range(8):
  print(batch[i], reverse_dictionary[batch[i]],
        '->', labels[i, 0], reverse_dictionary[labels[i, 0]])
# Out:
# 3082 originated -> 12 as
# 3082 originated -> 5243 anarchism
# 12 as -> 3082 originated
# 12 as -> 6 a
# 6 a -> 12 as
# 6 a -> 195 term
# 195 term -> 6 a
# 195 term -> 2 of

# %%
# Step 5: Begin training.
num_steps = 100001

with tf.Session(graph=graph) as session:
  # We must initialize all variables before we use them.
  init.run()
  print('Initialized')

  average_loss = 0
  for step in xrange(num_steps):
    batch_inputs, batch_labels = generate_batch(
        batch_size, num_skips, skip_window)
    feed_dict = {train_inputs: batch_inputs, train_labels: batch_labels}

    # We perform one update step by evaluating the optimizer op (including it
    # in the list of returned values for session.run()
    _, loss_val = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += loss_val

    if step % 2000 == 0:
      if step > 0:
        average_loss /= 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step ', step, ': ', average_loss)
      average_loss = 0

    # Note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in xrange(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8  # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k + 1]
        log_str = 'Nearest to %s:' % valid_word
        for k in xrange(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log_str = '%s %s,' % (log_str, close_word)
        print(log_str)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step  0 :  275.006225586
# Nearest to seven: prophylaxis, hitters, emphasizes, empires, curves, yelling, humberto, personifications,
# Nearest to for: sil, cartagena, hestia, hag, parlor, adrienne, taping, lavinia,
# Nearest to and: temporally, reese, fisa, iqaluit, satem, paleontologist, agglutinative, pouring,
# Nearest to was: heavyweight, hemispheric, cno, mehrgarh, yod, hamad, offending, wrestling,
# Nearest to history: envision, syndicalists, braided, containment, adhesives, truer, olde, zo,
# Nearest to world: rockies, qualify, weinberger, goin, rarely, ossetia, cushions, kjv,
# Nearest to united: aristotle, alma, rosamund, engendered, cypriot, curtains, imbalances, marangella,
# Nearest to first: thrusts, hardships, bangladeshis, liturgy, almaty, affiliation, emergent, rarity,
# Nearest to may: museum, stomping, wiseman, alhazred, adaptive, egyptians, cleef, exploits,
# Nearest to with: minicomputers, sera, contradict, guitarists, qc, tripolitania, egypt, andrewes,
# Nearest to two: mosque, yucat, daughters, reconciled, dv, emo, perennials, visa,
# Nearest to during: scranton, ian, nailed, salinger, small, fend, etruria, knesset,
# Nearest to no: offering, heaviside, dirham, patrice, degrees, falklands, schematic, cena,
# Nearest to would: yuan, chat, cornerback, spectator, fargo, exiled, tourist, operands,
# Nearest to it: paper, adversity, disabling, enforced, benedictine, diverse, waring, milgrom,
# Nearest to were: borealis, unmixed, hodgkin, abstention, sampler, stylist, condorcet, opposition,
# Average loss at step  2000 :  114.11664714
# Average loss at step  4000 :  52.3607406631
# Average loss at step  6000 :  32.9839288194
# Average loss at step  8000 :  23.9764928285
# Average loss at step  10000 :  17.7337288082
# Nearest to seven: nine, zero, six, coke, agave, vs, eight, lymphoma,
# Nearest to for: of, and, bckgr, in, with, marriage, churches, rod,
# Nearest to and: in, of, or, UNK, bckgr, by, zero, for,
# Nearest to was: is, and, fiber, mood, arkham, by, distant, security,
# Nearest to history: lifetime, harmony, doubt, UNK, politically, trial, marple, eichmann,
# Nearest to world: bckgr, homme, qualify, type, rockies, rarely, constellations, constitute,
# Nearest to united: aristotle, alma, drag, value, of, surrounded, deism, thrace,
# Nearest to first: socrates, hardships, meteorites, middle, hep, final, victim, mosque,
# Nearest to may: museum, alhazred, withdrawal, exploits, water, than, nine, roof,
# Nearest to with: in, and, for, by, tendency, causes, telephone, from,
# Nearest to two: one, eight, mosque, six, three, nine, agave, UNK,
# Nearest to during: appearances, greenland, small, temporary, reducing, ian, australian, higher,
# Nearest to no: offering, hazards, degrees, review, einstein, lost, information, michael,
# Nearest to would: spectator, atari, tourist, authors, cornerback, chat, studies, astor,
# Nearest to it: he, melbourne, a, injuries, caffeine, paper, omnibus, both,
# Nearest to were: are, is, granted, and, release, out, attention, albert,
# Average loss at step  12000 :  14.0335200959
# Average loss at step  14000 :  11.6481443621
# Average loss at step  16000 :  9.99695817423
# Average loss at step  18000 :  8.44693208265
# Average loss at step  20000 :  8.03763279176
# Nearest to seven: nine, zero, eight, six, four, three, five, two,
# Nearest to for: in, and, of, with, bckgr, by, from, as,
# Nearest to and: or, in, of, UNK, bckgr, zero, for, s,
# Nearest to was: is, by, were, had, and, in, quarry, has,
# Nearest to history: doubt, harmony, lifetime, politically, dasyprocta, marple, trial, eichmann,
# Nearest to world: rockies, circ, homme, qualify, bckgr, type, thucydides, intersection,
# Nearest to united: aristotle, alma, of, rosamund, thrace, deism, drag, surrounded,
# Nearest to first: socrates, hardships, final, middle, surveillance, dukes, victim, passion,
# Nearest to may: museum, roof, exploits, can, nine, alhazred, stupa, water,
# Nearest to with: in, for, by, and, from, as, albuquerque, after,
# Nearest to two: one, three, eight, six, four, zero, five, agouti,
# Nearest to during: hijacked, greenland, appearances, australian, temporary, of, smokey, reducing,
# Nearest to no: offering, but, hazards, review, adam, degrees, separated, lost,
# Nearest to would: spectator, atari, chat, tourist, authors, can, cornerback, sat,
# Nearest to it: he, this, there, the, still, a, albuquerque, they,
# Nearest to were: are, is, was, had, and, as, have, by,
# Average loss at step  22000 :  6.97987447286
# Average loss at step  24000 :  6.91403996074
# Average loss at step  26000 :  6.79426357543
# Average loss at step  28000 :  6.38898090041
# Average loss at step  30000 :  5.90646733797
# Nearest to seven: nine, eight, six, four, zero, five, three, one,
# Nearest to for: in, and, with, of, bckgr, by, on, from,
# Nearest to and: or, in, six, s, for, zero, agouti, abakan,
# Nearest to was: is, were, had, by, has, became, be, are,
# Nearest to history: adhesives, doubt, harmony, envision, lifetime, appomattox, dasyprocta, arcologies,
# Nearest to world: rockies, homme, qualify, circ, type, thucydides, fa, intersection,
# Nearest to united: aristotle, alma, engendered, rosamund, thrace, deism, wodehouse, of,
# Nearest to first: socrates, final, mishnayot, middle, dukes, hardships, victim, bckgr,
# Nearest to may: can, museum, nine, would, roof, or, exploits, cfa,
# Nearest to with: in, by, for, and, after, from, at, as,
# Nearest to two: six, three, four, eight, five, one, zero, agouti,
# Nearest to during: in, of, hijacked, and, greenland, australian, first, appearances,
# Nearest to no: offering, abakan, but, review, or, who, hazards, and,
# Nearest to would: can, spectator, may, but, will, atari, should, chat,
# Nearest to it: he, this, there, still, which, they, we, albuquerque,
# Nearest to were: are, was, is, have, had, by, and, fossils,
# Average loss at step  32000 :  5.98372944283
# Average loss at step  34000 :  5.65049821866
# Average loss at step  36000 :  5.75040236306
# Average loss at step  38000 :  5.53660918391
# Average loss at step  40000 :  5.28560843301
# Nearest to seven: eight, six, zero, four, nine, five, three, two,
# Nearest to for: bckgr, with, in, of, zero, agouti, on, and,
# Nearest to and: or, in, zero, circ, abakan, but, bckgr, operatorname,
# Nearest to was: is, were, had, has, by, became, be, are,
# Nearest to history: adhesives, doubt, harmony, envision, lifetime, publishes, precursor, dasyprocta,
# Nearest to world: rockies, homme, qualify, circ, vdc, fa, type, thucydides,
# Nearest to united: aristotle, alma, engendered, rosamund, albury, thrace, wodehouse, deism,
# Nearest to first: final, socrates, dukes, mishnayot, vdc, middle, victim, during,
# Nearest to may: can, would, will, could, should, museum, vma, roof,
# Nearest to with: in, for, after, from, and, by, within, agouti,
# Nearest to two: three, four, one, six, five, seven, zero, eight,
# Nearest to during: in, on, at, after, greenland, hijacked, australian, first,
# Nearest to no: offering, a, abakan, but, who, four, review, alpina,
# Nearest to would: can, will, may, spectator, should, could, but, did,
# Nearest to it: he, this, there, still, which, they, not, melbourne,
# Nearest to were: are, was, have, is, had, be, by, zero,
# Average loss at step  42000 :  5.3700371424
# Average loss at step  44000 :  5.22002287459
# Average loss at step  46000 :  5.22652382684
# Average loss at step  48000 :  5.23168245423
# Average loss at step  50000 :  4.99647696042
# Nearest to seven: eight, six, five, four, three, nine, zero, one,
# Nearest to for: bckgr, agouti, in, of, with, kapoor, on, and,
# Nearest to and: or, six, kapoor, four, seven, eight, circ, but,
# Nearest to was: is, were, has, had, by, became, are, kapoor,
# Nearest to history: doubt, adhesives, harmony, envision, publishes, lifetime, ark, precursor,
# Nearest to world: rockies, homme, vdc, fa, qualify, circ, dimethyl, type,
# Nearest to united: aristotle, alma, rosamund, engendered, thrace, albury, wodehouse, mee,
# Nearest to first: final, socrates, dukes, middle, mishnayot, last, during, vdc,
# Nearest to may: can, would, will, could, should, to, or, vma,
# Nearest to with: in, after, for, by, and, from, three, agouti,
# Nearest to two: three, four, one, six, five, seven, eight, agouti,
# Nearest to during: in, after, at, on, greenland, perceptual, smokey, of,
# Nearest to no: offering, abakan, a, it, review, or, but, alpina,
# Nearest to would: can, will, may, could, should, spectator, to, must,
# Nearest to it: he, this, there, still, which, they, kapoor, amalthea,
# Nearest to were: are, was, have, had, is, be, by, dasyprocta,
# Average loss at step  52000 :  5.07009686327
# Average loss at step  54000 :  5.17886658478
# Average loss at step  56000 :  5.03657932425
# Average loss at step  58000 :  5.03756935799
# Average loss at step  60000 :  4.92413952327
# Nearest to seven: eight, six, five, nine, four, zero, three, ursus,
# Nearest to for: bckgr, of, with, in, agouti, ursus, kapoor, five,
# Nearest to and: or, ursus, in, pulau, kapoor, but, of, wct,
# Nearest to was: is, were, had, has, by, became, pulau, be,
# Nearest to history: doubt, unrequited, adhesives, harmony, ursus, publishes, envision, pulau,
# Nearest to world: rockies, homme, qualify, ursus, circ, fa, vdc, dimethyl,
# Nearest to united: aristotle, alma, rosamund, engendered, microsite, albury, thrace, cypriot,
# Nearest to first: final, dukes, socrates, last, mishnayot, middle, vdc, during,
# Nearest to may: can, would, will, could, should, must, might, vma,
# Nearest to with: in, after, for, by, including, ursus, between, agouti,
# Nearest to two: three, four, one, six, five, ursus, eight, agouti,
# Nearest to during: in, after, at, perceptual, on, first, greenland, of,
# Nearest to no: offering, michelob, abakan, a, review, truetype, but, or,
# Nearest to would: can, will, may, could, should, must, spectator, to,
# Nearest to it: he, this, there, still, they, which, she, what,
# Nearest to were: are, was, have, had, pulau, is, be, by,
# Average loss at step  62000 :  5.01028048861
# Average loss at step  64000 :  4.84885261863
# Average loss at step  66000 :  4.58046358585
# Average loss at step  68000 :  4.97734062994
# Average loss at step  70000 :  4.91729630423
# Nearest to seven: eight, six, five, nine, four, three, zero, ursus,
# Nearest to for: bckgr, of, dinar, agouti, ursus, with, kapoor, in,
# Nearest to and: or, but, ursus, pulau, kapoor, mico, four, mitral,
# Nearest to was: is, were, has, had, pulau, became, by, cebus,
# Nearest to history: doubt, unrequited, ursus, harmony, publishes, thaler, pulau, uncodified,
# Nearest to world: rockies, homme, qualify, ursus, circ, vdc, fa, cyrillic,
# Nearest to united: alma, aristotle, cypriot, rosamund, microsite, engendered, dinar, mee,
# Nearest to first: final, last, socrates, dukes, mishnayot, during, vdc, fourth,
# Nearest to may: can, would, will, could, should, might, must, to,
# Nearest to with: within, dinar, between, for, after, including, in, by,
# Nearest to two: three, four, six, five, one, eight, seven, ursus,
# Nearest to during: in, after, at, perceptual, irt, first, under, precolonial,
# Nearest to no: offering, michelob, abakan, a, review, truetype, wct, dirham,
# Nearest to would: can, will, may, could, should, must, did, might,
# Nearest to it: he, this, there, they, still, which, she, what,
# Nearest to were: are, was, have, had, pulau, be, fossils, been,
# Average loss at step  72000 :  4.74825098717
# Average loss at step  74000 :  4.81310107017
# Average loss at step  76000 :  4.71950355899
# Average loss at step  78000 :  4.78465412518
# Average loss at step  80000 :  4.80840441316
# Nearest to seven: eight, six, five, four, nine, three, one, zero,
# Nearest to for: bckgr, dinar, ursus, agouti, kapoor, in, of, jug,
# Nearest to and: or, ursus, pulau, but, mitral, kapoor, operatorname, in,
# Nearest to was: is, were, had, has, became, pulau, by, cebus,
# Nearest to history: unrequited, doubt, publishes, harmony, ursus, uncodified, thaler, course,
# Nearest to world: rockies, homme, qualify, ursus, circ, fa, vdc, ossetia,
# Nearest to united: alma, cypriot, aristotle, rosamund, mee, engendered, microsite, imbalances,
# Nearest to first: final, last, during, second, dukes, fourth, socrates, mishnayot,
# Nearest to may: can, would, will, could, should, might, must, to,
# Nearest to with: between, in, within, dinar, including, by, agouti, after,
# Nearest to two: three, four, six, five, one, seven, eight, callithrix,
# Nearest to during: in, after, at, under, iit, irt, first, of,
# Nearest to no: offering, michelob, abakan, review, a, truetype, wct, there,
# Nearest to would: can, will, may, could, should, must, might, cannot,
# Nearest to it: he, this, there, which, still, they, she, microcebus,
# Nearest to were: are, was, have, had, pulau, be, been, liberate,
# Average loss at step  82000 :  4.77216670144
# Average loss at step  84000 :  4.75715760434
# Average loss at step  86000 :  4.76727539599
# Average loss at step  88000 :  4.73794205177
# Average loss at step  90000 :  4.71374247575
# Nearest to seven: eight, five, six, nine, four, three, zero, ursus,
# Nearest to for: dinar, bckgr, ursus, with, kapoor, agouti, in, amalthea,
# Nearest to and: or, but, ursus, while, including, pulau, kapoor, however,
# Nearest to was: is, has, had, were, became, pulau, by, dinar,
# Nearest to history: doubt, publishes, ursus, unrequited, pulau, thaler, harmony, uncodified,
# Nearest to world: rockies, qualify, homme, scalia, ursus, circ, fa, ossetia,
# Nearest to united: alma, cypriot, rosamund, aristotle, mee, microsite, engendered, imbalances,
# Nearest to first: final, last, second, dukes, during, vdc, mishnayot, socrates,
# Nearest to may: can, would, will, could, should, might, must, did,
# Nearest to with: within, in, between, including, for, dinar, agouti, by,
# Nearest to two: three, four, five, six, one, seven, eight, ursus,
# Nearest to during: in, after, under, at, iit, when, irt, first,
# Nearest to no: offering, a, michelob, abakan, truetype, wct, it, there,
# Nearest to would: will, can, may, could, should, must, might, cannot,
# Nearest to it: he, this, there, still, she, which, they, what,
# Nearest to were: are, was, have, had, pulau, be, fossils, been,
# Average loss at step  92000 :  4.6674784137
# Average loss at step  94000 :  4.70366152465
# Average loss at step  96000 :  4.69795062876
# Average loss at step  98000 :  4.5709001888
# Average loss at step  100000 :  4.70186523879
# Nearest to seven: six, eight, five, nine, four, three, zero, ursus,
# Nearest to for: dinar, bckgr, agouti, kapoor, in, ursus, of, with,
# Nearest to and: or, but, ursus, while, pulau, six, mico, kapoor,
# Nearest to was: is, had, has, were, became, pulau, by, dinar,
# Nearest to history: doubt, ursus, publishes, unrequited, pulau, thaler, harmony, circ,
# Nearest to world: rockies, homme, mtsho, qualify, circ, scalia, ursus, vdc,
# Nearest to united: cypriot, alma, stenella, rosamund, aristotle, mee, imbalances, engendered,
# Nearest to first: final, last, second, dukes, during, vdc, next, fourth,
# Nearest to may: can, would, will, could, should, might, must, cannot,
# Nearest to with: in, between, within, dinar, including, for, after, agouti,
# Nearest to two: four, three, five, six, one, seven, eight, ursus,
# Nearest to during: in, after, under, at, iit, when, irt, weakly,
# Nearest to no: offering, abakan, michelob, a, andamanese, wct, or, truetype,
# Nearest to would: will, can, may, could, should, must, might, cannot,
# Nearest to it: he, this, there, she, they, still, which, what,
# Nearest to were: are, have, was, had, pulau, be, is, fossils,

# %%
# Step 6: Visualize the embeddings.


def plot_with_labels(low_dim_embs, labels, filename='tsne.png'):
  assert low_dim_embs.shape[0] >= len(labels), 'More labels than embeddings'
  plt.figure(figsize=(18, 18))  # in inches
  for i, label in enumerate(labels):
    x, y = low_dim_embs[i, :]
    plt.scatter(x, y)
    plt.annotate(label,
                 xy=(x, y),
                 xytext=(5, 2),
                 textcoords='offset points',
                 ha='right',
                 va='bottom')
  plt.savefig(filename)

try:
  # pylint: disable=g-import-not-at-top
  from sklearn.manifold import TSNE
  import matplotlib.pyplot as plt

  tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
  plot_only = 500
  low_dim_embs = tsne.fit_transform(final_embeddings[:plot_only, :])
  labels = [reverse_dictionary[i] for i in xrange(plot_only)]
  plot_with_labels(low_dim_embs, labels)

except ImportError:
  print('Please install sklearn, matplotlib, and scipy to show embeddings.')
