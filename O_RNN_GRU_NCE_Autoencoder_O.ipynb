# %%
from Utils.FS import file
from Utils.tensorflow_helper import show_graph
from nltk.tokenize.punkt import PunktSentenceTokenizer
from nltk.tokenize import word_tokenize
from nltk.corpus import brown
from scipy.sparse import coo_matrix, dok_matrix
from scipy.sparse.linalg import svds
from sklearn.preprocessing import normalize
import matplotlib.pyplot as plt
import numpy as np
from sklearn.manifold import TSNE
from wordcloud import WordCloud
from nltk.corpus import stopwords
import tensorflow as tf
import math
import TextPreprocess.words2dict as words2dict
from tensorflow.python.layers import core as layers_core
from tensorflow.python.client import timeline

# %%
np.random.seed(1234)

# %%
sents = brown.sents()
sents = [[token.lower() for token in sent] for sent in sents]
words = brown.words()
words = [word.lower() for word in words]

# %%
print("Number of tokens: {}".format(len(words)))
print("Number of sentences: {}".format(len(sents)))
print("Longest sentences length: {}".format(max([len(sent) for sent in sents])))
MAX_SENTENCE_LENGTH = max([len(sent) for sent in sents])
# Out:
# Number of tokens: 1161192
# Number of sentences: 57340
# Longest sentences length: 180

# %%
words_dict, inv_words_dict = words2dict.convert(words)
print(words_dict['five'])
print(inv_words_dict[334])

words_size = len(words_dict)
print("Number of unique tokens: {}".format(words_size))
# Out:
# 334
# five
# Number of unique tokens: 49815

# %%
VOCABULAY_SIZE = len(words_dict)
GO_SYMBOL = VOCABULAY_SIZE - 1
PADDING_SYMBOL = VOCABULAY_SIZE - 2
UNK_SYMBOL = VOCABULAY_SIZE - 3

# %%
def batchPadding(batch, padding_symbol=PADDING_SYMBOL):
    size = max([len(record) for record in batch])
    result = np.full((len(batch), size), padding_symbol)
    for i in range(len(batch)):
        result[i][:len(batch[i])] = batch[i]
    return result

def batchMask(batch):
    size = max([len(record) for record in batch])
    result = np.full((len(batch), size), 0.0)
    for i in range(len(batch)):
        result[i][:len(batch[i])] = 1.0
    return result

# %%
"""
def dataGenerator(sents, words_dict, window_size = 2, batch_size=32, train_length=2, epouch=-1, padding_symbol=PADDING_SYMBOL):
    train = []
    label = []
    length = []
    while(epouch < 0 or epouch > 0):
        left_window = [padding_symbol for i in range(window_size)]
        target = [padding_symbol for i in range(train_length)]
        right_window = [padding_symbol for i in range(window_size)]
        for sent in sents:
            for word in sent:
                right_window.append(words_dict[word])
                target.append(right_window.pop(0))
                left_window.append(target.pop(0))
                left_window.pop(0)
                
                for context in left_window + right_window:
                    train.append(list(target))
                    label.append(list([context]))
                    length.append(len(target))
                    if(len(train) == batch_size):
                        yield train, label, length
                        train = []
                        label = []
                        length = []
        epouch -= 1
        print('epouch done...')
"""
# Out:
# "\ndef dataGenerator(sents, words_dict, window_size = 2, batch_size=32, train_length=2, epouch=-1, padding_symbol=PADDING_SYMBOL):\n    train = []\n    label = []\n    length = []\n    while(epouch < 0 or epouch > 0):\n        left_window = [padding_symbol for i in range(window_size)]\n        target = [padding_symbol for i in range(train_length)]\n        right_window = [padding_symbol for i in range(window_size)]\n        for sent in sents:\n            for word in sent:\n                right_window.append(words_dict[word])\n                target.append(right_window.pop(0))\n                left_window.append(target.pop(0))\n                left_window.pop(0)\n                \n                for context in left_window + right_window:\n                    train.append(list(target))\n                    label.append(list([context]))\n                    length.append(len(target))\n                    if(len(train) == batch_size):\n                        yield train, label, length\n                        train = []\n                        label = []\n                        length = []\n        epouch -= 1\n        print('epouch done...')\n"

# %%
def sentenceGenerator(sents, words_dict, batch_size=32, epouch=-1, padding_symbol=PADDING_SYMBOL):
    train = []
    length = []
    while(epouch < 0 or epouch > 0):
        for sent in sents:
            train.append([words_dict[word] for word in sent])
            length.append(len(sent))
            if(len(train) == batch_size):
                yield batchPadding(train), length, batchMask(train)
                train = []
                length = []
        epouch -= 1
        print('epouch done...')

# %%
#TRAIN_LENGTH = 4
#WINDOW_SIZE = 2
BATCH_SIZE = 1

# %%
#generator = dataGenerator(sents, words_dict, window_size = WINDOW_SIZE, batch_size=BATCH_SIZE, train_length=TRAIN_LENGTH, epouch=1)
#bigram_list = []
#for batch_inputs, _, _ in generator:
#    bigram_list += ['_'.join([inv_words_dict[idx] for idx in batch_input]) for batch_input in batch_inputs]
        
#bigrams_dict, inv_bigrams_dict = words2dict.convert(bigram_list)
#generator = sentenceGenerator(sents, words_dict)
#batch, lengths, mask = next(generator)
#print(batch[0])
#print(lengths)
#print(mask[0])

# %%
"""
def visualizeData(generator):
    train, label, length = next(generator)
    for i in range(len(train)):
        print([inv_words_dict[word] for word in train[i]], [inv_words_dict[word] for word in label[i]], length[i])

generator = dataGenerator(sents[:1], words_dict, window_size = 1, batch_size=64, train_length=2)
#print(sents[0])
#visualizeData(generator)
"""
# Out:
# '\ndef visualizeData(generator):\n    train, label, length = next(generator)\n    for i in range(len(train)):\n        print([inv_words_dict[word] for word in train[i]], [inv_words_dict[word] for word in label[i]], length[i])\n\ngenerator = dataGenerator(sents[:1], words_dict, window_size = 1, batch_size=64, train_length=2)\n#print(sents[0])\n#visualizeData(generator)\n'

# %%
#generator = dataGenerator(sents, words_dict, window_size = WINDOW_SIZE, batch_size=BATCH_SIZE, train_length=TRAIN_LENGTH)
generator = sentenceGenerator(sents, words_dict, batch_size=BATCH_SIZE)

# %%
ENCODER_DIMENSION = [50, 50, 100]
ENCODER_LAYERS = len(ENCODER_DIMENSION)

RNN_DIMENSION = [100, 50, 50]
RNN_LAYERS = len(RNN_DIMENSION)

DIMENSION = 50
NEGATIVE_SAMPLE = 64
MODE = 'train'

# %%
graph = tf.Graph()

with graph.as_default():
    
        #IN
        inputs = tf.placeholder(tf.int32, (None, None), name = "Input_Sentence_Word_Index")
        #OUT: (batch, time) int32
        
        batch_size = tf.shape(inputs)[0]
        steps = tf.shape(inputs)[1]
        
        #IN
        input_lengths = tf.placeholder(tf.int32, (None), name = "Input_Sentence_Length")
        #OUT: (batch) int32
                
        batch_size = tf.shape(inputs)[0]
        steps = tf.shape(inputs)[1]
        
        encoder_inputs = inputs
        #OUT: (batch, time) int32
        
        #decoder_inputs = tf.pad(tf.slice(encoder_inputs, [0,1], [batch_size, steps-1]), [[1, 0], [0, 0]])
        decoder_inputs = tf.pad(
            tf.slice(encoder_inputs, [0,0], [batch_size, steps-1]) - GO_SYMBOL, 
            [[0, 0], [1, 0]]
        ) + GO_SYMBOL
        #OUT: (batch, time) int32
        
        decoder_input_lengths = tf.reshape(input_lengths, [batch_size])
        #OUT: (batch) int32

        # assume same input length
        decoder_masks = tf.placeholder(tf.float32, (None, None), name = "Input_Sentence_Mask")
        #OUT: (batch, time)
        
        #labels = tf.placeholder(tf.int32, (None, 1), name = "Context_Word_Index")
        #OUT: (batch, 1) int32
        

        embeddings = tf.Variable(tf.random_uniform([VOCABULAY_SIZE, DIMENSION], -1.0, 1.0), trainable=False, name="Word2Vec")
        
        #IN: (batch, time) int32
        inputs_embed = tf.nn.embedding_lookup(embeddings, inputs, max_norm=1)
        #OUT: (batch, time, dim) float32
        decoder_embed = tf.nn.embedding_lookup(embeddings, decoder_inputs, max_norm=1)

        """
        #IN: (batch, time, dim) 
        #weights = [tf.Variable(tf.random_uniform([DIMENSION * 2, DIMENSION], minval=-1, maxval=1)) for i in range(RNN_LAYERS)]
        #bias = [tf.Variable(tf.random_uniform([DIMENSION], minval=-1, maxval=1)) for i in range(RNN_LAYERS)]
        
        #nn_input = tf.reshape(inputs_embed, (batch_size, DIMENSION))
        #nn_output = tf.ones((batch_size, DIMENSION))
        #for i in range(RNN_LAYERS):
        #    nn_output = tf.concat([nn_output, nn_input], 1)
        #    nn_output = tf.tanh(tf.matmul(nn_output, weights[i]) + bias[i])
        #out: (batch, DIMENSION)

        #IN: (batch, time, dim) float32
        #rnn_inputs = tf.transpose(inputs_embed, [1, 0, 2])
        #rnn_inputs = inputs_embed
        #OUT: (batch, time, dim) float32
        
        #cell = tf.contrib.rnn.LSTMCell(DIMENSION)
        cell = tf.contrib.rnn.GRUCell(DIMENSION)
        
        outputs, states = tf.contrib.legacy_seq2seq.embedding_rnn_seq2seq(
            encoder_inputs = encoder_inputs,
            decoder_inputs = decoder_inputs,
            cell=cell,
            num_encoder_symbols = VOCABULAY_SIZE,
            num_decoder_symbols = VOCABULAY_SIZE,
            embedding_size = DIMENSION,
            output_projection=(
                tf.Variable(tf.random_iniform([DIMENSION, VOCABULAY_SIZE], minval=-0.1 , maxval=0.1)),
                tf.Variable(tf.random_iniform([VOCABULAY_SIZE], minval=-0.1 , maxval=0.1))
            ),
            feed_previous=False,
        )
        
        loss = tf.contrib.legacy_seq2seq.sequence_loss(
            logits=outputs,
            targets=labels,
            weights,
            average_across_timesteps=True,
            average_across_batch=True,
            softmax_loss_function=None,
            name=None
        )
        """
        # OUT: [time [batch_size, DIMENSION]]
        
        
        ###### IN: (batch, time, DIMENSION) float32 ######
        
        with tf.variable_scope("Encoder") as encoder_scope:

            #cell = tf.contrib.rnn.LSTMCell(RNN_DIMENSION[-1])
            #cell = tf.contrib.rnn.GRUCell(ENCODER_DIMENSION) 
            cells = [tf.contrib.rnn.GRUCell(ENCODER_DIMENSION[i]) for i in range(ENCODER_LAYERS)]
            stack = tf.contrib.rnn.MultiRNNCell(cells)

            #rnn_tuple_state = tuple([tf.nn.rnn_cell.LSTMStateTuple(l[i][0], l[i][1]) for i in range(RNN_LAYERS)])

            #cell = tf.contrib.rnn.LSTMCell(DIMENSION, state_is_tuple=True)        
            #cell = tf.contrib.rnn.GRUCell(DIMENSION)
            #initial_state = cell.zero_state(batch_size, tf.float32)

            rnn_outputs, rnn_states = tf.nn.dynamic_rnn(stack, inputs_embed, dtype=tf.float32, sequence_length=input_lengths)
            
            #IN: (batch, time, RNN_DIMENSION[-1]) float32
            index = tf.range(0, batch_size) * tf.shape(inputs)[1] + (input_lengths - 1)
            rnn_final_state = tf.gather(tf.reshape(rnn_outputs, [-1, ENCODER_DIMENSION[-1]]), index)
            rnn_final_state = tf.reshape( rnn_final_state, [-1, ENCODER_DIMENSION[-1]])
            #rnn_final_state = tf.clip_by_norm(rnn_final_state, 1, axes=[1])
            ###rnn_final_state = tf.gather(tf.reshape(rnn_outputs, [-1, DIMENSION]), index)
            #OUT: (batch, RNN_DIMENSION[-1])
            print(rnn_outputs)
            print(rnn_final_state)
                    
        ###### OUT: (batch, time, RNN_DIMENSION[-1]) float32 ######
        
        
        ###### IN: (batch, time, RNN_DIMENSION[-1]) float32 ######
        
        with tf.variable_scope("Decoder") as decoder_scope:
            #cell = tf.contrib.rnn.LSTMCell(RNN_DIMENSION[-1])
            cells = [tf.contrib.rnn.GRUCell(RNN_DIMENSION[i]) for i in range(RNN_LAYERS)]
            stack = tf.contrib.rnn.MultiRNNCell(cells)
            
            if MODE == "train":
                helper = tf.contrib.seq2seq.TrainingHelper(
                    inputs=decoder_embed,
                    sequence_length=decoder_input_lengths)
                
            elif MODE == "infer":
                helper = tf.contrib.seq2seq.GreedyEmbeddingHelper(
                    embedding=embedding,
                    start_tokens=tf.tile([GO_SYMBOL], [batch_size]),
                    end_token=END_SYMBOL)
                
            decoder = tf.contrib.seq2seq.BasicDecoder(
                cell=stack,
                helper=helper,
                initial_state=(rnn_final_state, cells[-2].zero_state(batch_size, tf.float32), cells[-1].zero_state(batch_size, tf.float32)),
                #output_layer=layers_core.Dense(VOCABULAY_SIZE, use_bias=True, activation=None))
                output_layer=None)
            #sequence_loss has softmax already

            decoder_outputs, _ = tf.contrib.seq2seq.dynamic_decode(
                decoder=decoder,
                output_time_major=False,
                impute_finished=False,
                maximum_iterations=None,
                parallel_iterations=32,
                swap_memory=False,
                scope=None
            )
            
            nce_weights = tf.Variable(
            tf.truncated_normal([VOCABULAY_SIZE, RNN_DIMENSION[-1]],
                                stddev=1.0 / math.sqrt(RNN_DIMENSION[-1])), trainable=False)

            nce_biases = tf.Variable(tf.zeros([VOCABULAY_SIZE]), trainable=False)
        
            def nce_loss(labels, inputs):
                return tf.nn.nce_loss(
                    weights=nce_weights,
                    biases=nce_biases,
                    labels=tf.reshape(labels, [-1, 1]),
                    inputs=inputs,
                    num_sampled=NEGATIVE_SAMPLE,
                    num_classes=VOCABULAY_SIZE)
        
            seq_loss = tf.contrib.seq2seq.sequence_loss(
                logits=decoder_outputs.rnn_output,
                targets=inputs,
                weights=decoder_masks,
                average_across_timesteps=False,
                average_across_batch=False,
                softmax_loss_function=nce_loss,
                name=None
            )
            
            loss = tf.reduce_max(seq_loss)
            
            
            project_input = tf.placeholder(tf.float32, (None, DIMENSION), name = "Project_Inputs")
            project = tf.nn.softmax(project_input @ tf.transpose(nce_weights) + nce_biases)
            

            """
            helper = tf.contrib.seq2seq.TrainingHelper(decoder_inputs, decoder_input_lengths)
            decoder = tf.contrib.seq2seq.BasicDecoder(cell, helper, rnn_final_state)
        
            decoder_outputs, decoder_states = tf.contrib.seq2seq.dynamic_decode(decoder=decoder)
            print(decoder_outputs)
            #rnn_outputs, rnn_states = tf.nn.dynamic_rnn(cell, inputs_embed, initial_state=rnn_final_state, sequence_length=input_lengths)
            
            #weights: A 2D Tensor of shape [batch_size x sequence_length] and dtype float. Weights constitutes the weighting of each prediction in the sequence. When using weights as masking set all valid timesteps to 1 and all padded timesteps to 0.
            loss = tf.reduce_mean(tf.contrib.seq2seq.sequence_loss(
                logits=decoder_outputs,
                targets=labels,
                weights=decoder_masks,
                average_across_timesteps=True,
                average_across_batch=True,
                softmax_loss_function=None,
                name=None
            ))
            """

        #optimizer = tf.train.GradientDescentOptimizer(1.0).minimize(loss)
        #optimizer = tf.train.MomentumOptimizer(1.0, 0.5).minimize(loss)
        optimizer = tf.train.AdamOptimizer().minimize(loss)
        
        init = tf.global_variables_initializer()
        saver = tf.train.Saver()
        #embeddings_saver = tf.train.Saver({'Words2Vec': embeddings})
        word2VecSaver = tf.train.Saver({'Words2Vec': embeddings, 'NCE_Weights': nce_weights, 'NCE_Biases': nce_biases})
        #context = tf.nn.softmax(tf.matmul(rnn_final_state, tf.transpose(nce_weights)) + nce_biases)
# Out:
# Tensor("Encoder/rnn/transpose:0", shape=(?, ?, 100), dtype=float32)
# Tensor("Encoder/Reshape_1:0", shape=(?, 100), dtype=float32)
# /home/hoiy927/project/tf_playground/tf_playground/lib/python3.5/site-packages/tensorflow/python/ops/gradients_impl.py:93: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "

# %%
show_graph(graph.as_graph_def())
# Out:
#         <iframe seamless style="width:1200px;height:620px;border:0" srcdoc="
#         <script>
#           function load() {
#             document.getElementById(&quot;graph0.1915194503788923&quot;).pbtxt = 'node {\n  name: &quot;Input_Sentence_Word_Index&quot;\n  op: &quot;Placeholder&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_INT32\n    }\n  }\n  attr {\n    key: &quot;shape&quot;\n    value {\n      shape {\n      }\n    }\n  }\n}\nnode {\n  name: &quot;Shape&quot;\n  op: &quot;Shape&quot;\n  input: &quot;Input_Sentence_Word_Index&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_INT32\n    }\n  }\n  attr {\n    key: &quot;out_type&quot;\n    value {\n      type: DT_INT32\n    }\n  }\n}\nnode {\n  name: &quot;strided_slice/stack&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_INT32\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_INT32\n        tensor_shape {\n          dim {\n            size: 1\n          }\n        }\n        int_val: 0\n      }\n    }\n  }\n}\nnode {\n  name: &quot;strided_slice/stack_1&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_INT32\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_INT32\n        tensor_shape {\n          dim {\n            size: 1\n          }\n        }\n        int_val: 1\n      }\n    }\n  }\n}\nnode {\n  name: &quot;strided_slice/stack_2&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_INT32\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_INT32\n        tensor_shape {\n          dim {\n            size: 1\n          }\n        }\n        int_val: 1\n      }\n    }\n  }\n}\nnode {\n  name: &quot;strided_slice&quot;\n  op: &quot;StridedSlice&quot;\n  input: &quot;Shape&quot;\n  input: &quot;strided_slice/stack&quot;\n  input: &quot;strided_slice/stack_1&quot;\n  input: &quot;strided_slice/stack_2&quot;\n  attr {\n    key: &quot;Index&quot;\n    value {\n      type: DT_INT32\n    }\n  }\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_INT32\n    }\n  }\n  attr {\n    key: &quot;begin_mask&quot;\n    value {\n      i: 0\n    }\n  }\n  attr {\n    key: &quot;ellipsis_mask&quot;\n    value {\n      i: 0\n    }\n  }\n  attr {\n    key: &quot;end_mask&quot;\n    value {\n      i: 0\n    }\n  }\n  attr {\n    key: &quot;new_axis_mask&quot;\n    value {\n      i: 0\n    }\n  }\n  attr {\n    key: &quot;shrink_axis_mask&quot;\n    value {\n      i: 1\n    }\n  }\n}\nnode {\n  name: &quot;Shape_1&quot;\n  op: &quot;Shape&quot;\n  input: &quot;Input_Sentence_Word_Index&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_INT32\n    }\n  }\n  attr {\n    key: &quot;out_type&quot;\n    value {\n      type: DT_INT32\n    }\n  }\n}\nnode {\n  name: &quot;strided_slice_1/stack&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_INT32\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_INT32\n        tensor_shape {\n          dim {\n            size: 1\n          }\n        }\n        int_val: 1\n      }\n    }\n  }\n}\nnode {\n  name: &quot;strided_slice_1/stack_1&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_INT32\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_INT32\n        tensor_shape {\n          dim {\n            size: 1\n          }\n        }\n        int_val: 2\n      }\n    }\n  }\n}\nnode {\n  name: &quot;strided_slice_1/stack_2&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_INT32\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_INT32\n        tensor_shape {\n          dim {\n            size: 1\n          }\n        }\n        int_val: 1\n      } ...

# %%
num_steps = 200000
MODEL = './model/seq2seq-autoencoder.ckpt'
WORDS2VEC_MODEL = './model/brown-Words2Vec-{}.ckpt'.format(DIMENSION)

# %%
def cloestWord(vec, words_vec, count=10, method='cos'):
    if method == 'cos':
        dist = np.array([ sum(vec * words_vec[key]) for key in words_vec.keys()])
        top_ten = dist.argsort()[::-1][:10]
    else:
        dist = np.array([ sum(np.square(np.array(vec) - np.array(words_vec[key]))) for key in words_vec.keys()])
        top_ten = dist.argsort()[:10]
    return [list(words_vec.keys())[i] for i in top_ten]

def cloestWord2(word, emb, count=10, method='cos'):
    return cloestWord3(emb[words_dict[word]], emb, count, method)

def cloestWord3(vec, emb, count=10, method='cos'):
    if method == 'cos':
        dist = np.array([ sum(vec * emb[i]) for i in range(emb.shape[0])])
        # dist: word index -> dist
        
        top = dist.argsort()[::-1][:count]
        # top: ranking -> word index
        
    return [(inv_words_dict[i], "%.2f" % dist[i])  for i in top]

def to_word_indices(words):
    return [words_dict[word] for word in words]

# %%
DEBUG_SIZE = 1000

with tf.Session(graph=graph) as session:
    init.run()
    word2VecSaver.restore(session, WORDS2VEC_MODEL)
    #saver.restore(session, MODEL)
    
    run_options = tf.RunOptions(trace_level=tf.RunOptions.FULL_TRACE)
    run_metadata = tf.RunMetadata()

      
    average_loss = 0
    for step in range(num_steps):
        batch_inputs, batch_input_lengths, batch_masks = next(generator)
        feed_dict = {inputs: batch_inputs, input_lengths: batch_input_lengths, decoder_masks: batch_masks}

        #_, loss_val = session.run([optimizer, loss], feed_dict=feed_dict, options=run_options, run_metadata=run_metadata)
        _, loss_val = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += loss_val
        

        if step % DEBUG_SIZE == 0:
            if step > 0:
                average_loss /= DEBUG_SIZE
                print('Average loss at step ', step, ': ', average_loss)
                average_loss = 0
                
                feed_dict = {inputs: [
                    to_word_indices(['once', 'upon', 'a', 'time']), 
                    to_word_indices(['this', 'cat', 'is', 'cute'])
                ], input_lengths:[4, 4], decoder_masks: [[1, 1, 1, 1], [1,1,1,1]]}

                a, b, c = session.run([decoder_outputs.rnn_output, seq_loss, loss], feed_dict)
                print('encoder_input: ', [inv_words_dict[out] for out in feed_dict[inputs][0]])
                print('decoder_output: ', [inv_words_dict[word.argmax()] for word in project.eval({
                    project_input: a[0]
                })])
                print('encoder_input: ', [inv_words_dict[out] for out in feed_dict[inputs][1]])
                print('decoder_output: ', [inv_words_dict[word.argmax()] for word in project.eval({
                    project_input: a[1]
                })])
                print(b)
                print(c)

                
        if step % DEBUG_SIZE == 0:
            save_path = saver.save(session, MODEL)
            print("Model saved in file: %s" % save_path)
            
            # Create the Timeline object, and write it to a json
            tl = timeline.Timeline(run_metadata.step_stats)
            ctf = tl.generate_chrome_trace_format()
            with open('timeline.json', 'w') as f:
                f.write(ctf)
# Out:
# INFO:tensorflow:Restoring parameters from ./model/brown-Words2Vec-50.ckpt
# Model saved in file: ./model/seq2seq-autoencoder.ckpt
# Average loss at step  1000 :  6.3488354125
# encoder_input:  ['once', 'upon', 'a', 'time']
# decoder_output:  [',', 'the', 'the', 'the']
# encoder_input:  ['this', 'cat', 'is', 'cute']
# decoder_output:  [',', 'the', 'the', 'the']
# [[ 5.27328777  6.43218088  4.96463203  5.54037237]
#  [ 5.28700018  5.12587404  5.269238    4.8261199 ]]
# 6.43218
# Model saved in file: ./model/seq2seq-autoencoder.ckpt
# Average loss at step  2000 :  6.23649755812
# encoder_input:  ['once', 'upon', 'a', 'time']
# decoder_output:  ['the', 'the', 'the', 'the']
# encoder_input:  ['this', 'cat', 'is', 'cute']
# decoder_output:  ['the', 'the', 'the', 'the']
# [[ 4.95577621  6.35347414  4.6366744   5.49743986]
#  [ 4.9020834   5.36163664  5.67190266  5.07391739]]
# 6.35347
# Model saved in file: ./model/seq2seq-autoencoder.ckpt
# Average loss at step  3000 :  6.14451270485
# encoder_input:  ['once', 'upon', 'a', 'time']
# decoder_output:  ['the', 'the', 'the', 'the']
# encoder_input:  ['this', 'cat', 'is', 'cute']
# decoder_output:  ['the', 'the', 'the', 'the']
# [[ 4.68304682  6.23712301  4.58375835  4.70264673]
#  [ 4.89379644  5.373034    5.70327187  5.40798473]]
# 6.23712
# Model saved in file: ./model/seq2seq-autoencoder.ckpt
# Average loss at step  4000 :  6.18982856369
# encoder_input:  ['once', 'upon', 'a', 'time']
# decoder_output:  ['the', 'the', 'the', 'the']
# encoder_input:  ['this', 'cat', 'is', 'cute']
# decoder_output:  ['the', 'the', 'the', 'the']
# [[ 4.4034214   5.79456329  4.58223534  4.42647457]
#  [ 4.57254219  5.18961191  5.09429312  5.5349369 ]]
# 5.79456
# Model saved in file: ./model/seq2seq-autoencoder.ckpt
# Average loss at step  5000 :  6.18191438627
# encoder_input:  ['once', 'upon', 'a', 'time']
# decoder_output:  ['the', 'the', 'the', 'the']
# encoder_input:  ['this', 'cat', 'is', 'cute']
# decoder_output:  ['the', 'the', 'the', 'the']
# [[ 4.31611156  5.68704653  4.539639    3.93014216]
#  [ 4.99523258  4.95700264  5.67992973  4.9885726 ]]
# 5.68705
# Model saved in file: ./model/seq2seq-autoencoder.ckpt
# Average loss at step  6000 :  6.17323127937
# encoder_input:  ['once', 'upon', 'a', 'time']
# decoder_output:  ['the', 'the', 'the', 'years']
# encoder_input:  ['this', 'cat', 'is', 'cute']
# decoder_output:  ['the', 'the', 'the', 'the']
# [[ 4.23606968  5.56797314  4.52947283  3.90811253]
#  [ 4.65435266  5.09909153  5.48550797  5.77218771]]
# 5.77219
# Model saved in file: ./model/seq2seq-autoencoder.ckpt
# Average loss at step  7000 :  6.09061187649
# encoder_input:  ['once', 'upon', 'a', 'time']
# decoder_output:  ['the', 'the', 'the', 'the']
# encoder_input:  ['this', 'cat', 'is', 'cute']
# decoder_output:  ['the', 'the', 'the', 'the']
# [[ 4.36937571  5.26894283  4.14747477  4.52824116]
#  [ 4.81195831  4.91300392  5.74303579  5.05050898]]
# 5.74304
# Model saved in file: ./model/seq2seq-autoencoder.ckpt
# Average loss at step  8000 :  6.05249608731
# encoder_input:  ['once', 'upon', 'a', 'time']
# decoder_output:  ['the', 'the', 'the', ',']
# encoder_input:  ['this', 'cat', 'is', 'cute']
# decoder_output:  ['the', 'the', '.', 'the']
# [[ 4.41526842  5.64893436  4.62740088  4.3227706 ]
#  [ 5.16797781  4.90497971  5.69086266  5.16570187]]
# 5.69086
# Model saved in file: ./model/seq2seq-autoencoder.ckpt
# Average loss at step  9000 :  6.02454368258
# encoder_input:  ['once', 'upon', 'a', 'time']
# decoder_output:  ['the', 'the', 'the', ',']
# encoder_input:  ['this', 'cat', 'is', 'cute']
# decoder_output:  ['the', 'the', ',', 'the']
# [[ 4.73502588  5.88457727  4.59213305  4.55845213]
#  [ 5.70264816  4.87059355  5.44209433  5.28600931]]
# 5.88458
# Model saved in file: ./model/seq2seq-autoencoder.ckpt
# Average loss at step  10000 :  5.96694236398
# encoder_input:  ['once', 'upon', 'a', 'time']
# decoder_output:  ['the', 'the', 'the', ',']
# encoder_input:  ['this', 'cat', 'is', 'cute']
# decoder_output:  ['the', 'was', 'was', '.']
# [[ 4.10533619  5.9635191   4.50743103  3.70730519]
#  [ 4.6294713   4.85335255  4.6997757   5.14196777]]
# 5.96352
# Model saved in file: ./model/seq2seq-autoencoder.ckpt
# Average loss at step  11000 :  5.96770529723
# encoder_input:  ['once', 'upon', 'a', 'time']
# decoder_output:  ['the', 'the', 'the', ',']
# encoder_input:  ['this', 'cat', 'is', 'cute']
# decoder_output:  ['the', 'the', 'was', 'the']
# [[ 4.16180515  5.51117897  4.33140182  4.20558405]
#  [ 4.63914537  4.78083277  4.94145489  5.15469646]]
# 5.51118
# Model saved in file: ./model/seq2seq-autoencoder.ckpt
# Average loss at step  12000 :  5.90187227416
# encoder_input:  ['once', 'upon', 'a', 'time']
# decoder_output:  ['the', 'the', 'the', 'head']
# encoder_input:  ['this', 'cat', 'is', 'cute']
# decoder_output:  ['the', 'one', 'was', '.']
# [[ 4.02954292  5.51411629  4.65887117  5.17991972]
#  [ 4.55303907  4.81753635  5.51918697  5.37237644]]
# 5.51919
# Model saved in file: ./model/seq2seq-autoencoder.ckpt
# Average loss at step  13000 :  5.91656288671
# encoder_input:  ['once', 'upon', 'a', 'time']
# decoder_output:  ['the', 'the', 'the', ',']
# encoder_input:  ['this', 'cat', 'is', 'cute']
# decoder_output:  ['the', 'to', 'was', 'the']
# [[ 3.97481489  5.60331202  4.29799175  4.76248884]
#  [ 4.8953805   4.82666111  5.56495714  5.07006741]]
# 5.60331
# Model saved in file: ./model/seq2seq-autoencoder.ckpt
# Average loss at step  14000 :  5.95149051988
# encoder_input:  ['once', 'upon', 'a', 'time']
# decoder_output:  ['the', 'the', 'the', ',']
# encoder_input:  ['this', 'cat', 'is', 'cute']
# decoder_output:  ['the', 'one', 'was', '.']
# [[ 3.93981242  5.76052332  4.47562647  4.48296022]
#  [ 4.58533049  4.77932501  4.73735666  5.4958415 ]]
# 5.76052
# Model saved in file: ./model/seq2seq-autoencoder.ckpt
# Average loss at step  15000 :  5.93722504187
# encoder_input:  ['once', 'upon', 'a', 'time']
# decoder_output:  ['the', 'the', 'the', ',']
# encoder_input:  ['this', 'cat', 'is', 'cute']
# decoder_output:  ['the', 'you', 'the', 'the']
# [[ 3.96104598  5.50679541  4.32857323  5.08944559]
#  [ 4.72027349  4.73421764  5.10036421  5.32544756]]
# 5.5068
# Model saved in file: ./model/seq2seq-autoencoder.ckpt
# Average loss at step  16000 :  6.00478310406
# encoder_input:  ['once', 'upon', 'a', 'time']
# decoder_output:  ['the', 'the', 'the', ',']
# encoder_input:  ['this', 'cat', 'is', 'cute']
# decoder_output:  ['the', 'one', 'the', '.']
# [[ 4.12985945  5.65331364  4.42530346  4.81488037]
#  [ 5.01113272  4.79064465  5.23344326  5.05285549]]
# 5.65331
# Model saved in file: ./model/seq2seq-autoencoder.ckpt
# Average loss at step  17000 :  5.98053646898
# encoder_input:  ['once', 'upon', 'a', 'time']
# decoder_output:  ['the', 'the', 'the', ',']
# encoder_input:  ['this', 'cat', 'is', 'cute']
# decoder_output:  ['the', 'was', 'the', 'the']
# [[ 4.10585165  5.53046799  4.30845165  5.56641769]
#  [ 4.78031206  4.77835751  5.94985771  4.87089443]]
# 5.94986
# Model saved in file: ./model/seq2seq-autoencoder.ckpt
# Average loss at step  18000 :  5.89662897253
# encoder_input:  ['once', 'upon', 'a', 'time']
# decoder_output:  ['the', 'was', 'the', ',']
# encoder_input:  ['this', 'cat', 'is', 'cute']
# decoder_output:  ['he', 'was', '.', '.']
# [[ 3.9583497   5.79437065  4.13771009  5.40895605]
#  [ 4.99683809  5.21261644  5.15978241  5.78144979]]
# 5.79437
# Model saved in file: ./model/seq2seq-autoencoder.ckpt
# Average loss at step  19000 :  5.88700480866
# encoder_input:  ['once', 'upon', 'a', 'time']
# decoder_output:  ['the', 'the', 'the', ',']
# encoder_input:  ['this', 'cat', 'is', 'cute']
# decoder_output:  ['he', 'was', 'was', '.']
# [[ 4.12443209  5.88365316  4.0969162   5.09277058]
#  [ 5.22248173  5.00326109  5.73366737  5.25257158]]
# 5.88365
# Model saved in file: ./model/seq2seq-autoencoder.ckpt
# Average loss at step  20000 :  5.98228296363
# encoder_input:  ['once', 'upon', 'a', 'time']
# decoder_output:  ['the', 'the', 'the', ',']
# encoder_input:  ['this', 'cat', 'is', 'cute']
# decoder_output:  ['the', '.', '.', '.']
# [[ 4.50193596  5.81007862  4.39992714  5.17881489]
#  [ 4.78750944  5.34420395  5.27820158  5.52578735]]
# 5.81008
# Model saved in file: ./model/seq2seq-autoencoder.ckpt
# epouch done...
# Average loss at step  21000 :  6.09144214571
# encoder_input:  ['once', 'upon', 'a', 'time']
# decoder_output:  ['the', 'the', 'the', ',']
# encoder_input:  ['this', 'cat', 'is', 'cute']
# decoder_output:  ['the', 'was', '.', '.']
# [[ 4.28975344  6.01644087  4.54054737  4.30833244]
#  [ 5.05763531  5.04409933  5.0452323   5.08602381]]
# 6.01644
# Model saved in file: ./model/seq2seq-autoencoder.ckpt
# Average loss at step  22000 :  6.18658280849
# encoder_input:  ['once', 'upon', 'a', 'time']
# decoder_output:  ['the', 'the', 'the', ',']
# encoder_input:  ['this', 'cat', 'is', 'cute']
# decoder_output:  ['the', 'was', 'was', '.']
# [[ 4.67900181  6.18026066  4.34946632  5.37142801]
#  [ 5.22163486  4.98807287  5.51658487  5.0413022 ]]
# 6.18026
# Model saved in file: ./model/seq2seq-autoencoder.ckpt
# Average loss at step  23000 :  6.17864224005
# encoder_input:  ['once', 'upon', 'a', 'time']
# decoder_output:  ['the', 'the', 'the', ',']
# encoder_input:  ['this', 'cat', 'is', 'cute']
# decoder_output:  ['the', ',', ',', '.']
# [[ 4.38959885  5.86137486  4.36247015  5.52192879]
#  [ 4.92692852  4.96035147  5.55693865  5.3125329 ]]
# 5.86137
# Model saved in file: ./model/seq2seq-autoencoder.ckpt
# Average loss at step  24000 :  6.19852427948
# encoder_input:  ['once', 'upon', 'a', 'time']
# decoder_output:  ['the', 'the', 'the', ',']
# encoder_input:  ['this', 'cat', 'is', 'cute']
# decoder_output:  ['the', 'have', 'have', '.']
# [[ 4.27865028  5.96119928  4.63078213  4.92341042]
#  [ 4.56753254  5.02442837  5.61818886  5.07211828]]
# 5.9612
# Model saved in file: ./model/seq2seq-autoencoder.ckpt
# Average loss at step  25000 :  6.2049617784
# encoder_input:  ['once', 'upon', 'a', 'time']
# decoder_output:  ['the', 'the', 'the', 'new']
# encoder_input:  ['this', 'cat', 'is', 'cute']
# decoder_output:  ['the', 'was', 'have', 'a']
# [[ 4.48211861  5.95706606  4.38121462  4.77652311]
#  [ 4.92933369  5.066957    5.06341648  5.04796267]]
# 5.95707
# Model saved in file: ./model/seq2seq-autoencoder.ckpt
# Average loss at step  26000 :  6.13647701502
# encoder_input:  ['once', 'upon', 'a', 'time']
# decoder_output:  ['the', 'the', 'the', 'new']
# encoder_input:  ['this', 'cat', 'is', 'cute']
# decoder_output:  ['the', ',', 'the', 'the']
# [[ 4.53981161  5.78700781  4.58339214  5.4098711 ]
#  [ 5.06998444  5.02541971  4.85340977  4.8582263 ]]
# 5.78701
# Model saved in file: ./model/seq2seq-autoencoder.ckpt
# Average loss at step  27000 :  6.03990542704
# encoder_input:  ['once', 'upon', 'a', 'time']
# decoder_output:  ['the', '.', 'the', '.']
# encoder_input:  ['this', 'cat', 'is', 'cute']
# decoder_output:  ['he', 'was', 'the', '.']
# [[ 4.35745478  6.23214722  3.90906143  5.23359203]
#  [ 5.30238199  5.06462097  4.76996803  5.08469868]]
# 6.23215
# Model saved in file: ./model/seq2seq-autoencoder.ckpt
# Average loss at step  28000 :  6.03498033476
# encoder_input:  ['once', 'upon', 'a', 'time']
# decoder_output:  ['the', 'the', 'the', ',']
# encoder_input:  ['this', 'cat', 'is', 'cute']
# decoder_output:  ['the', ',', 'the', 'the']
# [[ 4.45917225  5.8074584   4.05339003  5.17931747]
#  [ 4.58287287  4.86686563  5.02678299  4.75883389]]
# 5.80746
# Model saved in file: ./model/seq2seq-autoencoder.ckpt
# Average loss at step  29000 :  6.08833558691
# encoder_input:  ['once', 'upon', 'a', 'time']
# decoder_output:  ['the', 'the', 'the', ',']
# encoder_input:  ['this', 'cat', 'is', 'cute']
# decoder_output:  ['the', 'was', 'the', 'the']
# [[ 4.23852015  5.99740219  4.10946989  5.10921097]
#  [ 4.3502903   5.03564787  4.64557028  5.08024549]]
# 5.9974
# Model saved in file: ./model/seq2seq-autoencoder.ckpt
# Average loss at step  30000 :  6.11387702787
# encoder_input:  ['once', 'upon', 'a', 'time']
# decoder_output:  ['the', 'the', 'the', ',']
# encoder_input:  ['this', 'cat', 'is', 'cute']
# decoder_output:  ['the', ',', 'the', 'the']
# [[ 4.450315    6.24053812  4.26771402  4.82906151]
#  [ 4.59562349  5.0155406   5.11356449  4.81839132]]
# 6.24054
# Model saved in file: ./model/seq2seq-autoencoder.ckpt
# Average loss at step  31000 :  6.01964539409
# encoder_input:  ['once', 'upon', 'a', 'time']
# decoder_output:  ['the', 'the', 'the', ',']
# encoder_input:  ['this', 'cat', 'is', 'cute']
# decoder_output:  ['the', ',', 'was', 'the']
# [[ 4.45579052  6.11101675  4.47886467  4.87634659]
#  [ 4.40454197  4.9696126   4.45842743  4.84066725]]
# 6.11102
# Model saved in file: ./model/seq2seq-autoencoder.ckpt
# Average loss at step  32000 :  5.97066924953
# encoder_input:  ['once', 'upon', 'a', 'time']
# decoder_output:  ['the', 'the', 'the', ',']
# encoder_input:  ['this', 'cat', 'is', 'cute']
# decoder_output:  ['the', ',', 'the', 'the']
# [[ 4.40765858  5.89165688  4.16354561  5.67394066]
#  [ 4.57248688  4.99337101  5.01627684  4.74534416]]
# 5.89166
# Model saved in file: ./model/seq2seq-autoencoder.ckpt
# Average loss at step  33000 :  5.98019276357
# encoder_input:  ['once', 'upon', 'a', 'time']
# decoder_output:  ['the', 'was', 'the', ',']
# encoder_input:  ['this', 'cat', 'is', 'cute']
# decoder_output:  ['the', 'is', 'was', ',']
# [[ 4.3377552   6.11383533  4.37920094  4.96431446]
#  [ 4.40894747  4.94833422  3.63846564  4.9540987 ]]
# 6.11384
# Model saved in file: ./model/seq2seq-autoencoder.ckpt
# Average loss at step  34000 :  5.62825945961
# encoder_input:  ['once', 'upon', 'a', 'time']
# decoder_output:  ['the', 'the', 'the', '.']
# encoder_input:  ['this', 'cat', 'is', 'cute']
# decoder_output:  ['the', ',', 'was', 'the']
# [[ 4.22214651  5.75296926  4.23461723  4.36066961]
#  [ 3.97722292  5.01055813  4.06505871  4.8346529 ]]
# 5.75297
# Model saved in file: ./model/seq2seq-autoencoder.ckpt
# Average loss at step  35000 :  5.6425577569
# encoder_input:  ['once', 'upon', 'a', 'time']
# decoder_output:  ['the', '.', 'the', '.']
# encoder_input:  ['this', 'cat', 'is', 'cute']
# decoder_output:  ['the', 'the', 'the', 'to']
# [[ 4.3253603   5.37189245  3.80191278  4.8766675 ]
#  [ 4.07554817  5.3411684   4.84702873  5.23053741]]
# 5.37189
# Model saved in file: ./model/seq2seq-autoencoder.ckpt
# Average loss at step  36000 :  5.74282480907
# encoder_input:  ['once', 'upon', 'a', 'time']
# decoder_output:  ['the', 'the', 'the', '.']
# encoder_input:  ['this', 'cat', 'is', 'cute']
# decoder_output:  ['the', 'the', ',', 'the']
# [[ 4.32616425  5.87898922  3.97310615  5.10364199]
#  [ 4.18508482  5.18107653  4.98058224  5.03245974]]
# 5.87899
# Model saved in file: ./model/seq2seq-autoencoder.ckpt
# Average loss at step  37000 :  5.919395127
# encoder_input:  ['once', 'upon', 'a', 'time']
# decoder_output:  ['the', 'the', 'the', ',']
# encoder_input:  ['this', 'cat', 'is', 'cute']
# decoder_output:  ['the', 'the', ',', 'the']
# [[ 4.190485    5.93294477  4.2270937   4.50715733]
#  [ 4.1999836   5.23755598  4.57236624  4.89487839]]
# 5.93294
# Model saved in file: ./model/seq2seq-autoencoder.ckpt
# Average loss at step  38000 :  5.95337339973
# encoder_input:  ['once', 'upon', 'a', 'time']
# decoder_output:  ['the', 'the', 'the', ',']
# encoder_input:  ['this', 'cat', 'is', 'cute']
# decoder_output:  ['the', 'the', 'the', 'the']
# [[ 4.06442976  5.88751078  3.79391909  4.68775511]
#  [ 4.26070309  5.02724504  5.19033909  4.72987318]]
# 5.88751
# Model saved in file: ./model/seq2seq-autoencoder.ckpt
# Average loss at step  39000 :  5.91150970781
# encoder_input:  ['once', 'upon', 'a', 'time']
# decoder_output:  ['the', 'the', 'the', '.']
# encoder_input:  ['this', 'cat', 'is', 'cute']
# decoder_output:  ['the', 'the', '.', 'the']
# [[ 4.50539732  6.384161    4.22099113  4.81269979]
#  [ 4.52209949  5.09930325  5.20080137  4.90018272]]
# 6.38416
# Model saved in file: ./model/seq2seq-autoencoder.ckpt
# Average loss at step  40000 :  5.99171739519
# encoder_input:  ['once', 'upon', 'a', 'time']
# decoder_output:  ['the', 'the', 'the', ',']
# encoder_input:  ['this', 'cat', 'is', 'cute']
# decoder_output:  ['the', ',', ',', ',']
# [[ 4.51475906  6.49667501  4.23053169  4.70546865]
#  [ 4.21983051  5.12221098  4.50577927  4.82492924]]
# 6.49668
# Model saved in file: ./model/seq2seq-autoencoder.ckpt
# Average loss at step  41000 :  5.9208559345
# encoder_input:  ['once', 'upon', 'a', 'time']
# decoder_output:  ['the', 'the', 'the', '.']
# encoder_input:  ['this', 'cat', 'is', 'cute']
# decoder_output:  ['the', 'the', '.', ',']
# [[ 4.39169216  6.12704086  4.19103765  4.83052683]
#  [ 4.23546743  5.2005434   4.97365856  4.92900848]]
# 6.12704
# Model saved in file: ./model/seq2seq-autoencoder.ckpt
# Average loss at step  42000 :  5.91278397924
# encoder_input:  ['once', 'upon', 'a', 'time']
# decoder_output:  ['the', 'the', 'the', ',']
# encoder_input:  ['this', 'cat', 'is', 'cute']
# decoder_output:  ['the', 'the', 'the', 'the']
# [[ 3.90808272  6.46531868  3.99315548  5.18376732]
#  [ 3.92117667  5.18605661  4.728652    4.90220594]]
# 6.46532
# Model saved in file: ./model/seq2seq-autoencoder.ckpt
# Average loss at step  43000 :  5.94623862052
# encoder_input:  ['once', 'upon', 'a', 'time']
# decoder_output:  ['the', 'the', 'the', '.']
# encoder_input:  ['this', 'cat', 'is', 'cute']
# decoder_output:  ['the', 'have', 'have', 'the']
# [[ 4.7188673   6.80474615  4.0147047   4.23061419]
#  [ 4.427073    5.15718746  4.59224129  5.45023775]]
# 6.80475
# Model saved in file: ./model/seq2seq-autoencoder.ckpt
# Average loss at step  44000 :  5.95670018029
# encoder_input:  ['once', 'upon', 'a', 'time']
# decoder_output:  ['the', 'the', 'the', '.']
# encoder_input:  ['this', 'cat', 'is', 'cute']
# decoder_output:  ['the', ',', '.', 'the']
# [[ 4.05080891  5.92912817  3.76625299  4.59754181]
#  [ 4.44877768  4.98888254  4.9332962   5.16284132]]
# 5.92913
# Model saved in file: ./model/seq2seq-autoencoder.ckpt
# Average loss at step  45000 :  5.96256191123
# encoder_input:  ['once', 'upon', 'a', 'time']
# decoder_output:  ['the', 'the', 'the', 'one']
# encoder_input:  ['this', 'cat', 'is', 'cute']
# decoder_output:  ['the', 'have', '.', 'the']
# [[ 4.14729261  6.15650129  3.97779536  3.85903907]
#  [ 4.54633808  4.76610279  4.38467932  5.3744812 ]]
# 6.1565
# Model saved in file: ./model/seq2seq-autoencoder.ckpt
# Average loss at step  46000 :  5.88790970349
# encoder_input:  ['once', 'upon', 'a', 'time']
# decoder_output:  ['the', 'the', 'the', ',']
# encoder_input:  ['this', 'cat', 'is', 'cute']
# decoder_output:  ['the', ',', 'was', 'a']
# [[ 4.04900503  6.33785152  4.13154793  4.26780081]
#  [ 4.40364599  5.10892344  4.05068636  5.1732235 ]]
# 6.33785
# Model saved in file: ./model/seq2seq-autoencoder.ckpt
# Average loss at step  47000 :  5.96728319216
# encoder_input:  ['once', 'upon', 'a', 'time']
# decoder_output:  ['the', 'was', 'the', ',']
# encoder_input:  ['this', 'cat', 'is', 'cute']
# decoder_output:  ['the', 'is', ',', 'a']
# [[ 4.34630728  6.4572382   4.34696293  4.08439541]
#  [ 4.67538404  4.93449688  4.27846003  4.96480846]]
# 6.45724
# Model saved in file: ./model/seq2seq-autoencoder.ckpt
# Average loss at step  48000 :  6.00011565208
# encoder_input:  ['once', 'upon', 'a', 'time']
# decoder_output:  ['the', 'was', 'the', '.']
# encoder_input:  ['this', 'cat', 'is', 'cute']
# decoder_output:  ['the', 'was', 'was', 'a']
# [[ 4.26583958  6.39973259  3.93610954  3.50746942]
#  [ 4.45730352  5.35497093  4.62280607  5.21595144]]
# 6.39973
# Model saved in file: ./model/seq2seq-autoencoder.ckpt
# Average loss at step  49000 :  5.73135172558
# encoder_input:  ['once', 'upon', 'a', 'time']
# decoder_output:  ['the', '.', 'the', '.']
# encoder_input:  ['this', 'cat', 'is', 'cute']
# decoder_output:  ['the', ',', '.', 'the']
# [[ 4.55989647  6.2908287   4.25620556  4.6629343 ]
#  [ 4.42407131  5.24268818  4.37856054  5.40260267]]
# 6.29083
# Model saved in file: ./model/seq2seq-autoencoder.ckpt
# Average loss at step  50000 :  5.65420782197
# encoder_input:  ['once', 'upon', 'a', 'time']
# decoder_output:  ['the', 'the', 'the', '.']
# encoder_input:  ['this', 'cat', 'is', 'cute']
# decoder_output:  ['the', ',', '.', 'a']
# [[ 4.21329308  5.9782176   4.21325111  4.54293966]
#  [ 4.17796803  5.04342794  4.57562447  5.26214027]]
# 5.97822
# Model saved in file: ./model/seq2seq-autoencoder.ckpt
# Average loss at step  51000 :  5.72410858768
# encoder_input:  ['once', 'upon', 'a', 'time']
# decoder_output:  ['the', 'the', 'the', ',']
# encoder_input:  ['this', 'cat', 'is', 'cute']
# decoder_output:  ['the', 'the', 'the', 'the']
# [[ 4.46054602  6.33838272  4.42508173  4.99829721]
#  [ 4.4925046   5.04603863  5.38781452  4.91437292]]
# 6.33838
# Model saved in file: ./model/seq2seq-autoencoder.ckpt
# Average loss at step  52000 :  5.8165546937
# encoder_input:  ['once', 'upon', 'a', 'time']
# decoder_output:  ['the', 'the', 'the', 'the']
# encoder_input:  ['this', 'cat', 'is', 'cute']
# decoder_output:  ['the', 'the', 'the', 'a']
# [[ 4.26375675  6.32569551  3.95443892  5.02847195]
#  [ 4.41759157  5.06684637  4.79899406  5.07093287]]
# 6.3257
# Model saved in file: ./model/seq2seq-autoencoder.ckpt
# Average loss at step  53000 :  5.77999320328
# encoder_input:  ['once', 'upon', 'a', 'time']
# decoder_output:  ['the', 'the', 'the', ',']
# encoder_input:  ['this', 'cat', 'is', 'cute']
# decoder_output:  ['the', 'the', 'was', 'a']
# [[ 4.19340992  6.63418818  4.09186172  4.50761414]
#  [ 4.12272406  4.95216894  4.35725451  4.93522263]]
# 6.63419
# Model saved in file: ./model/seq2seq-autoencoder.ckpt
# Average loss at step  54000 :  5.85402602708
# encoder_input:  ['once', 'upon', 'a', 'time']
# decoder_output:  ['the', 'the', 'the', '.']
# encoder_input:  ['this', 'cat', 'is', 'cute']
# decoder_output:  ['the', 'the', 'the', 'the']
# [[ 4.17039299  6.24988699  3.94298148  4.04766893]
#  [ 4.13364697  4.98376131  5.04141521  4.91619158]]
# 6.24989
# Model saved in file: ./model/seq2seq-autoencoder.ckpt
# Average loss at step  55000 :  5.89810548699
# encoder_input:  ['once', 'upon', 'a', 'time']
# decoder_output:  ['the', 'the', 'the', '.']
# encoder_input:  ['this', 'cat', 'is', 'cute']
# decoder_output:  ['the', 'of', '.', 'the']
# [[ 4.32220078  6.21272993  3.75054574  3.89353085]
#  [ 4.20061398  5.17670345  4.72575998  5.06150913]]
# 6.21273
# Model saved in file: ./model/seq2seq-autoencoder.ckpt
# Average loss at step  56000 :  5.853625723
# encoder_input:  ['once', 'upon', 'a', 'time']
# decoder_output:  ['the', 'the', 'the', '.']
# encoder_input:  ['this', 'cat', 'is', 'cute']
# decoder_output:  ['the', ',', '.', 'the']
# [[ 4.10619736  5.93095016  3.89871645  5.38108635]
#  [ 4.30966806  5.38682175  4.95379019  5.21107674]]
# 5.93095
# Model saved in file: ./model/seq2seq-autoencoder.ckpt
# Average loss at step  57000 :  5.9619203223
# encoder_input:  ['once', 'upon', 'a', 'time']
# decoder_output:  ['the', 'the', 'the', '.']
# encoder_input:  ['this', 'cat', 'is', 'cute']
# decoder_output:  ['the', 'of', 'have', 'the']
# [[ 4.23587894  6.1422267   3.94444323  3.96637702]
#  [ 4.40540075  4.93425465  4.85966015  4.73626137]]
# 6.14223
# Model saved in file: ./model/seq2seq-autoencoder.ckpt
# Average loss at step  58000 :  5.8487722342
# encoder_input:  ['once', 'upon', 'a', 'time']
# decoder_output:  ['the', 'the', 'the', '.']
# encoder_input:  ['this', 'cat', 'is', 'cute']
# decoder_output:  ['the', 'of', ',', 'the']
# [[ 4.01918554  5.86561489  4.30043125  4.77280998]
#  [ 4.19146538  4.98845434  4.66271973  4.71992207]]
# 5.86561
# Model saved in file: ./model/seq2seq-autoencoder.ckpt
# Average loss at step  59000 :  5.74622687113
# encoder_input:  ['once', 'upon', 'a', 'time']
# decoder_output:  ['he', 'was', '.', '.']
# encoder_input:  ['this', 'cat', 'is', 'cute']
# decoder_output:  ['the', 'was', 'was', 'a']
# [[ 4.65522623  6.30190849  3.94599271  4.45944738]
#  [ 4.59421158  4.98217249  4.06157351  4.80830717]]
# 6.30191
# Model saved in file: ./model/seq2seq-autoencoder.ckpt
# Average loss at step  60000 :  5.7201782217
# encoder_input:  ['once', 'upon', 'a', 'time']
# decoder_output:  ['the', 'the', 'the', '.']
# encoder_input:  ['this', 'cat', 'is', 'cute']
# decoder_output:  ['the', 'the', '.', 'the']
# [[ 4.06932402  5.43579865  4.22986698  4.11955261]
#  [ 4.27025938  5.10395908  5.80475569  4.90236807]]
# 5.80476
# Model saved in file: ./model/seq2seq-autoencoder.ckpt
# Average loss at step  61000 :  5.73344458401
# encoder_input:  ['once', 'upon', 'a', 'time']
# decoder_output:  ['the', '.', '.', '.']
# encoder_input:  ['this', 'cat', 'is', 'cute']
# decoder_output:  ['the', 'was', '.', 'the']
# [[ 4.02503347  5.32010698  3.59913898  4.30792618]
#  [ 4.44835615  5.05933428  4.70880222  4.64257288]]
# 5.32011
# Model saved in file: ./model/seq2seq-autoencoder.ckpt
# Average loss at step  62000 :  5.77257211113
# encoder_input:  ['once', 'upon', 'a', 'time']
# decoder_output:  ['the', '.', 'the', 'one']
# encoder_input:  ['this', 'cat', 'is', 'cute']
# decoder_output:  ['the', 'one', '.', 'a']
# [[ 3.96510077  5.13869476  3.80502653  4.54592752]
#  [ 4.28590393  4.84342146  4.98651934  4.36535883]]
# 5.13869
# Model saved in file: ./model/seq2seq-autoencoder.ckpt
# Average loss at step  63000 :  5.78368893874
# encoder_input:  ['once', 'upon', 'a', 'time']
# decoder_output:  ['the', 'the', 'the', 'one']
# encoder_input:  ['this', 'cat', 'is', 'cute']
# decoder_output:  ['the', 'of', 'the', 'the']
# [[ 4.59136677  5.47116327  3.72445869  4.62609673]
#  [ 4.31524515  5.08789062  4.99573612  4.93627167]]
# 5.47116
# Model saved in file: ./model/seq2seq-autoencoder.ckpt
# Average loss at step  64000 :  5.69370982802
# encoder_input:  ['once', 'upon', 'a', 'time']
# decoder_output:  ['he', 'the', 'the', '.']
# encoder_input:  ['this', 'cat', 'is', 'cute']
# decoder_output:  ['the', 'the', 'the', 'the']
# [[ 4.37386513  4.71058846  3.35851169  4.19726849]
#  [ 4.24049282  5.13788652  5.81299734  4.70845938]]
# 5.813
# Model saved in file: ./model/seq2seq-autoencoder.ckpt
# Average loss at step  65000 :  5.71666130447
# encoder_input:  ['once', 'upon', 'a', 'time']
# decoder_output:  ['the', 'was', 'the', '.']
# encoder_input:  ['this', 'cat', 'is', 'cute']
# decoder_output:  ['the', 'of', 'of', 'the']
# [[ 3.84206343  5.78630161  4.25983572  4.89071941]
#  [ 4.17490816  4.95719337  4.6094985   4.85509777]]
# 5.7863
# Model saved in file: ./model/seq2seq-autoencoder.ckpt
# Average loss at step  66000 :  5.67435126185
# encoder_input:  ['once', 'upon', 'a', 'time']
# decoder_output:  ['the', '.', 'the', ',']
# encoder_input:  ['this', 'cat', 'is', 'cute']
# decoder_output:  ['the', 'of', 'of', 'of']
# [[ 3.92341256  4.71325302  3.5541296   4.12464476]
#  [ 4.06031799  4.95830441  4.4448123   5.14850235]]
# 5.1485
# Model saved in file: ./model/seq2seq-autoencoder.ckpt
# Average loss at step  67000 :  5.69734198809
# encoder_input:  ['once', 'upon', 'a', 'time']
# decoder_output:  ['the', '.', 'the', 'years']
# encoder_input:  ['this', 'cat', 'is', 'cute']
# decoder_output:  ['the', 'one', 'of', 'of']
# [[ 4.14057493  5.11697102  3.62155151  4.21955299]
#  [ 3.91880345  4.91360664  4.41152573  5.0690856 ]]
# 5.11697
# Model saved in file: ./model/seq2seq-autoencoder.ckpt
# Average loss at step  68000 :  5.67693191886
# encoder_input:  ['once', 'upon', 'a', 'time']
# decoder_output:  ['he', '.', '.', '.']
# encoder_input:  ['this', 'cat', 'is', 'cute']
# decoder_output:  ['the', 'one', ',', 'not']
# [[ 4.31966925  5.14292192  4.1567421   3.96669006]
#  [ 4.3472147   5.47398376  4.43608093  5.36117077]]
# 5.47398
# Model saved in file: ./model/seq2seq-autoencoder.ckpt
# Average loss at step  69000 :  5.5575189079
# encoder_input:  ['once', 'upon', 'a', 'time']
# decoder_output:  ['the', 'the', 'the', 'right']
# encoder_input:  ['this', 'cat', 'is', 'cute']
# decoder_output:  ['the', 'the', ',', 'the']
# [[ 3.91530275  5.15226603  3.27959013  3.7728951 ]
#  [ 3.99687099  4.76603937  5.03148794  4.77141333]]
# 5.15227
# Model saved in file: ./model/seq2seq-autoencoder.ckpt
# Average loss at step  70000 :  5.64680400723
# encoder_input:  ['once', 'upon', 'a', 'time']
# decoder_output:  ['the', 'to', '.', '.']
# encoder_input:  ['this', 'cat', 'is', 'cute']
# decoder_output:  ['the', ',', ',', 'the']
# [[ 4.00759697  5.09495354  4.15984392  4.93677711]
#  [ 4.30607796  5.09836674  5.14886856  4.71670103]]
# 5.14887
# Model saved in file: ./model/seq2seq-autoencoder.ckpt
# Average loss at step  71000 :  5.67613910437
# encoder_input:  ['once', 'upon', 'a', 'time']
# decoder_output:  ['the', '.', '.', '.']
# encoder_input:  ['this', 'cat', 'is', 'cute']
# decoder_output:  ['the', 'the', 'of', 'the']
# [[ 4.16201973  4.87498188  3.87674356  4.48177338]
#  [ 3.96784377  5.29661083  4.89178896  4.92241383]]
# 5.29661
# Model saved in file: ./model/seq2seq-autoencoder.ckpt
# Average loss at step  72000 :  5.63899609911
# encoder_input:  ['once', 'upon', 'a', 'time']
# decoder_output:  ['the', '.', 'the', '.']
# encoder_input:  ['this', 'cat', 'is', 'cute']
# decoder_output:  ['the', 'the', ',', 'the']
# [[ 3.87075019  4.75307035  4.27797079  5.2291193 ]
#  [ 3.88618946  5.22529745  4.88572168  4.89546824]]
# 5.22912
# Model saved in file: ./model/seq2seq-autoencoder.ckpt
# Average loss at step  73000 :  5.76538304615
# encoder_input:  ['once', 'upon', 'a', 'time']
# decoder_output:  ['the', 'the', 'the', '.']
# encoder_input:  ['this', 'cat', 'is', 'cute']
# decoder_output:  ['the', 'the', ',', 'the']
# [[ 3.64253283  4.85932732  4.54522371  4.19784975]
#  [ 3.981673    5.03242111  5.34590435  4.93763494]]
# 5.3459
# Model saved in file: ./model/seq2seq-autoencoder.ckpt
# Average loss at step  74000 :  5.72695633054
# encoder_input:  ['once', 'upon', 'a', 'time']
# decoder_output:  ['i', 'to', 'the', 'to']
# encoder_input:  ['this', 'cat', 'is', 'cute']
# decoder_output:  ['the', 'the', ',', 'the']
# [[ 4.58684349  5.06750011  3.58158207  3.57885242]
#  [ 3.85835075  5.04226685  4.91056538  4.60412931]]
# 5.0675
# Model saved in file: ./model/seq2seq-autoencoder.ckpt
# Average loss at step  75000 :  5.62911731768
# encoder_input:  ['once', 'upon', 'a', 'time']
# decoder_output:  ['just', 'to', 'the', 'to']
# encoder_input:  ['this', 'cat', 'is', 'cute']
# decoder_output:  ['the', ',', 'the', 'the']
# [[ 3.94878435  5.11042595  4.08914232  4.54570341]
#  [ 4.18689919  4.95083284  5.86357117  4.83738995]]
# 5.86357
# Model saved in file: ./model/seq2seq-autoencoder.ckpt
# Average loss at step  76000 :  5.66503006655
# encoder_input:  ['once', 'upon', 'a', 'time']
# decoder_output:  ['just', 'the', 'the', 'to']
# encoder_input:  ['this', 'cat', 'is', 'cute']
# decoder_output:  ['the', ',', ',', 'the']
# [[ 3.71071959  5.00327444  3.84087229  4.30835199]
#  [ 3.95902467  4.87273121  5.20634222  4.71145344]]
# 5.20634
# Model saved in file: ./model/seq2seq-autoencoder.ckpt
# Average loss at step  77000 :  5.65313861179
# encoder_input:  ['once', 'upon', 'a', 'time']
# decoder_output:  ['``', 'to', 'the', 'to']
# encoder_input:  ['this', 'cat', 'is', 'cute']
# decoder_output:  ['the', 'the', 'the', 'the']
# [[ 4.13591719  4.72499514  3.56784821  5.43357944]
#  [ 4.27840376  5.15751839  5.89202118  4.93198061]]
# 5.89202
# Model saved in file: ./model/seq2seq-autoencoder.ckpt
# Average loss at step  78000 :  5.79052430713
# encoder_input:  ['once', 'upon', 'a', 'time']
# decoder_output:  ['``', 'the', '.', 'to']
# encoder_input:  ['this', 'cat', 'is', 'cute']
# decoder_output:  ['the', 'the', 'was', 'the']
# [[ 4.05201626  5.26545572  4.02239656  4.72899151]
#  [ 3.90348148  4.84226942  4.60584831  4.41157246]]
# 5.26546
# Model saved in file: ./model/seq2seq-autoencoder.ckpt
# epouch done...
# Average loss at step  79000 :  6.05633509064
# encoder_input:  ['once', 'upon', 'a', 'time']
# decoder_output:  ['he', 'the', 'the', 'to']
# encoder_input:  ['this', 'cat', 'is', 'cute']
# decoder_output:  ['the', 'was', 'was', 'the']
# [[ 4.26474142  5.43155003  3.7400322   5.60635662]
#  [ 4.18959045  5.10990906  4.73278236  4.84579611]]
# 5.60636
# Model saved in file: ./model/seq2seq-autoencoder.ckpt
# Average loss at step  80000 :  5.99534969825
# encoder_input:  ['once', 'upon', 'a', 'time']
# decoder_output:  ["don't", 'the', 'the', '.']
# encoder_input:  ['this', 'cat', 'is', 'cute']
# decoder_output:  ['the', 'the', 'the', 'the']
# [[ 4.33284092  5.10480452  4.1182127   5.52847767]
#  [ 4.15494251  4.86959743  5.75320148  4.67969513]]
# 5.7532
# Model saved in file: ./model/seq2seq-autoencoder.ckpt
# Average loss at step  81000 :  6.02501950622
# encoder_input:  ['once', 'upon', 'a', 'time']
# decoder_output:  ['the', 'the', 'the', '.']
# encoder_input:  ['this', 'cat', 'is', 'cute']
# decoder_output:  ['the', 'the', 'the', 'the']
# [[ 4.22183418  4.68503809  4.37452126  5.93868876]
#  [ 4.08542824  5.64565945  6.14442396  4.79217243]]
# 6.14442
# Model saved in file: ./model/seq2seq-autoencoder.ckpt
# Average loss at step  82000 :  6.01755761445
# encoder_input:  ['once', 'upon', 'a', 'time']
# decoder_output:  ['the', 'the', 'the', 'the']
# encoder_input:  ['this', 'cat', 'is', 'cute']
# decoder_output:  ['the', ',', ',', 'the']
# [[ 4.24423027  5.26006174  3.9151547   5.15287113]
#  [ 4.29519606  4.78443384  4.85499144  4.48073816]]
# 5.26006
# Model saved in file: ./model/seq2seq-autoencoder.ckpt
# Average loss at step  83000 :  6.00990886348
# encoder_input:  ['once', 'upon', 'a', 'time']
# decoder_output:  ['the', 'the', 'the', '.']
# encoder_input:  ['this', 'cat', 'is', 'cute']
# decoder_output:  ['the', ',', ',', 'the']
# [[ 3.92252254  5.18561029  3.83914709  5.4913516 ]
#  [ 3.92760777  4.92207479  4.82222795  4.88703489]]
# 5.49135
# Model saved in file: ./model/seq2seq-autoencoder.ckpt
# Average loss at step  84000 :  5.87996598107
# encoder_input:  ['once', 'upon', 'a', 'time']
# decoder_output:  ['the', 'the', 'the', '.']
# encoder_input:  ['this', 'cat', 'is', 'cute']
# decoder_output:  ['the', ',', 'was', 'the']
# [[ 4.1631422   5.73010874  4.14057779  4.85939026]
#  [ 4.1015048   4.99336624  4.03882742  4.63970184]]
# 5.73011
# Model saved in file: ./model/seq2seq-autoencoder.ckpt
# Average loss at step  85000 :  5.82183959043
# encoder_input:  ['once', 'upon', 'a', 'time']
# decoder_output:  ['the', 'the', 'the', '.']
# encoder_input:  ['this', 'cat', 'is', 'cute']
# decoder_output:  ['the', ',', 'was', 'the']
# [[ 4.28822994  5.33901596  4.10190916  5.32065725]
#  [ 3.98329329  5.09011555  4.17869949  4.76509476]]
# 5.33902
# Model saved in file: ./model/seq2seq-autoencoder.ckpt
# Average loss at step  86000 :  5.94688923073
# encoder_input:  ['once', 'upon', 'a', 'time']
# decoder_output:  ['the', 'the', 'the', '.']
# encoder_input:  ['this', 'cat', 'is', 'cute']
# decoder_output:  ['the', ',', ',', 'the']
# [[ 4.23262215  5.01369524  3.91933203  4.80416965]
#  [ 4.30314112  4.98028803  4.52236843  4.42043352]]
# 5.0137
# Model saved in file: ./model/seq2seq-autoencoder.ckpt
# Average loss at step  87000 :  5.93946478164
# encoder_input:  ['once', 'upon', 'a', 'time']
# decoder_output:  ['the', 'the', 'the', '.']
# encoder_input:  ['this', 'cat', 'is', 'cute']
# decoder_output:  ['the', ',', ',', 'the']
# [[ 4.30586958  5.45911074  3.98078108  5.27944088]
#  [ 4.34676504  5.02317142  4.60844231  4.69742966]]
# 5.45911
# Model saved in file: ./model/seq2seq-autoencoder.ckpt
# Average loss at step  88000 :  5.98469739509
# encoder_input:  ['once', 'upon', 'a', 'time']
# decoder_output:  ['the', 'the', 'the', '.']
# encoder_input:  ['this', 'cat', 'is', 'cute']
# decoder_output:  ['the', ',', 'was', 'the']
# [[ 4.05476284  5.01751518  4.00593567  4.36644697]
#  [ 4.00804424  4.87766457  3.8489542   4.74916553]]
# 5.01752
# Model saved in file: ./model/seq2seq-autoencoder.ckpt
# Average loss at step  89000 :  5.72982653642
# encoder_input:  ['once', 'upon', 'a', 'time']
# decoder_output:  ['the', 'the', 'the', '.']
# encoder_input:  ['this', 'cat', 'is', 'cute']
# decoder_output:  ['the', ',', 'was', 'the']
# [[ 3.92903566  4.85699081  3.58661914  4.76613045]
#  [ 3.73295426  4.9753027   3.88043571  4.56760645]]
# 4.9753
# Model saved in file: ./model/seq2seq-autoencoder.ckpt
# Average loss at step  90000 :  5.86093873358
# encoder_input:  ['once', 'upon', 'a', 'time']
# decoder_output:  ['the', 'the', 'the', '.']
# encoder_input:  ['this', 'cat', 'is', 'cute']
# decoder_output:  ['the', ',', ',', 'the']
# [[ 3.99193883  5.30170584  3.52731514  5.06719494]
#  [ 3.97628212  5.06393766  4.09687662  4.76068258]]
# 5.30171
# Model saved in file: ./model/seq2seq-autoencoder.ckpt
# Average loss at step  91000 :  5.54334526509
# encoder_input:  ['once', 'upon', 'a', 'time']
# decoder_output:  ['the', 'the', 'the', ',']
# encoder_input:  ['this', 'cat', 'is', 'cute']
# decoder_output:  ['the', ',', 'was', 'the']
# [[ 4.130054    6.14122343  4.06839037  5.08703613]
#  [ 4.11710596  4.98020124  3.67791843  4.58698368]]
# 6.14122
# Model saved in file: ./model/seq2seq-autoencoder.ckpt
# Average loss at step  92000 :  5.60667816401
# encoder_input:  ['once', 'upon', 'a', 'time']
# decoder_output:  ['the', 'the', 'the', '.']
# encoder_input:  ['this', 'cat', 'is', 'cute']
# decoder_output:  ['the', ',', 'is', 'the']
# [[ 4.31702948  5.2649827   3.61480856  4.71079016]
#  [ 3.81351519  4.87793493  3.68966246  4.34485865]]
# 5.26498
# Model saved in file: ./model/seq2seq-autoencoder.ckpt
# Average loss at step  93000 :  5.53387733293
# encoder_input:  ['once', 'upon', 'a', 'time']
# decoder_output:  ['the', 'to', 'the', '.']
# encoder_input:  ['this', 'cat', 'is', 'cute']
# decoder_output:  ['the', ',', 'was', 'the']
# [[ 4.26256704  4.70647097  3.64257741  4.70915127]
#  [ 3.83991671  4.90956831  3.90986538  4.59234095]]
# 4.90957
# Model saved in file: ./model/seq2seq-autoencoder.ckpt
# Average loss at step  94000 :  5.63068959105
# encoder_input:  ['once', 'upon', 'a', 'time']
# decoder_output:  ['the', 'the', 'the', ',']
# encoder_input:  ['this', 'cat', 'is', 'cute']
# decoder_output:  ['the', ',', 'was', 'the']
# [[ 4.71867561  5.94951868  4.05165958  4.20923185]
#  [ 4.03395462  4.89739323  3.35608625  4.67610502]]
# 5.94952
# Model saved in file: ./model/seq2seq-autoencoder.ckpt
# Average loss at step  95000 :  5.78187557232
# encoder_input:  ['once', 'upon', 'a', 'time']
# decoder_output:  ['the', 'the', 'the', '.']
# encoder_input:  ['this', 'cat', 'is', 'cute']
# decoder_output:  ['the', 'is', 'was', 'the']
# [[ 4.04395294  5.30786943  3.48729467  4.50129557]
#  [ 3.5871129   5.02649307  3.52274776  4.85791969]]
# 5.30787
# Model saved in file: ./model/seq2seq-autoencoder.ckpt
# Average loss at step  96000 :  5.7746829493
# encoder_input:  ['once', 'upon', 'a', 'time']
# decoder_output:  ['the', 'the', 'the', '.']
# encoder_input:  ['this', 'cat', 'is', 'cute']
# decoder_output:  ['the', ',', ',', 'the']
# [[ 4.34114599  5.8434701   3.89318848  4.35165548]
#  [ 3.63387847  4.68344116  4.32238007  4.4030633 ]]
# 5.84347
# Model saved in file: ./model/seq2seq-autoencoder.ckpt
# Average loss at step  97000 :  5.78182135367
# encoder_input:  ['once', 'upon', 'a', 'time']
# decoder_output:  ['the', 'the', 'the', '.']
# encoder_input:  ['this', 'cat', 'is', 'cute']
# decoder_output:  ['the', ',', ',', 'the']
# [[ 3.72513962  5.22549057  3.71799183  5.4125309 ]
#  [ 3.67407203  4.88399553  3.81420398  4.31766701]]
# 5.41253
# Model saved in file: ./model/seq2seq-autoencoder.ckpt
# Average loss at step  98000 :  5.79256519914
# encoder_input:  ['once', 'upon', 'a', 'time']
# decoder_output:  ['the', 'the', 'the', '.']
# encoder_input:  ['this', 'cat', 'is', 'cute']
# decoder_output:  ['the', ',', 'was', 'the']
# [[ 3.62588763  6.03846359  4.08250666  5.21002913]
#  [ 3.64850426  4.85526133  3.62218451  4.47850561]]
# 6.03846
# Model saved in file: ./model/seq2seq-autoencoder.ckpt
# Average loss at step  99000 :  5.78128045303
# encoder_input:  ['once', 'upon', 'a', 'time']
# decoder_output:  ['the', 'can', 'the', '.']
# encoder_input:  ['this', 'cat', 'is', 'cute']
# decoder_output:  ['the', 'the', 'was', 'the']
# [[ 4.06380701  6.17289209  3.94274068  5.03566217]
#  [ 3.67589498  4.89313126  3.76253533  4.72647095]]
# 6.17289
# Model saved in file: ./model/seq2seq-autoencoder.ckpt
# Average loss at step  100000 :  5.80557337141
# encoder_input:  ['once', 'upon', 'a', 'time']
# decoder_output:  ['the', 'the', 'the', '.']
# encoder_input:  ['this', 'cat', 'is', 'cute']
# decoder_output:  ['the', 'the', 'was', 'the']
# [[ 3.53076363  5.35424232  3.52773833  4.96120596]
#  [ 3.45151925  4.95820093  3.46013856  4.86012506]]
# 5.35424
# Model saved in file: ./model/seq2seq-autoencoder.ckpt
# Average loss at step  101000 :  5.80473729932
# encoder_input:  ['once', 'upon', 'a', 'time']
# decoder_output:  ['the', 'the', 'the', '.']
# encoder_input:  ['this', 'cat', 'is', 'cute']
# decoder_output:  ['the', ',', 'is', 'the']
# [[ 3.90108585  5.17804003  3.67913294  4.76528692]
#  [ 3.73946095  4.98020172  3.69116759  4.80860519]]
# 5.17804
# Model saved in file: ./model/seq2seq-autoencoder.ckpt
# Average loss at step  102000 :  5.80497728193
# encoder_input:  ['once', 'upon', 'a', 'time']
# decoder_output:  ['the', 'the', 'the', '.']
# encoder_input:  ['this', 'cat', 'is', 'cute']
# decoder_output:  ['the', ',', 'was', 'the']
# [[ 3.66909313  5.39172745  3.63460946  4.71859837]
#  [ 4.06173754  5.02014923  3.6663177   4.85414648]]
# 5.39173
# Model saved in file: ./model/seq2seq-autoencoder.ckpt
# Average loss at step  103000 :  5.76365093201
# encoder_input:  ['once', 'upon', 'a', 'time']
# decoder_output:  ['the', 'to', 'the', 'to']
# encoder_input:  ['this', 'cat', 'is', 'cute']
# decoder_output:  ['the', ',', 'was', 'the']
# [[ 3.73787785  5.0553422   3.50948095  3.93452501]
#  [ 4.13098335  4.92965937  3.71156788  4.83257723]]
# 5.05534
# Model saved in file: ./model/seq2seq-autoencoder.ckpt
# Average loss at step  104000 :  5.81820559609
# encoder_input:  ['once', 'upon', 'a', 'time']
# decoder_output:  ['the', 'to', 'the', 'to']
# encoder_input:  ['this', 'cat', 'is', 'cute']
# decoder_output:  ['the', ',', ',', 'the']
# [[ 3.84594035  5.38148212  3.74820304  4.19050789]
#  [ 3.99442792  4.92103672  3.77938414  4.71224451]]
# 5.38148
# Model saved in file: ./model/seq2seq-autoencoder.ckpt
# Average loss at step  105000 :  5.88100841236
# encoder_input:  ['once', 'upon', 'a', 'time']
# decoder_output:  ['sure', 'to', 'the', 'to']
# encoder_input:  ['this', 'cat', 'is', 'cute']
# decoder_output:  ['the', 'the', 'is', 'the']
# [[ 3.93201733  5.83635044  4.06728888  3.76270294]
#  [ 3.93804097  5.19680977  3.47904944  5.1281991 ]]
# 5.83635
# Model saved in file: ./model/seq2seq-autoencoder.ckpt
# Average loss at step  106000 :  5.66793436956
# encoder_input:  ['once', 'upon', 'a', 'time']
# decoder_output:  ['the', 'the', 'the', '.']
# encoder_input:  ['this', 'cat', 'is', 'cute']
# decoder_output:  ['the', 'the', 'is', 'the']
# [[ 3.8375721   5.29045153  3.62421775  3.9899807 ]
#  [ 3.97121215  5.23389578  3.92689157  4.89251661]]
# 5.29045
# Model saved in file: ./model/seq2seq-autoencoder.ckpt
# Average loss at step  107000 :  5.45561470455
# encoder_input:  ['once', 'upon', 'a', 'time']
# decoder_output:  ['the', 'the', 'the', '.']
# encoder_input:  ['this', 'cat', 'is', 'cute']
# decoder_output:  ['the', ',', 'is', 'the']
# [[ 4.07973576  5.11643171  3.50197291  4.3133111 ]
#  [ 3.98082638  4.95221663  3.48951459  4.7933979 ]]
# 5.11643
# Model saved in file: ./model/seq2seq-autoencoder.ckpt

# %%
with tf.Session(graph=graph) as session:
    saver.restore(session, MODEL)
    generator = sentenceGenerator(sents, words_dict, batch_size=2)
    batch_inputs, batch_input_lengths, batch_masks = next(generator)
    
    feed_dict = {
        inputs: batch_inputs,
        input_lengths: batch_input_lengths,
        decoder_masks: batch_masks
    }
    
    feed_dict = {inputs: [
        to_word_indices(['once', 'upon', 'a', 'time']), 
        to_word_indices(['this', 'cat', 'is', 'cute'])
    ], input_lengths:[4, 4], decoder_masks: [[1, 1, 1, 1], [1,1,1,1]]}
    
    a, b, c = session.run([decoder_outputs.rnn_output, seq_loss, loss], feed_dict)
    print('encoder_input: ', [inv_words_dict[out] for out in feed_dict['inputs'][0]])
    print('decoder_output: ', [inv_words_dict[word.argmax()] for word in project.eval({
        project_input: a[0]
    })])
    print('encoder_input: ', [inv_words_dict[out] for out in feed_dict['inputs'][1]])
    print('decoder_output: ', [inv_words_dict[word.argmax()] for word in project.eval({
        project_input: a[1]
    })])
    print(b)
    print(c)
    
    print('hi', np.average(b * batch_masks))
    
    
    #print(a[0][0].argsort())
    #print('decoder_outputs: ', [inv_words_dict[out] for out in a[0]])
    #print(b)
    #print(c)
