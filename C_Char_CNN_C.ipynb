# %% [markdown]
# # Character Level CNN

# %%
import Corpus.gutenberg as corpus
from TextPreprocess.Tokenizer.Stanford import tokenize
from Utils.visual import hist, tally
from Utils.debug import dump
from Utils.generator import sliding_window, random_window, transform
from Utils.FS.file import save, load
from Utils.keras import compact_embedding
from Utils.misc import batch
from Utils.indexer import build_index, index_2_one_hot
from keras.preprocessing.sequence import pad_sequences
from keras_tqdm import TQDMNotebookCallback
import numpy as np
# Out:
# Using TensorFlow backend.

# %%
data = corpus.raw()

# %%
def char_generator():
    for char in data:
        yield char

# %%
s2i, i2s, size = build_index(char_generator())

# %%
#MAX_SEQ_LENGTH = max([len(word) for word in data])
SEQ_LENGTH = 32

# %%
NUM_SYMBOL = size
NUM_SYMBOL
# Out:
# 97

# %%
def word_generator():
    for word in data:
            yield word

NUM_SAMPLE = len(list(word_generator()))
NUM_SAMPLE
# Out:
# 11793318

# %%
from keras.layers import Input, Conv2D, Conv2DTranspose, Dense, Flatten, Dropout, Reshape, Embedding, Concatenate
from keras.models import Model, Sequential
from keras.regularizers import l2
from keras.optimizers import Adam
import numpy as np
import tensorflow as tf

def custom_loss(y_true, y_pred):
    print(y_true.shape)
    '''Just another crossentropy'''
    #y_pred = T.clip(y_pred, epsilon, 1.0 - epsilon)
    #y_pred /= y_pred.sum(axis=-1, keepdims=True)
    #cce = T.nnet.categorical_crossentropy(y_pred, y_true)
    '''
    [np.average
        tf.nn.sparse_softmax_cross_entropy_with_logits(
            labels=y_true[i],
            logits=y_pred[i],
        )
     for i in y_true]
    '''
    return y_true - y_pred

def create_baseline():
    
    activation = 'selu'
    padding = 'same'
    use_bias = True
    layer = 3
    dim = [200, 100, 50, 200, 200, 100]
    kernel = [5, 3, 2, 2, 2, 2]
    strides = [1, 2, 2, 1, 1, ]
    
    inp = Input(shape=(SEQ_LENGTH,NUM_SYMBOL))
    x = Reshape((1, SEQ_LENGTH, NUM_SYMBOL))(inp)
    layers = []
    for i in range(layer):
        x = Conv2D(dim[i], (1, kernel[i]), strides=(1, strides[i]), activation=activation, padding=padding, use_bias=use_bias)(x)
        layers.append(x)

    x = Dense(10, activation='selu')(x)
    x = Flatten()(x)
    y = Flatten()(layers[0])
    x = Concatenate()([x,y])
    x = Dense(300, activation='selu')(x)
    x = Dense(NUM_SYMBOL, activation='softmax')(x)
    model = Model(inp, x)
    opt = Adam(lr=0.002, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0002)
    model.compile(loss='categorical_crossentropy',
              optimizer=opt)
    return model

# %%
model = create_baseline()
model.summary()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_1 (InputLayer)             (None, 32, 97)        0
# ____________________________________________________________________________________________________
# reshape_1 (Reshape)              (None, 1, 32, 97)     0           input_1[0][0]
# ____________________________________________________________________________________________________
# conv2d_1 (Conv2D)                (None, 1, 32, 200)    97200       reshape_1[0][0]
# ____________________________________________________________________________________________________
# conv2d_2 (Conv2D)                (None, 1, 16, 100)    60100       conv2d_1[0][0]
# ____________________________________________________________________________________________________
# conv2d_3 (Conv2D)                (None, 1, 8, 50)      10050       conv2d_2[0][0]
# ____________________________________________________________________________________________________
# dense_1 (Dense)                  (None, 1, 8, 10)      510         conv2d_3[0][0]
# ____________________________________________________________________________________________________
# flatten_1 (Flatten)              (None, 80)            0           dense_1[0][0]
# ____________________________________________________________________________________________________
# flatten_2 (Flatten)              (None, 6400)          0           conv2d_1[0][0]
# ____________________________________________________________________________________________________
# concatenate_1 (Concatenate)      (None, 6480)          0           flatten_1[0][0]
#                                                                    flatten_2[0][0]
# ____________________________________________________________________________________________________
# dense_2 (Dense)                  (None, 300)           1944300     concatenate_1[0][0]
# ____________________________________________________________________________________________________
# dense_3 (Dense)                  (None, 97)            29197       dense_2[0][0]
# ====================================================================================================
# Total params: 2,141,357
# Trainable params: 2,141,357
# Non-trainable params: 0
# ____________________________________________________________________________________________________

# %%
from keras.utils.np_utils import to_categorical

def encode_word(word):
    unpad = batch(s2i, word)
    one_hot = to_categorical(unpad, num_classes=NUM_SYMBOL)
    return one_hot

def decode_word(one_hot):
    return i2s( np.random.choice([i for i in range(NUM_SYMBOL)], p = one_hot)  )
    

# last char is used as output
# so set it like gen = sliding_window(SEQ_LENGTH + 1)(data)
def sample_generator(sliding_window_generator, batch_size = 64):
    data = []
    label = []
    for window in sliding_window_generator:
        data.append(encode_word(window[:-1]))
        label.append(encode_word(window[-1:])[0])
        if len(data) == batch_size:
            yield (np.array(data), np.array(label))
            data = []
            label = []

# %%
window_gen = sliding_window(SEQ_LENGTH + 1)(data)
print(next(sample_generator(window_gen, 2))[0].shape)
print(next(sample_generator(window_gen, 2))[1].shape)
# Out:
# (2, 32, 97)
# (2, 97)

# %%
from keras.callbacks import Callback, ModelCheckpoint
def testing(model):
    seed = """Your child comes home and presents you with a drawing of your house. There's a blue house, a yellow sun, and a green sky. You admire their handiwork and then gently ask why the sky is green. Shouldn't it be blue? Most teachers and parents would have the same reaction, but before you speak, stop! That innocent little comment carries a powerful punch. Unbeknownst to you, you are about to squelch your child's natural developing creativity.
Everyone has the ability to be creative, however, Professor of Biology and neurobiologist Erin Clabough Ph.D. writes that
"creativity can be easily crushed by goals imposed by others."
Not everyone needs to see the world in the same light- and they shouldn't. Before you mention that sky should be blue, consider your reasons carefully. Your child can see that a sky is blue, but in their world it isn't. Allow them the freedom to be creative. Creativity fosters critical thinking and problem solving skills. It helps people to deal with stress and adapt to changes.
"""
    for i in range(500):
        seed = seed + decode_word(model.predict(np.array([encode_word(seed[-SEQ_LENGTH:])]))[0])[0]
        
    print(seed)

class testSample(Callback):
    def on_epoch_end(self, batch, logs={}):
        testing(model)

# %%
from keras_tqdm import TQDMNotebookCallback

mc = ModelCheckpoint('./model/char_cnn_2.hdf5', monitor='loss', verbose=0, save_best_only=True, save_weights_only=False, mode='auto', period=1)


word_gen = word_generator()
BATCH_SIZE = 1024
model.fit_generator(
    sample_generator(window_gen, BATCH_SIZE),
    NUM_SAMPLE // BATCH_SIZE // 100,
    epochs=200000,
    callbacks = [testSample(), mc]
    #verbose=0, callbacks=[TQDMNotebookCallback(), testSample()]
)
# Out:
# Epoch 1/200000
# Your child comes home and presents you with a drawing of your house. There's a blue house, a yellow sun, and a green sky. You admire their handiwork and then gently ask why the sky is green. Shouldn't it be blue? Most teachers and parents would have the same reaction, but before you speak, stop! That innocent little comment carries a powerful punch. Unbeknownst to you, you are about to squelch your child's natural developing creativity.
# Everyone has the ability to be creative, however, Professor of Biology and neurobiologist Erin Clabough Ph.D. writes that
# "creativity can be easily crushed by goals imposed by others."
# Not everyone needs to see the world in the same light- and they shouldn't. Before you mention that sky should be blue, consider your reasons carefully. Your child can see that a sky is blue, but in their world it isn't. Allow them the freedom to be creative. Creativity fosters critical thinking and problem solving skills. It helps people to deal with stress and adapt to changes.
# Kditht exafiust orsconlimy uevitin the comalf maice he say.  he teatledyous inchingitl, ad youl hink und natn iredory nowiy  routand ntaive
# "heandeert.  Sminedsy, aad se wiel ongar"
# tood the
# tupanve y anke har ing ed, suchutins ochepleatd patsuif has ad wouch aly butungink nt alloref Son hall,
# nladssy way headn,--I hable ferrever astinerisid dot saivery withs peat youtd han inghet suld cavedy
# hap edon juvin nof the wallla bu her amanl, bhe is wluther omf youp caplich
# anisif juct anitheppoan nco
# 115/115 [==============================] - 27s - loss: 2.3985
# Epoch 2/200000
# Your child comes home and presents you with a drawing of your house. There's a blue house, a yellow sun, and a green sky. You admire their handiwork and then gently ask why the sky is green. Shouldn't it be blue? Most teachers and parents would have the same reaction, but before you speak, stop! That innocent little comment carries a powerful punch. Unbeknownst to you, you are about to squelch your child's natural developing creativity.
# Everyone has the ability to be creative, however, Professor of Biology and neurobiologist Erin Clabough Ph.D. writes that
# "creativity can be easily crushed by goals imposed by others."
# Not everyone needs to see the world in the same light- and they shouldn't. Before you mention that sky should be blue, consider your reasons carefully. Your child can see that a sky is blue, but in their world it isn't. Allow them the freedom to be creative. Creativity fosters critical thinking and problem solving skills. It helps people to deal with stress and adapt to changes.
# Ang hapmilibefuron him said awnothariest time bathat sancthed sain thouss wasd."
# I naveld thive by test fieg, appliot stoy of.
# THe in as compeof:  honcedfing--
# hes ory peseed
# fathe thene co very ksor
# auplless, thate bast, and musnchtof nissele bid andiend-comizans Is mient. --fouthile my Mrs.GErwa,---I the diedmy,
# tadeny onoth, s beinge in must battou, and atfoy nou meling fuandetor--sulcoubjuyd thimilly, and comestye, wall mme the ory--avary she.
#
# "As Nolhand meot been of Mr. Whidon hepprizing-
# 115/115 [==============================] - 27s - loss: 2.0928
# Epoch 3/200000
# Your child comes home and presents you with a drawing of your house. There's a blue house, a yellow sun, and a green sky. You admire their handiwork and then gently ask why the sky is green. Shouldn't it be blue? Most teachers and parents would have the same reaction, but before you speak, stop! That innocent little comment carries a powerful punch. Unbeknownst to you, you are about to squelch your child's natural developing creativity.
# Everyone has the ability to be creative, however, Professor of Biology and neurobiologist Erin Clabough Ph.D. writes that
# "creativity can be easily crushed by goals imposed by others."
# Not everyone needs to see the world in the same light- and they shouldn't. Before you mention that sky should be blue, consider your reasons carefully. Your child can see that a sky is blue, but in their world it isn't. Allow them the freedom to be creative. Creativity fosters critical thinking and problem solving skills. It helps people to deal with stress and adapt to changes.
#
# Thereched-cond; he salk ow the oll't inethews, at en a dsucer.
#
# "Why one gayeing eranysedwoplt thas _
# geheing her himpsed son, ohe ing batliditisith, herust on wiol ap wilfterable a Hartay han sondiining of
# ochenfore the hioglverieg,  has grol anr,"is teby pactain;
# ant wyou they was mo darpeser atomed to hishem bould oo dered,
# denet haw thourthels wisish wore; ar aalmens suid hat antere iappanorad you."
#
# "eust meall, aid you, wof his contidl,
# breop conout ore quaieblige.  Theye then Bules, ough
# 115/115 [==============================] - 27s - loss: 1.9859
# Epoch 4/200000
# Your child comes home and presents you with a drawing of your house. There's a blue house, a yellow sun, and a green sky. You admire their handiwork and then gently ask why the sky is green. Shouldn't it be blue? Most teachers and parents would have the same reaction, but before you speak, stop! That innocent little comment carries a powerful punch. Unbeknownst to you, you are about to squelch your child's natural developing creativity.
# Everyone has the ability to be creative, however, Professor of Biology and neurobiologist Erin Clabough Ph.D. writes that
# "creativity can be easily crushed by goals imposed by others."
# Not everyone needs to see the world in the same light- and they shouldn't. Before you mention that sky should be blue, consider your reasons carefully. Your child can see that a sky is blue, but in their world it isn't. Allow them the freedom to be creative. Creativity fosters critical thinking and problem solving skills. It helps people to deal with stress and adapt to changes.
#
# of it Emma
# bogh mrouth," so was in forty, whown!--
#
# "Stere wind to my..  You stly he my aif tad hand ros ape ea med
# hanked wor alfiftity he; that wham all ceto sust o thour, poid ther the
# Comen.
# She was os great as powmenttake.  Very do.  Thes
# the teobthit yolf alf y sage aid haverr being
# thest wo gote
# muented be.  They a leake--
# hawo baly cossed was with meranined beer, Affires not that hears, for this ations it to mery.
#
# "They ars tols anssy sfortt nemy her'suran,
# shis mast."
#
# "One iss, Enta
# 115/115 [==============================] - 27s - loss: 1.8807
# Epoch 5/200000
# Your child comes home and presents you with a drawing of your house. There's a blue house, a yellow sun, and a green sky. You admire their handiwork and then gently ask why the sky is green. Shouldn't it be blue? Most teachers and parents would have the same reaction, but before you speak, stop! That innocent little comment carries a powerful punch. Unbeknownst to you, you are about to squelch your child's natural developing creativity.
# Everyone has the ability to be creative, however, Professor of Biology and neurobiologist Erin Clabough Ph.D. writes that
# "creativity can be easily crushed by goals imposed by others."
# Not everyone needs to see the world in the same light- and they shouldn't. Before you mention that sky should be blue, consider your reasons carefully. Your child can see that a sky is blue, but in their world it isn't. Allow them the freedom to be creative. Creativity fosters critical thinking and problem solving skills. It helps people to deal with stress and adapt to changes.
#  Mrs. Weston, and y thank I am
# with a qoiet lich to herd, thw we sharn?  Mrstightear--ounder the simws contan parfees deantiers pand, thank were know uta yom wa sutt I no--sume you had for aghtar a deett not wall it quitety contime!--fith Missowes, shaid surm do bose propertell nich of yhan sarpritthary seed harre. --but do othat one incuse--pooced and mine proaldes thought.--Our yes onttreme, shigh Mrssandses, mush uljuye all
# of miges wathat note all anxirshen?--on werhat to wither fornice ligh
# 115/115 [==============================] - 27s - loss: 1.8278
# Epoch 6/200000
# Your child comes home and presents you with a drawing of your house. There's a blue house, a yellow sun, and a green sky. You admire their handiwork and then gently ask why the sky is green. Shouldn't it be blue? Most teachers and parents would have the same reaction, but before you speak, stop! That innocent little comment carries a powerful punch. Unbeknownst to you, you are about to squelch your child's natural developing creativity.
# Everyone has the ability to be creative, however, Professor of Biology and neurobiologist Erin Clabough Ph.D. writes that
# "creativity can be easily crushed by goals imposed by others."
# Not everyone needs to see the world in the same light- and they shouldn't. Before you mention that sky should be blue, consider your reasons carefully. Your child can see that a sky is blue, but in their world it isn't. Allow them the freedom to be creative. Creativity fosters critical thinking and problem solving skills. It helps people to deal with stress and adapt to changes.
# It misudniciras malied but have band she wicluds to good ho, shourd for bodly be more norssele,
# 's senurfarss ood widh cothout his thad but guch after seallaction thlighs bass,
# such she as you beeved in not unjoke,
# uf he John coulparlack,
# have sa ssfrurares mowneth aspeat rou grout awa.  but inty ray dow have fanted;
# buth her hor, wheadd fremalys lees frem-dind.  So him be whelertleng timine;
# and his thalws of she plity now do; an she rill-himself
# he aid passess as her subed fate.'
#
# "I could not
# 115/115 [==============================] - 27s - loss: 1.7882
# Epoch 7/200000
# Your child comes home and presents you with a drawing of your house. There's a blue house, a yellow sun, and a green sky. You admire their handiwork and then gently ask why the sky is green. Shouldn't it be blue? Most teachers and parents would have the same reaction, but before you speak, stop! That innocent little comment carries a powerful punch. Unbeknownst to you, you are about to squelch your child's natural developing creativity.
# Everyone has the ability to be creative, however, Professor of Biology and neurobiologist Erin Clabough Ph.D. writes that
# "creativity can be easily crushed by goals imposed by others."
# Not everyone needs to see the world in the same light- and they shouldn't. Before you mention that sky should be blue, consider your reasons carefully. Your child can see that a sky is blue, but in their world it isn't. Allow them the freedom to be creative. Creativity fosters critical thinking and problem solving skills. It helps people to deal with stress and adapt to changes.
# He has doom not yourself, the cluamed her mhas moll
# one poonded, mispartent his spenect intted it upprice and oh?  Soikness
# of But evily suldergr epancer.
# Siast hapment, eencon Beses most befincemparning been
# at Ranknow owarns."
#
# "Oh!`Ay!. "As!" Had one, ther juctlaciden hove
# mouthing beranxtren they tive she kit unous ary died.  Tittill, ze begone of have
# in the llied--it ally, ther not
# many
# fealkne her af, mittleme."!
# How Mie]M!"scomed." beed it undeccllsatuon.  Minle!
# of friendsincalbining.
# 115/115 [==============================] - 27s - loss: 1.7410
# Epoch 8/200000
# Your child comes home and presents you with a drawing of your house. There's a blue house, a yellow sun, and a green sky. You admire their handiwork and then gently ask why the sky is green. Shouldn't it be blue? Most teachers and parents would have the same reaction, but before you speak, stop! That innocent little comment carries a powerful punch. Unbeknownst to you, you are about to squelch your child's natural developing creativity.
# Everyone has the ability to be creative, however, Professor of Biology and neurobiologist Erin Clabough Ph.D. writes that
# "creativity can be easily crushed by goals imposed by others."
# Not everyone needs to see the world in the same light- and they shouldn't. Before you mention that sky should be blue, consider your reasons carefully. Your child can see that a sky is blue, but in their world it isn't. Allow them the freedom to be creative. Creativity fosters critical thinking and problem solving skills. It helps people to deal with stress and adapt to changes.
#
# Whet to the stive to wing atty her than
# taccroors profos, thous ferinceiten,
# and ather have the praided go deitupon day,
# that nexperitty ressipaimitiry,
# and sose the betty, an she herwey howh chiss of the have been danit prearcent; and beong hamile such agenation, soweily.  SurnA non borways it by odess periet,
# wherh preter
# acher, by been of thore fich with they fay wruch corned conly oun fuch
# ther appeiner, and that
# as reamh stive could
# to sthe stee sirtections of which,
# hipposs the tare of gu
# 115/115 [==============================] - 27s - loss: 1.7567
# Epoch 9/200000
# Your child comes home and presents you with a drawing of your house. There's a blue house, a yellow sun, and a green sky. You admire their handiwork and then gently ask why the sky is green. Shouldn't it be blue? Most teachers and parents would have the same reaction, but before you speak, stop! That innocent little comment carries a powerful punch. Unbeknownst to you, you are about to squelch your child's natural developing creativity.
# Everyone has the ability to be creative, however, Professor of Biology and neurobiologist Erin Clabough Ph.D. writes that
# "creativity can be easily crushed by goals imposed by others."
# Not everyone needs to see the world in the same light- and they shouldn't. Before you mention that sky should be blue, consider your reasons carefully. Your child can see that a sky is blue, but in their world it isn't. Allow them the freedom to be creative. Creativity fosters critical thinking and problem solving skills. It helps people to deal with stress and adapt to changes.
#
# The wo, and she reconstions condically
# af latihfouther Mrs; Anny's been greess
# to Capfain Wentwoumed wished by adence,
# every resed was stingll be gone her,
# do goout,
# so e plonest oflitadion he ther gettlent herselfoce conoted, we have werowintely pot the utherss;
# and well not fouting of whose.  She all me there reacing of fallacted alrough of tosest to whers; they, the direver
# to Lady Luemer of the woll giness behore what he couthed withoS ancerty gairly roung in the heal eany,
# wing Honliesplas
# 115/115 [==============================] - 27s - loss: 1.6817
# Epoch 10/200000
# Your child comes home and presents you with a drawing of your house. There's a blue house, a yellow sun, and a green sky. You admire their handiwork and then gently ask why the sky is green. Shouldn't it be blue? Most teachers and parents would have the same reaction, but before you speak, stop! That innocent little comment carries a powerful punch. Unbeknownst to you, you are about to squelch your child's natural developing creativity.
# Everyone has the ability to be creative, however, Professor of Biology and neurobiologist Erin Clabough Ph.D. writes that
# "creativity can be easily crushed by goals imposed by others."
# Not everyone needs to see the world in the same light- and they shouldn't. Before you mention that sky should be blue, consider your reasons carefully. Your child can see that a sky is blue, but in their world it isn't. Allow them the freedom to be creative. Creativity fosters critical thinking and problem solving skills. It helps people to deal with stress and adapt to changes.
#
# He lad bother nwaich.
# Indesed wome, I compen's farm it the law yode he suppritune of frillys not,
# as of mome.  Iadis?  A moing, dity in though but all fort, undent buent ar Baust
# worth
# ind enve anrioving seiming it onliott, Buth there; and Mrs littatunnyse.  In mis do visit
# beithee and Tillowan, she okenwy or park no myence, I all and most at I have ine
# everyiple the resotred at possible
# byounged to twill thoweved not consle howed at he knowly was tive otere of Anne?"
#
# "She Mrs Musgroldisyed, b
# 115/115 [==============================] - 27s - loss: 1.6352
# Epoch 11/200000
# Your child comes home and presents you with a drawing of your house. There's a blue house, a yellow sun, and a green sky. You admire their handiwork and then gently ask why the sky is green. Shouldn't it be blue? Most teachers and parents would have the same reaction, but before you speak, stop! That innocent little comment carries a powerful punch. Unbeknownst to you, you are about to squelch your child's natural developing creativity.
# Everyone has the ability to be creative, however, Professor of Biology and neurobiologist Erin Clabough Ph.D. writes that
# "creativity can be easily crushed by goals imposed by others."
# Not everyone needs to see the world in the same light- and they shouldn't. Before you mention that sky should be blue, consider your reasons carefully. Your child can see that a sky is blue, but in their world it isn't. Allow them the freedom to be creative. Creativity fosters critical thinking and problem solving skills. It helps people to deal with stress and adapt to changes.
# It tessiness she herself sundeds with mill envembeding in tround as and him; for unis theusind's landed as Miss
# had to hardulucgived over fether, who --
#
# "This and wifding; for whensfy they be what the statt lolengant mone server such sheir thinkinguess plaised intirestong inther have a ritusefel remayt by conful of Miss Ely alw, him then ingroft to
# friend another intt as Louisa.  She faid a veringstler;
# and very aganden with has; but In towas lether intell of thop's glowarn.  Hit doet by Marly
# 115/115 [==============================] - 27s - loss: 1.5843
# Epoch 12/200000
# Your child comes home and presents you with a drawing of your house. There's a blue house, a yellow sun, and a green sky. You admire their handiwork and then gently ask why the sky is green. Shouldn't it be blue? Most teachers and parents would have the same reaction, but before you speak, stop! That innocent little comment carries a powerful punch. Unbeknownst to you, you are about to squelch your child's natural developing creativity.
# Everyone has the ability to be creative, however, Professor of Biology and neurobiologist Erin Clabough Ph.D. writes that
# "creativity can be easily crushed by goals imposed by others."
# Not everyone needs to see the world in the same light- and they shouldn't. Before you mention that sky should be blue, consider your reasons carefully. Your child can see that a sky is blue, but in their world it isn't. Allow them the freedom to be creative. Creativity fosters critical thinking and problem solving skills. It helps people to deal with stress and adapt to changes.
# Belted and your fay reper, possorneived, fer in memant which in uther oknew
# or Smrews than Mirsands, and whis wishe undy
# was any pookes, ursed herself in said, they of tcomptance
# tractias wemparmany condlaymory placceall and enreint the onhe hoodes whis guid havietancated when instable
# ouch of his bruetain.  On the veming in wheted enoughing had poot
# and rendenfire was a fe hapinfectures oving.
# An Jonn Jabrow's pound, dengald enood,
# I mas the sule sunger.  Hay very, for well,
# as her momether fay
# 115/115 [==============================] - 27s - loss: 1.6267
# Epoch 13/200000
# Your child comes home and presents you with a drawing of your house. There's a blue house, a yellow sun, and a green sky. You admire their handiwork and then gently ask why the sky is green. Shouldn't it be blue? Most teachers and parents would have the same reaction, but before you speak, stop! That innocent little comment carries a powerful punch. Unbeknownst to you, you are about to squelch your child's natural developing creativity.
# Everyone has the ability to be creative, however, Professor of Biology and neurobiologist Erin Clabough Ph.D. writes that
# "creativity can be easily crushed by goals imposed by others."
# Not everyone needs to see the world in the same light- and they shouldn't. Before you mention that sky should be blue, consider your reasons carefully. Your child can see that a sky is blue, but in their world it isn't. Allow them the freedom to be creative. Creativity fosters critical thinking and problem solving skills. It helps people to deal with stress and adapt to changes.
#
# The wearvinathing thoughred in foid to prous
# as consition, he rus dece to on thote
# best of funce for lose bestlent,
# but on though werusgeleaved was senging it it.  Thole out inessibling, he, freep.
#  Misianne's feal veeithing is wortake it prreenstint!
# Pood come walk the fexcinesaired and passon.  I cisisioun--shat to that to come without, withed agpeness ille be nomely--withing
# the is whited lained at onention
# of in oncaure enoughilnes, as more ceitance, he perfoct ot a past tois bounding herfe
# 115/115 [==============================] - 27s - loss: 1.6059
# Epoch 14/200000
# Your child comes home and presents you with a drawing of your house. There's a blue house, a yellow sun, and a green sky. You admire their handiwork and then gently ask why the sky is green. Shouldn't it be blue? Most teachers and parents would have the same reaction, but before you speak, stop! That innocent little comment carries a powerful punch. Unbeknownst to you, you are about to squelch your child's natural developing creativity.
# Everyone has the ability to be creative, however, Professor of Biology and neurobiologist Erin Clabough Ph.D. writes that
# "creativity can be easily crushed by goals imposed by others."
# Not everyone needs to see the world in the same light- and they shouldn't. Before you mention that sky should be blue, consider your reasons carefully. Your child can see that a sky is blue, but in their world it isn't. Allow them the freedom to be creative. Creativity fosters critical thinking and problem solving skills. It helps people to deal with stress and adapt to changes.
#
# HE wxickly her ton have, indo ituaty, whather acquaid."
#
# "It Marianne, grreasured to agrost listertived it, Marianne,
# soon his weel no pooraginy her nothers!  Marianne,
# "as soon of the lewas;
# and Coloness
# vilice sasure lart short Mad. Jenning, Chorous Elinor ofle of ofterficed at alr aimfinent
# from swelt coldoss, I he saefled--it wish it her bount is!  Supposatiout nithouger's expose, and exaut them
# you arleappoing the other.  They addereced attleak to Lady Middleton's anmorning."
#
# "As! Poldad,
# 115/115 [==============================] - 27s - loss: 1.5614
# Epoch 15/200000
# Your child comes home and presents you with a drawing of your house. There's a blue house, a yellow sun, and a green sky. You admire their handiwork and then gently ask why the sky is green. Shouldn't it be blue? Most teachers and parents would have the same reaction, but before you speak, stop! That innocent little comment carries a powerful punch. Unbeknownst to you, you are about to squelch your child's natural developing creativity.
# Everyone has the ability to be creative, however, Professor of Biology and neurobiologist Erin Clabough Ph.D. writes that
# "creativity can be easily crushed by goals imposed by others."
# Not everyone needs to see the world in the same light- and they shouldn't. Before you mention that sky should be blue, consider your reasons carefully. Your child can see that a sky is blue, but in their world it isn't. Allow them the freedom to be creative. Creativity fosters critical thinking and problem solving skills. It helps people to deal with stress and adapt to changes.
#
# The meant her ver, are you made not being of whom thing ening, and Dostrly dince
# to gone thout pare wonce in rece,
# a clitistion, as afford, therefore, edone NOf any
# plocitiain to to properest really Barknow; Fanny's, had preasurill been agone preas,
# compaly that will vady been of iy She
# took onlughter, whit gait this and enough yoursel--it lank--TTRStumpast,
# the Dechal ever, sisped them alf--but gight
# having parkness, folings so many, she prrprainful-lone, a many his deark the bear to proved he
# 115/115 [==============================] - 27s - loss: 1.5641
# Epoch 16/200000
# Your child comes home and presents you with a drawing of your house. There's a blue house, a yellow sun, and a green sky. You admire their handiwork and then gently ask why the sky is green. Shouldn't it be blue? Most teachers and parents would have the same reaction, but before you speak, stop! That innocent little comment carries a powerful punch. Unbeknownst to you, you are about to squelch your child's natural developing creativity.
# Everyone has the ability to be creative, however, Professor of Biology and neurobiologist Erin Clabough Ph.D. writes that
# "creativity can be easily crushed by goals imposed by others."
# Not everyone needs to see the world in the same light- and they shouldn't. Before you mention that sky should be blue, consider your reasons carefully. Your child can see that a sky is blue, but in their world it isn't. Allow them the freedom to be creative. Creativity fosters critical thinking and problem solving skills. It helps people to deal with stress and adapt to changes.
# I cellave'r must inters, to suppose But whethers of
# noty, onatee intindy otly travauthes words, that she timent deairsuley
# was plousunds to from Miss MariansI would
# with lutated them hearged lest dear,
# without of Edwn she whoweved them as hoor eade bawaved on.  Fetty was!--had ing joud
# to hunder in welll
# own, the warl of a rearing hoo newardaids
# in tlist of heard living, when and though they livensinced of them,
# ferted from toe distery twenthers befered to her all
# changemand the Middrivences ana
# 115/115 [==============================] - 27s - loss: 1.5338
# Epoch 17/200000
# Your child comes home and presents you with a drawing of your house. There's a blue house, a yellow sun, and a green sky. You admire their handiwork and then gently ask why the sky is green. Shouldn't it be blue? Most teachers and parents would have the same reaction, but before you speak, stop! That innocent little comment carries a powerful punch. Unbeknownst to you, you are about to squelch your child's natural developing creativity.
# Everyone has the ability to be creative, however, Professor of Biology and neurobiologist Erin Clabough Ph.D. writes that
# "creativity can be easily crushed by goals imposed by others."
# Not everyone needs to see the world in the same light- and they shouldn't. Before you mention that sky should be blue, consider your reasons carefully. Your child can see that a sky is blue, but in their world it isn't. Allow them the freedom to be creative. Creativity fosters critical thinking and problem solving skills. It helps people to deal with stress and adapt to changes.
#
#
# Nothing very hell with were they would be Barty day
# caret ut the murning the not home,
# it sightery wes against ever the has not
# absover to be much Lucy of my tractly for
# pirolforty, resh Whenevenst of his moce
# in to tindly and utiles, and their friendsence
# I by than yetry out has immet--has; but I have neeand it uston,
# when o hir hazicare our vising, without
# would acknowledg in perssifictly could, I was extraisly will
# us in vooity on unquine, ablich at sudd not a fletty,
# I was ine hour, obseov
# 115/115 [==============================] - 27s - loss: 1.5549
# Epoch 18/200000
# Your child comes home and presents you with a drawing of your house. There's a blue house, a yellow sun, and a green sky. You admire their handiwork and then gently ask why the sky is green. Shouldn't it be blue? Most teachers and parents would have the same reaction, but before you speak, stop! That innocent little comment carries a powerful punch. Unbeknownst to you, you are about to squelch your child's natural developing creativity.
# Everyone has the ability to be creative, however, Professor of Biology and neurobiologist Erin Clabough Ph.D. writes that
# "creativity can be easily crushed by goals imposed by others."
# Not everyone needs to see the world in the same light- and they shouldn't. Before you mention that sky should be blue, consider your reasons carefully. Your child can see that a sky is blue, but in their world it isn't. Allow them the freedom to be creative. Creativity fosters critical thinking and problem solving skills. It helps people to deal with stress and adapt to changes.
#
# 25:32 And I my besson to beaughter not  all tween.
#
# 25:26 And the lamelted to preased; Rooke seak.
#
# 26:67 And thause, the daught to the wick at? And I thige as acher digpitel his sold the
# eppindidy; and let usposianc: which mady the
# childlen camess aboarlatime the piin of thing withe nerets, His wastel he was a son; and dethly ads, I: LORD saw trided. He it; and awelt nasted these thay dain.
#
# 25:10 And resself to of Lact, Absah's LORD the witning an Astowam.
#
# 25:16 And this uson the chaslict be
# 115/115 [==============================] - 27s - loss: 1.6934
# Epoch 19/200000
# Your child comes home and presents you with a drawing of your house. There's a blue house, a yellow sun, and a green sky. You admire their handiwork and then gently ask why the sky is green. Shouldn't it be blue? Most teachers and parents would have the same reaction, but before you speak, stop! That innocent little comment carries a powerful punch. Unbeknownst to you, you are about to squelch your child's natural developing creativity.
# Everyone has the ability to be creative, however, Professor of Biology and neurobiologist Erin Clabough Ph.D. writes that
# "creativity can be easily crushed by goals imposed by others."
# Not everyone needs to see the world in the same light- and they shouldn't. Before you mention that sky should be blue, consider your reasons carefully. Your child can see that a sky is blue, but in their world it isn't. Allow them the freedom to be creative. Creativity fosters critical thinking and problem solving skills. It helps people to deal with stress and adapt to changes.
#
# 10:20 And Josebh, secure Hanse dayiuned will give of Egyp thach.
#
# 05 13:10 And us of the agwas with me fataous, and to be pree unto Ephearing nought ti:10:5 Thesred the sand bowed them And, thee, and lake yet is gaid of his me alse: buld, and surd, Rebed unto the pare of the shall severy we, and fuily ingon
# he pade for the bole wands for unto Egypt in the with of I tile,
# and and I lave, w all fir to hond a me.
#
# 21:00 Then they see of Eehp na onoth whill his bock.
#
# 29:10 Me goode w; K cupphed de
# 115/115 [==============================] - 27s - loss: 1.5641
# Epoch 20/200000
# Your child comes home and presents you with a drawing of your house. There's a blue house, a yellow sun, and a green sky. You admire their handiwork and then gently ask why the sky is green. Shouldn't it be blue? Most teachers and parents would have the same reaction, but before you speak, stop! That innocent little comment carries a powerful punch. Unbeknownst to you, you are about to squelch your child's natural developing creativity.
# Everyone has the ability to be creative, however, Professor of Biology and neurobiologist Erin Clabough Ph.D. writes that
# "creativity can be easily crushed by goals imposed by others."
# Not everyone needs to see the world in the same light- and they shouldn't. Before you mention that sky should be blue, consider your reasons carefully. Your child can see that a sky is blue, but in their world it isn't. Allow them the freedom to be creative. Creativity fosters critical thinking and problem solving skills. It helps people to deal with stress and adapt to changes.
#
# 28:22 And thou hality a matred in haugh a tabitaw the langel onesh at that with money that It shalt bett, at haby shall, and belour
# not kpineouther kill be entour.
#
# 28:8 Thou may  bralf the ling shalt time: the of
# bill thou put the chald, accoty mutter, and theith blen
# in the nauploats, in the the bring, and hipinentfor, If fourt may brars, upon in batt, of oathen not be wore an he purpar, and make theRey, and tablen in the han, and Isrally upon wind
# shalt.
#
# 28:34 Thou shalt make of aftan heabo
# 115/115 [==============================] - 27s - loss: 1.4531
# Epoch 21/200000
# Your child comes home and presents you with a drawing of your house. There's a blue house, a yellow sun, and a green sky. You admire their handiwork and then gently ask why the sky is green. Shouldn't it be blue? Most teachers and parents would have the same reaction, but before you speak, stop! That innocent little comment carries a powerful punch. Unbeknownst to you, you are about to squelch your child's natural developing creativity.
# Everyone has the ability to be creative, however, Professor of Biology and neurobiologist Erin Clabough Ph.D. writes that
# "creativity can be easily crushed by goals imposed by others."
# Not everyone needs to see the world in the same light- and they shouldn't. Before you mention that sky should be blue, consider your reasons carefully. Your child can see that a sky is blue, but in their world it isn't. Allow them the freedom to be creative. Creativity fosters critical thinking and problem solving skills. It helps people to deal with stress and adapt to changes.
#
# 13:55 And the prople sut lear own, and twalt house be a grean one the laid in the take than dam anchate that
# the thed so of his he
# shall foenof, and able and fated it is
# east, and the dam ho theid we tood conagu shall tood the preasts have the riain.
#
# 13:44 And the massiffleth in if the bried of an appeadened the ine: it in trot to be
# intad.
#
# 12:4 And if thou rigitions water, in to he skewher of
# it e sta othed, whit, thou chah outh comman.
#
# 213:4 And
# he sprofy to doo the amother shall have the
# 115/115 [==============================] - 27s - loss: 1.3665
# Epoch 22/200000
# Your child comes home and presents you with a drawing of your house. There's a blue house, a yellow sun, and a green sky. You admire their handiwork and then gently ask why the sky is green. Shouldn't it be blue? Most teachers and parents would have the same reaction, but before you speak, stop! That innocent little comment carries a powerful punch. Unbeknownst to you, you are about to squelch your child's natural developing creativity.
# Everyone has the ability to be creative, however, Professor of Biology and neurobiologist Erin Clabough Ph.D. writes that
# "creativity can be easily crushed by goals imposed by others."
# Not everyone needs to see the world in the same light- and they shouldn't. Before you mention that sky should be blue, consider your reasons carefully. Your child can see that a sky is blue, but in their world it isn't. Allow them the freedom to be creative. Creativity fosters critical thinking and problem solving skills. It helps people to deal with stress and adapt to changes.
#
# 7:21 NOoAnd the speak tome wamc offering, 7:77 One of
# monems walken; thungret by wive incelfired
# of the fill of the give of thighone.
#
# 7:79 Ono the service one tepars, shat of the 7imst of thou slad five
# the: 7:73 One
# priest of live monter, twenty y:67 And the LORD speapleave of
# very; nive shekels, five in the of the first ren5:7: 7:56 One sin five eas soicer
# sha water, sheveths of good: 5:16 One a toxe
# saw, of begur the dive feen, five shelly offering, 7:77 One gilven munt of fens unchake glea
# 115/115 [==============================] - 27s - loss: 1.3438
# Epoch 23/200000
# Your child comes home and presents you with a drawing of your house. There's a blue house, a yellow sun, and a green sky. You admire their handiwork and then gently ask why the sky is green. Shouldn't it be blue? Most teachers and parents would have the same reaction, but before you speak, stop! That innocent little comment carries a powerful punch. Unbeknownst to you, you are about to squelch your child's natural developing creativity.
# Everyone has the ability to be creative, however, Professor of Biology and neurobiologist Erin Clabough Ph.D. writes that
# "creativity can be easily crushed by goals imposed by others."
# Not everyone needs to see the world in the same light- and they shouldn't. Before you mention that sky should be blue, consider your reasons carefully. Your child can see that a sky is blue, but in their world it isn't. Allow them the freedom to be creative. Creativity fosters critical thinking and problem solving skills. It helps people to deal with stress and adapt to changes.
# E39:9 And those willowed and went ternand one
# concer thild sayes, and her hoirs defarites, siben shousa lambs for cound
# without of it wordred which it, and ye it gepa turne
# to roseive usroes.
#
# 13:33: 30:18 Every unto kirsh seaks were anly dezireth ow has veose fourt congred the LORD, twen thousand one
# youngating to Joclians; 1all conking the find of inlingh, 3 continuberdurgel even porn or their rambs, and, who kring oElouph wath
# he groughousand tower giver, thoughoute remon the not won
# gathered
# 115/115 [==============================] - 27s - loss: 1.3908
# Epoch 24/200000
# Your child comes home and presents you with a drawing of your house. There's a blue house, a yellow sun, and a green sky. You admire their handiwork and then gently ask why the sky is green. Shouldn't it be blue? Most teachers and parents would have the same reaction, but before you speak, stop! That innocent little comment carries a powerful punch. Unbeknownst to you, you are about to squelch your child's natural developing creativity.
# Everyone has the ability to be creative, however, Professor of Biology and neurobiologist Erin Clabough Ph.D. writes that
# "creativity can be easily crushed by goals imposed by others."
# Not everyone needs to see the world in the same light- and they shouldn't. Before you mention that sky should be blue, consider your reasons carefully. Your child can see that a sky is blue, but in their world it isn't. Allow them the freedom to be creative. Creativity fosters critical thinking and problem solving skills. It helps people to deal with stress and adapt to changes.
#
# 12:2 Fe draten man an the weench day, and shalt have to seven all hit greand; 22:22 I
# to bless or ing ward go with at as into him arne: and but that he
# sin awd every begat is the latse theit was numsh one of the sickewith in his estarly, whother the hath poncy of place with us;
# for young hear I pain, yor, and make
# them, and but ye not agtentreck of they that when:
# 211:22 And ther, I will will goft ince trit;
# is in the sgark into him the LORD, to moyes amsel
# the seeflittly whenst the LORD's thee
# 115/115 [==============================] - 27s - loss: 1.3749
# Epoch 25/200000
# Your child comes home and presents you with a drawing of your house. There's a blue house, a yellow sun, and a green sky. You admire their handiwork and then gently ask why the sky is green. Shouldn't it be blue? Most teachers and parents would have the same reaction, but before you speak, stop! That innocent little comment carries a powerful punch. Unbeknownst to you, you are about to squelch your child's natural developing creativity.
# Everyone has the ability to be creative, however, Professor of Biology and neurobiologist Erin Clabough Ph.D. writes that
# "creativity can be easily crushed by goals imposed by others."
# Not everyone needs to see the world in the same light- and they shouldn't. Before you mention that sky should be blue, consider your reasons carefully. Your child can see that a sky is blue, but in their world it isn't. Allow them the freedom to be creative. Creativity fosters critical thinking and problem solving skills. It helps people to deal with stress and adapt to changes.
#
# 24:25 And it
# weathatherall and the swee away were snoundart, and is to the dan,2
# 4:25 Andisted, for alon therear, and
# cornam as that abopl the bestwonth and wuth the
# swild Joshua shall.
# 13:7 As thathoaly qaited an up that bast brought at at
# out ebests of Aurichants, to call
# ver is sibeBon heach, seithere, the tattterness: the
# Piilshater, which took of Dawain, unter thereon his
# beccus or Mawar; 13:25 And Shhtribes othat dir Gahtam
# werdew, and
# Jesccase wooted whote, and Kenwar be1danded aga; 5:15
# 115/115 [==============================] - 27s - loss: 1.3497
# Epoch 26/200000
# Your child comes home and presents you with a drawing of your house. There's a blue house, a yellow sun, and a green sky. You admire their handiwork and then gently ask why the sky is green. Shouldn't it be blue? Most teachers and parents would have the same reaction, but before you speak, stop! That innocent little comment carries a powerful punch. Unbeknownst to you, you are about to squelch your child's natural developing creativity.
# Everyone has the ability to be creative, however, Professor of Biology and neurobiologist Erin Clabough Ph.D. writes that
# "creativity can be easily crushed by goals imposed by others."
# Not everyone needs to see the world in the same light- and they shouldn't. Before you mention that sky should be blue, consider your reasons carefully. Your child can see that a sky is blue, but in their world it isn't. Allow them the freedom to be creative. Creativity fosters critical thinking and problem solving skills. It helps people to deal with stress and adapt to changes.
#
# 32:15 And the Prilistings over to the mostang to
# him. And he sInwad, be way
# all among Ho
# bram unto sen this .316:
# So wo thas were he as angly were on I have took this his cide of Gah.
#
# 1and my sover in to seven the wrom again himse
# be ning of Stjle.
#
# 16:2 And theriem hus said unto him, And said, Shouh his could not, all thou will whore all his madey: tharkewed was burla
# time
# aparts offer wich repanions of they, and, 21:53 And wherihgs
# down mored heaver pebiled again the came unto him, and sItra
# 115/115 [==============================] - 27s - loss: 1.3929
# Epoch 27/200000
# Your child comes home and presents you with a drawing of your house. There's a blue house, a yellow sun, and a green sky. You admire their handiwork and then gently ask why the sky is green. Shouldn't it be blue? Most teachers and parents would have the same reaction, but before you speak, stop! That innocent little comment carries a powerful punch. Unbeknownst to you, you are about to squelch your child's natural developing creativity.
# Everyone has the ability to be creative, however, Professor of Biology and neurobiologist Erin Clabough Ph.D. writes that
# "creativity can be easily crushed by goals imposed by others."
# Not everyone needs to see the world in the same light- and they shouldn't. Before you mention that sky should be blue, consider your reasons carefully. Your child can see that a sky is blue, but in their world it isn't. Allow them the freedom to be creative. Creativity fosters critical thinking and problem solving skills. It helps people to deal with stress and adapt to changes.
#
# 17:28 Then Ammon to thout sait.
#
# 10:47 Dut of the Philistines utoo, and against his offering?.
# 15:17 Wherefore taken of his side, or said, Abook, tho very;
# put he servaved have the kook of God.
#
# 17:43 And Saul have unturused him, and with Gol? and these, and went seared heavon
# yad himself unto Dived, and of thy servantsland where child: and the
# Philistine armarly, and his land will thou sreave his but unto the children of Adaso, and the Philistine,
# and shall stide, and hood have preest very in
# 115/115 [==============================] - 27s - loss: 1.3662
# Epoch 28/200000
# Your child comes home and presents you with a drawing of your house. There's a blue house, a yellow sun, and a green sky. You admire their handiwork and then gently ask why the sky is green. Shouldn't it be blue? Most teachers and parents would have the same reaction, but before you speak, stop! That innocent little comment carries a powerful punch. Unbeknownst to you, you are about to squelch your child's natural developing creativity.
# Everyone has the ability to be creative, however, Professor of Biology and neurobiologist Erin Clabough Ph.D. writes that
# "creativity can be easily crushed by goals imposed by others."
# Not everyone needs to see the world in the same light- and they shouldn't. Before you mention that sky should be blue, consider your reasons carefully. Your child can see that a sky is blue, but in their world it isn't. Allow them the freedom to be creative. Creativity fosters critical thinking and problem solving skills. It helps people to deal with stress and adapt to changes.
#
# 9:12 But thy before Book aak ware. So b reet and tream
# for the with the said thy said, Arienjedm, the place every, as, and yet again, Behold, I say
# that I liver naugh, is be a to he king.
#
# 12:13 And Nawal rear now fas up acher said, Why weart the lain away that
# I am
# I fish serving appu.
#
# 14:5 And Joab Saelisadon king's Broarmai, every shed so blaid, became to
# they tore, never the then in Jotab anamb to
# Abbils be come up were make him offer Let that which
# booketh, he that is camiai: 3:14 We
# wecl
# 115/115 [==============================] - 26s - loss: 1.3554
# Epoch 29/200000
# Your child comes home and presents you with a drawing of your house. There's a blue house, a yellow sun, and a green sky. You admire their handiwork and then gently ask why the sky is green. Shouldn't it be blue? Most teachers and parents would have the same reaction, but before you speak, stop! That innocent little comment carries a powerful punch. Unbeknownst to you, you are about to squelch your child's natural developing creativity.
# Everyone has the ability to be creative, however, Professor of Biology and neurobiologist Erin Clabough Ph.D. writes that
# "creativity can be easily crushed by goals imposed by others."
# Not everyone needs to see the world in the same light- and they shouldn't. Before you mention that sky should be blue, consider your reasons carefully. Your child can see that a sky is blue, but in their world it isn't. Allow them the freedom to be creative. Creativity fosters critical thinking and problem solving skills. It helps people to deal with stress and adapt to changes.
#
# 11:12 And the king treation gave upon the morrung abut:
# 11:21 For they the sept of golded Israel.
#
# 11:17 For is Solomon; and the heigh of Shishon.
#
# 11:16 And Solomons (God gave bugld out of Egypt.
#
# 11:41 And Marainemen's heas the Solomon to said, Ald amonth the cause of his perpef when at which were had toward and seven unto the kingeth
# whather.
#
# 11:11 And if Esianth was were Benaiah buest of an hime up t2David the
# hild commorjekines, all in Egiton thrayon's harm, and expeels of the maved; not
# 115/115 [==============================] - 27s - loss: 1.3986
# Epoch 30/200000
# Your child comes home and presents you with a drawing of your house. There's a blue house, a yellow sun, and a green sky. You admire their handiwork and then gently ask why the sky is green. Shouldn't it be blue? Most teachers and parents would have the same reaction, but before you speak, stop! That innocent little comment carries a powerful punch. Unbeknownst to you, you are about to squelch your child's natural developing creativity.
# Everyone has the ability to be creative, however, Professor of Biology and neurobiologist Erin Clabough Ph.D. writes that
# "creativity can be easily crushed by goals imposed by others."
# Not everyone needs to see the world in the same light- and they shouldn't. Before you mention that sky should be blue, consider your reasons carefully. Your child can see that a sky is blue, but in their world it isn't. Allow them the freedom to be creative. Creativity fosters critical thinking and problem solving skills. It helps people to deal with stress and adapt to changes.
#
# 10:11 But David and abored toghter it be ying, and lettlemp?  20:40 The lecer came to all me land; behold, the chaluasaboar in the
# anler.
#
# 8:21 And it , and rain a stecaty yet him?
# be anger she had ebirejo; and to the down shall day charge the Bearth.
#
# 10:20 Now the kept of the faty man the filled on him
# told, who his fast reeter? And this thou shalt young all the loth them, that the hath said with the king of Jehah belide; and they
# and the twilt have heaves, made aaga.
#
# 9:11 And he returned al
# 115/115 [==============================] - 27s - loss: 1.2958
# Epoch 31/200000
# ...
# the people asteon, and I will not all the wombsing the worderture me
# fing every, ways in her bains.
#
# 3:21 Sold, ye wise the words and eot them.
#
# 4:32 For the layer man, and let him wickets understanding elle; bot ake thoughts of thy youth strepsth, word, is patceremer of thy
# word, abous our ine mieth.
#
# 2:5 He cutime ye him the barkening, saying, Labmuse will her wi
# 115/115 [==============================] - 27s - loss: 1.3775
# Epoch 38/200000
# Your child comes home and presents you with a drawing of your house. There's a blue house, a yellow sun, and a green sky. You admire their handiwork and then gently ask why the sky is green. Shouldn't it be blue? Most teachers and parents would have the same reaction, but before you speak, stop! That innocent little comment carries a powerful punch. Unbeknownst to you, you are about to squelch your child's natural developing creativity.
# Everyone has the ability to be creative, however, Professor of Biology and neurobiologist Erin Clabough Ph.D. writes that
# "creativity can be easily crushed by goals imposed by others."
# Not everyone needs to see the world in the same light- and they shouldn't. Before you mention that sky should be blue, consider your reasons carefully. Your child can see that a sky is blue, but in their world it isn't. Allow them the freedom to be creative. Creativity fosters critical thinking and problem solving skills. It helps people to deal with stress and adapt to changes.
#
# 2:1
# The told of will smoken my blats; or not thy chies of oldes,
# out of the earth: for he I shall Herudan him headen his own, and that in the concennation.
#
# 2:9 He better but all I daus not wine, and
# should not go a wise; and the regarden the LORD, because of the litte fair of an his own eyes of mirchs: but
# with work night than they coverfor, the lold is holds,
# reither live of thine is praise, 2:5 But it the vissunder, thy fing his is the good's son.
#
# 1:2 For he wwith thee persured mine love, a
# 115/115 [==============================] - 27s - loss: 1.4215
# Epoch 39/200000
# Your child comes home and presents you with a drawing of your house. There's a blue house, a yellow sun, and a green sky. You admire their handiwork and then gently ask why the sky is green. Shouldn't it be blue? Most teachers and parents would have the same reaction, but before you speak, stop! That innocent little comment carries a powerful punch. Unbeknownst to you, you are about to squelch your child's natural developing creativity.
# Everyone has the ability to be creative, however, Professor of Biology and neurobiologist Erin Clabough Ph.D. writes that
# "creativity can be easily crushed by goals imposed by others."
# Not everyone needs to see the world in the same light- and they shouldn't. Before you mention that sky should be blue, consider your reasons carefully. Your child can see that a sky is blue, but in their world it isn't. Allow them the freedom to be creative. Creativity fosters critical thinking and problem solving skills. It helps people to deal with stress and adapt to changes.
#
# 29:25 He known to awfore even, and Isa; from the lengur mains, and
# it shall bund at came unto the LORD, when the good, behold, and my
# me woreat the tpon to the cort to bletted: therefore their
# larm, who blood, and yaught hath remer's day whee, and shall be govenivers, and the monesh: and is the
# rult sees strence, and the uttarleth,
# all thou that eyes people, the mother
# anly.
#
# 26:1 Then lood that their bearward lave trong shall, and ever
# themself: for the Giland, and heardeth a roter boward, and
# 115/115 [==============================] - 26s - loss: 1.3780
# Epoch 40/200000
# Your child comes home and presents you with a drawing of your house. There's a blue house, a yellow sun, and a green sky. You admire their handiwork and then gently ask why the sky is green. Shouldn't it be blue? Most teachers and parents would have the same reaction, but before you speak, stop! That innocent little comment carries a powerful punch. Unbeknownst to you, you are about to squelch your child's natural developing creativity.
# Everyone has the ability to be creative, however, Professor of Biology and neurobiologist Erin Clabough Ph.D. writes that
# "creativity can be easily crushed by goals imposed by others."
# Not everyone needs to see the world in the same light- and they shouldn't. Before you mention that sky should be blue, consider your reasons carefully. Your child can see that a sky is blue, but in their world it isn't. Allow them the freedom to be creative. Creativity fosters critical thinking and problem solving skills. It helps people to deal with stress and adapt to changes.
#
# 9:22 I from their upon us the daughter; the whose is
# saideth.
#
# 2:29 Therefuled the LORD out and all that swemeds seem ob away have: they that cut of the eorsumed the
# heart, take them in a firite of wike mounsaim, and speking, saith the LORD,
# Jehoshame, he prake the gates that came, sut them all name them! but
# withel in jeitit deem, and the wear light
# w6se of his namengarded divise talls; and of the
# vix all their to thumberdunded them it, take stened,
# and the man the gattless the two out thesbre
# 115/115 [==============================] - 27s - loss: 1.3196
# Epoch 41/200000
# Your child comes home and presents you with a drawing of your house. There's a blue house, a yellow sun, and a green sky. You admire their handiwork and then gently ask why the sky is green. Shouldn't it be blue? Most teachers and parents would have the same reaction, but before you speak, stop! That innocent little comment carries a powerful punch. Unbeknownst to you, you are about to squelch your child's natural developing creativity.
# Everyone has the ability to be creative, however, Professor of Biology and neurobiologist Erin Clabough Ph.D. writes that
# "creativity can be easily crushed by goals imposed by others."
# Not everyone needs to see the world in the same light- and they shouldn't. Before you mention that sky should be blue, consider your reasons carefully. Your child can see that a sky is blue, but in their world it isn't. Allow them the freedom to be creative. Creativity fosters critical thinking and problem solving skills. It helps people to deal with stress and adapt to changes.
#
# 32:33 They saidst there out of Ne, that drink to their count
# retarest.
#
# 36:36 Return them that ye make unto thee,
# and the king of Judah, and reek
# up all the king of Bayah, Joromiah laken
# evely her heard plussed into the
# rilies.
#
# 27:5 And the Chaldeants and this not unto the sons unto the pring
# aboved that the chitherities can offering, and to thine of the king ene day king of Babylon the Canannaiah her long: a2
# he manst of yurder anon that I daught Jude adam the pon
# hearken, that also abewer th
# 115/115 [==============================] - 27s - loss: 1.1736
# Epoch 42/200000
# Your child comes home and presents you with a drawing of your house. There's a blue house, a yellow sun, and a green sky. You admire their handiwork and then gently ask why the sky is green. Shouldn't it be blue? Most teachers and parents would have the same reaction, but before you speak, stop! That innocent little comment carries a powerful punch. Unbeknownst to you, you are about to squelch your child's natural developing creativity.
# Everyone has the ability to be creative, however, Professor of Biology and neurobiologist Erin Clabough Ph.D. writes that
# "creativity can be easily crushed by goals imposed by others."
# Not everyone needs to see the world in the same light- and they shouldn't. Before you mention that sky should be blue, consider your reasons carefully. Your child can see that a sky is blue, but in their world it isn't. Allow them the freedom to be creative. Creativity fosters critical thinking and problem solving skills. It helps people to deal with stress and adapt to changes.
#
# 4:5 Bown!  4:23 Sole and there toer sparafied our thee: 5:39 Therefore shall be treadle heaven accomith thee fall saidst thee
# into our man, saith the Lest that there was not sword thou torstend then fill thystricked shall
# the sweanghteal: and thy smade that was against made in
# his filll: and the will put streel.
#
# 5:82 All the blood: for when recrersures; they name, and say by the hand.
#
# 3:7 And there shall me a rongerts of Babylon courrise
# the words.
#
# 6:16 Ich is doise of ted cause, And in
# unde
# 115/115 [==============================] - 26s - loss: 1.2766
# Epoch 43/200000
# Your child comes home and presents you with a drawing of your house. There's a blue house, a yellow sun, and a green sky. You admire their handiwork and then gently ask why the sky is green. Shouldn't it be blue? Most teachers and parents would have the same reaction, but before you speak, stop! That innocent little comment carries a powerful punch. Unbeknownst to you, you are about to squelch your child's natural developing creativity.
# Everyone has the ability to be creative, however, Professor of Biology and neurobiologist Erin Clabough Ph.D. writes that
# "creativity can be easily crushed by goals imposed by others."
# Not everyone needs to see the world in the same light- and they shouldn't. Before you mention that sky should be blue, consider your reasons carefully. Your child can see that a sky is blue, but in their world it isn't. Allow them the freedom to be creative. Creativity fosters critical thinking and problem solving skills. It helps people to deal with stress and adapt to changes.
#
# 33:9 In thee were chalvering look the for which her the sword, ye, say  brought upon the together them spake the son
# of thy meathy, the LORD came unto me, in the neeth all
# the cities upon him: cut shall purfects remon are earth for for be, nor dash that are all
# the sease the hast they shall be for thy
# onession, until which he had moltheres
# recy, O whom the foot her; 89:3 The repon ye than shall he saith; and will all the natisned,
# lelt see shall people dron, which conce and she wicked.
#
# 32:10 F
# 115/115 [==============================] - 26s - loss: 1.2356
# Epoch 44/200000
# Your child comes home and presents you with a drawing of your house. There's a blue house, a yellow sun, and a green sky. You admire their handiwork and then gently ask why the sky is green. Shouldn't it be blue? Most teachers and parents would have the same reaction, but before you speak, stop! That innocent little comment carries a powerful punch. Unbeknownst to you, you are about to squelch your child's natural developing creativity.
# Everyone has the ability to be creative, however, Professor of Biology and neurobiologist Erin Clabough Ph.D. writes that
# "creativity can be easily crushed by goals imposed by others."
# Not everyone needs to see the world in the same light- and they shouldn't. Before you mention that sky should be blue, consider your reasons carefully. Your child can see that a sky is blue, but in their world it isn't. Allow them the freedom to be creative. Creativity fosters critical thinking and problem solving skills. It helps people to deal with stress and adapt to changes.
#
# 5:1 Then Apred, bus Sire up and the loon.
#
# 6:18 Then said, Mirbom, O Kire, saith, and spranself
# asden uphains, and damishus these
# known shall boild; I am his provinen to the stong
# bous and his the cities, out thus God the pornir of accordinge.
#
# 5:8 I that came thou those water of the kings of the house on it be and over upon
# the fat there that made that I dre obed my my people at the north, and a stanner
# that he made to dotinged these was ot Umbar set up unto rorn, and donigh,
# and carmies, Mirt
# 115/115 [==============================] - 26s - loss: 1.2790
# Epoch 45/200000
#  74/115 [==================>...........] - ETA: 9s - loss: 1.3153
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-95449f6bf03a> in <module>()
#      10     NUM_SAMPLE // BATCH_SIZE // 100,
#      11     epochs=200000,
# ---> 12     callbacks = [testSample(), mc]
#      13     #verbose=0, callbacks=[TQDMNotebookCallback(), testSample()]
#      14 )
#
# /home/hoiy927/project/tf_playground/tf_playground/lib/python3.5/site-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      85                 warnings.warn('Update your `' + object_name +
#      86                               '` call to the Keras 2 API: ' + signature, stacklevel=2)
# ---> 87             return func(*args, **kwargs)
#      88         wrapper._original_function = func
#      89         return wrapper
#
# /home/hoiy927/project/tf_playground/tf_playground/lib/python3.5/site-packages/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, initial_epoch)
#    1838                     outs = self.train_on_batch(x, y,
#    1839                                                sample_weight=sample_weight,
# -> 1840                                                class_weight=class_weight)
#    1841
#    1842                     if not isinstance(outs, list):
#
# /home/hoiy927/project/tf_playground/tf_playground/lib/python3.5/site-packages/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight)
#    1563             ins = x + y + sample_weights
#    1564         self._make_train_function()
# -> 1565         outputs = self.train_function(ins)
#    1566         if len(outputs) == 1:
#    1567             return outputs[0]
#
# /home/hoiy927/project/tf_playground/tf_playground/lib/python3.5/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2266         updated = session.run(self.outputs + [self.updates_op],
#    2267                               feed_dict=feed_dict,
# -> 2268                               **self.session_kwargs)
#    2269         return updated[:len(self.outputs)]
#    2270
#
# /home/hoiy927/project/tf_playground/tf_playground/lib/python3.5/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     787     try:
#     788       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 789                          run_metadata_ptr)
#     790       if run_metadata:
#     791         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /home/hoiy927/project/tf_playground/tf_playground/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     995     if final_fetches or final_targets:
#     996       results = self._do_run(handle, final_targets, final_fetches,
# --> 997                              feed_dict_string, options, run_metadata)
#     998     else:
#     999       results = []
#
# /home/hoiy927/project/tf_playground/tf_playground/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1130     if handle is None:
#    1131       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1132                            target_list, options, run_metadata)
#    1133     else:
#    1134       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /home/hoiy927/project/tf_playground/tf_playground/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1137   def _do_call(self, fn, *args):
#    1138     try:
# -> 1139       return fn(*args)
#    1140     except errors.OpError as e:
#    1141       message = compat.as_text(e.message)
#
# /home/hoiy927/project/tf_playground/tf_playground/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1119         return tf_session.TF_Run(session, options,
#    1120                                  feed_dict, fetch_list, target_list,
# -> 1121                                  status, run_metadata)
#    1122
#    1123     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
seed = """Your child comes home and presents you with a drawing of your house. There's a blue house, a yellow sun, and a green sky. You admire their handiwork and then gently ask why the sky is green. Shouldn't it be blue? Most teachers and parents would have the same reaction, but before you speak, stop! That innocent little comment carries a powerful punch. Unbeknownst to you, you are about to squelch your child's natural developing creativity.
Everyone has the ability to be creative, however, Professor of Biology and neurobiologist Erin Clabough Ph.D. writes that
"creativity can be easily crushed by goals imposed by others."
Not everyone needs to see the world in the same light- and they shouldn't. Before you mention that sky should be blue, consider your reasons carefully. Your child can see that a sky is blue, but in their world it isn't. Allow them the freedom to be creative. Creativity fosters critical thinking and problem solving skills. It helps people to deal with stress and adapt to changes.
"""

for i in range(500):
    seed = seed + decode_word(model.predict(np.array([encode_word(seed[-SEQ_LENGTH:])]))[0])[0]
