# %%
from Utils.FS import file
from Utils.tensorflow_helper import show_graph
from nltk.tokenize.punkt import PunktSentenceTokenizer
from nltk.tokenize import word_tokenize
from nltk.corpus import brown
from scipy.sparse import coo_matrix, dok_matrix
from scipy.sparse.linalg import svds
from sklearn.preprocessing import normalize
import matplotlib.pyplot as plt
import numpy as np
from sklearn.manifold import TSNE
from wordcloud import WordCloud
from nltk.corpus import stopwords
import tensorflow as tf
import math
import TextPreprocess.words2dict as words2dict

# %%
np.random.seed(1234)

# %%
sents = brown.sents()
sents = [[token.lower() for token in sent] for sent in sents]
words = brown.words()
words = [word.lower() for word in words]

# %%
print("Number of tokens: {}".format(len(words)))
print("Number of sentences: {}".format(len(sents)))
print("Longest sentences length: {}".format(max([len(sent) for sent in sents])))
MAX_SENTENCE_LENGTH = max([len(sent) for sent in sents])
# Out:
# Number of tokens: 1161192
# Number of sentences: 57340
# Longest sentences length: 180

# %%
words_dict, inv_words_dict = words2dict.convert(words)
print(words_dict['five'])
print(inv_words_dict[334])

words_size = len(words_dict)
print("Number of unique tokens: {}".format(words_size))
# Out:
# 334
# five
# Number of unique tokens: 49815

# %%
def batchPadding(batch, padding_symbol=words_dict['--']):
    size = max([len(record) for record in batch])
    result = np.full((len(batch), size), padding_symbol)
    for i in range(len(batch)):
        result[i][:len(batch[i])] = batch[i]
    return result

# %%
def dataGenerator(sents, words_dict, window_size = 2, batch_size=32, train_length=2, epouch=-1):
    train = []
    label = []
    length = []
    while(epouch < 0 or epouch > 0):
        left_window = [words_dict['--'] for i in range(window_size)]
        target = [words_dict['--'] for i in range(train_length)]
        right_window = [words_dict['--'] for i in range(window_size)]
        for sent in sents:
            for word in sent:
                right_window.append(words_dict[word])
                target.append(right_window.pop(0))
                left_window.append(target.pop(0))
                left_window.pop(0)
                
                for context in left_window + right_window:
                    train.append(list(target))
                    label.append(list([context]))
                    length.append(len(target))
                    if(len(train) == batch_size):
                        yield train, label, length
                        train = []
                        label = []
                        length = []
        epouch -= 1
        print('epouch done...')

# %%
TRAIN_LENGTH = 2
WINDOW_SIZE = 2
BATCH_SIZE = 32

# %%
def visualizeData(generator):
    train, label, length = next(generator)
    for i in range(len(train)):
        print([inv_words_dict[word] for word in train[i]], [inv_words_dict[word] for word in label[i]], length[i])

generator = dataGenerator(sents[:1], words_dict, window_size = 1, batch_size=64, train_length=2)
#print(sents[0])
#visualizeData(generator)

# %%
generator = dataGenerator(sents, words_dict, window_size = WINDOW_SIZE, batch_size=BATCH_SIZE, train_length=TRAIN_LENGTH, epouch=1)
bigram_list = []
for batch_inputs, _, _ in generator:
    bigram_list += ['_'.join([inv_words_dict[idx] for idx in batch_input]) for batch_input in batch_inputs]
        
bigrams_dict, inv_bigrams_dict = words2dict.convert(bigram_list)
# Out:
# epouch done...

# %%
print(len(bigrams_dict))
print(bigrams_dict['good_morning'])
print(inv_bigrams_dict[0])
print(inv_bigrams_dict[1])
print(inv_bigrams_dict[2])
print(inv_bigrams_dict[3])
print(inv_bigrams_dict[4])
print(inv_bigrams_dict[5])
# Out:
# 436002
# 308342
# of_the
# ,_and
# ._the
# in_the
# ,_the
# ._``

# %%
generator = dataGenerator(sents, words_dict, window_size = WINDOW_SIZE, batch_size=BATCH_SIZE, train_length=TRAIN_LENGTH)

# %%
RNN_DIMENSION = [50]
RNN_LAYERS = 1
DIMENSION = 50
VOCABULAY_SIZE = len(words_dict)
NEGATIVE_SAMPLE = 128

# %%
graph = tf.Graph()

with graph.as_default():
    
        inputs = tf.placeholder(tf.int32, (None, None), name = "Input_Sentence_Word_Index")
        #OUT: (batch, time) int32
        
        input_lengths = tf.placeholder(tf.int32, (None), name = "Input_Sentence_Length")
        #OUT: (batch) int32
        
        labels = tf.placeholder(tf.int32, (None, 1), name = "Context_Word_Index")
        #OUT: (batch, 1) int32
        
        batch_size = tf.shape(inputs)[0]
        
        embeddings = tf.Variable(tf.random_uniform([VOCABULAY_SIZE, DIMENSION], -1.0, 1.0), trainable=False, name="Word2Vec")
        
        #IN: (batch, time) int32
        inputs_embed = tf.nn.embedding_lookup(embeddings, inputs, max_norm=1)
        #OUT: (batch, time, dim) float32
        
        #IN: (batch, time, dim) 
        #weights = [tf.Variable(tf.random_uniform([DIMENSION * 2, DIMENSION], minval=-1, maxval=1)) for i in range(RNN_LAYERS)]
        #bias = [tf.Variable(tf.random_uniform([DIMENSION], minval=-1, maxval=1)) for i in range(RNN_LAYERS)]
        
        #nn_input = tf.reshape(inputs_embed, (batch_size, DIMENSION))
        #nn_output = tf.ones((batch_size, DIMENSION))
        #for i in range(RNN_LAYERS):
        #    nn_output = tf.concat([nn_output, nn_input], 1)
        #    nn_output = tf.tanh(tf.matmul(nn_output, weights[i]) + bias[i])
        #out: (batch, DIMENSION)

        #IN: (batch, time, dim) float32
        #rnn_inputs = tf.transpose(inputs_embed, [1, 0, 2])
        rnn_inputs = inputs_embed
        #OUT: (batch, time, dim) float32
        
        with tf.variable_scope("LSTM") as lstm_scope:

            cell = tf.contrib.rnn.LSTMCell(RNN_DIMENSION[-1])        
            #stack = tf.contrib.rnn.MultiRNNCell([tf.contrib.rnn.LSTMCell(RNN_DIMENSION[i]) for i in range(RNN_LAYERS)])

            #rnn_tuple_state = tuple([tf.nn.rnn_cell.LSTMStateTuple(l[i][0], l[i][1]) for i in range(RNN_LAYERS)])

            #cell = tf.contrib.rnn.LSTMCell(DIMENSION, state_is_tuple=True)        
            #cell = tf.contrib.rnn.GRUCell(DIMENSION)
            initial_state = cell.zero_state(batch_size, tf.float32)

            #IN: (batch, time, DIMENSION) float32
            rnn_outputs, rnn_states = tf.nn.dynamic_rnn(cell, rnn_inputs, initial_state=initial_state, sequence_length=input_lengths)
            #OUT: (batch, time, RNN_DIMENSION[-1]) float32
            lstm_variables = tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, scope=lstm_scope.name)
            print(lstm_variables)
        
        
        #IN: (batch, time, RNN_DIMENSION[-1]) float32
        index = tf.range(0, batch_size) * tf.shape(inputs)[1] + (input_lengths - 1)
        rnn_final_state = tf.gather(tf.reshape(rnn_outputs, [-1, RNN_DIMENSION[-1]]), index)
        #rnn_final_state = tf.clip_by_norm(rnn_final_state, 1, axes=[1])
        ###rnn_final_state = tf.gather(tf.reshape(rnn_outputs, [-1, DIMENSION]), index)
        #OUT: (batch, RNN_DIMENSION[-1])
        
        #IN: (batch, DIMENSION)
        nce_weights = tf.Variable(
            tf.truncated_normal([VOCABULAY_SIZE, DIMENSION],
                                stddev=1.0 / math.sqrt(DIMENSION)), name="NCE_Weights", trainable=True)

        nce_biases = tf.Variable(tf.zeros([VOCABULAY_SIZE]), name="NCE_Biases", trainable=True)
        
        loss = tf.reduce_mean(
          tf.nn.nce_loss(weights=nce_weights,
                     biases=nce_biases,
                     labels=labels,
                     inputs=rnn_final_state,
                     num_sampled=NEGATIVE_SAMPLE,
                     num_classes=VOCABULAY_SIZE))

        #optimizer = tf.train.GradientDescentOptimizer(1.0).minimize(loss)
        optimizer = tf.train.MomentumOptimizer(1.0, 0.5).minimize(loss)
        #optimizer = tf.train.AdamOptimizer().minimize(loss)
        
        init = tf.global_variables_initializer()
        saver = tf.train.Saver()
        embeddings_saver = tf.train.Saver({'Words2Vec': embeddings})
        #context = tf.nn.softmax(tf.matmul(rnn_final_state, tf.transpose(nce_weights)) + nce_biases)
# Out:
# [<tf.Variable 'LSTM/rnn/lstm_cell/weights:0' shape=(100, 200) dtype=float32_ref>, <tf.Variable 'LSTM/rnn/lstm_cell/biases:0' shape=(200,) dtype=float32_ref>]
# /home/hoiy927/project/tf_playground/tf_playground/lib/python3.5/site-packages/tensorflow/python/ops/gradients_impl.py:93: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "

# %%
#show_graph(graph.as_graph_def())

# %%
num_steps = 200000
MODEL = './model/Word2Vec-tf-emb-rnn-nce-2.ckpt'
WORDS2VEC_MODEL = './model/brown-Words2Vec-{}.ckpt'.format(DIMENSION)

# %%
def cloestWord(vec, words_vec, count=10, method='cos'):
    if method == 'cos':
        dist = np.array([ sum(vec * words_vec[key]) for key in words_vec.keys()])
        top_ten = dist.argsort()[::-1][:10]
    else:
        dist = np.array([ sum(np.square(np.array(vec) - np.array(words_vec[key]))) for key in words_vec.keys()])
        top_ten = dist.argsort()[:10]
    return [list(words_vec.keys())[i] for i in top_ten]

def cloestWord2(word, emb, count=10, method='cos'):
    return cloestWord3(emb[words_dict[word]], emb, count, method)

def cloestWord3(vec, emb, count=10, method='cos'):
    if method == 'cos':
        dist = np.array([ sum(vec * emb[i]) for i in range(emb.shape[0])])
        # dist: word index -> dist
        
        top = dist.argsort()[::-1][:count]
        # top: ranking -> word index
        
    return [(inv_words_dict[i], "%.2f" % dist[i])  for i in top]

def to_word_indices(words):
    return [words_dict[word] for word in words]

# %%
with tf.Session(graph=graph) as session:
    #init.run()
    #embeddings_saver.restore(session, WORDS2VEC_MODEL)
    saver.restore(session, MODEL)
      
    average_loss = 0
    for step in range(num_steps):
        batch_inputs, batch_labels, batch_input_lengths = next(generator)
        feed_dict = {inputs: batch_inputs, labels: batch_labels, input_lengths: batch_input_lengths}

        _, loss_val = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += loss_val

        if step % 2000 == 0:
            if step > 0:
                average_loss /= 2000
                print('Average loss at step ', step, ': ', average_loss)
                average_loss = 0
                
                emb = embeddings.eval()
                normalize(emb, norm='l2', axis=1, copy=False)
                print('word2vec: ', cloestWord2('two', emb))
                
                dict_list = [[i] for i in range(len(words_dict))]
                dict_list_lengths = [1 for i in range(len(words_dict))]
                emb = rnn_final_state.eval(feed_dict={inputs: dict_list, input_lengths: dict_list_lengths})
                normalize(emb, norm='l2', axis=1, copy=False)
                print('rnn: ', cloestWord2('two', emb))
                
                vec = rnn_final_state.eval(feed_dict={inputs: [to_word_indices(['good', 'morning'])], input_lengths: [2]})
                normalize(vec, norm='l2', axis=1, copy=False)
                print('rnn: ', cloestWord3(vec[0], emb))

                
        if step % 2000 == 0:
            save_path = saver.save(session, MODEL)
            print("Model saved in file: %s" % save_path)
# Out:
# INFO:tensorflow:Restoring parameters from ./model/Word2Vec-tf-emb-rnn-nce-2.ckpt
# Model saved in file: ./model/Word2Vec-tf-emb-rnn-nce-2.ckpt
# Average loss at step  2000 :  5.2352974714
# word2vec:  [('two', '1.00'), ('four', '0.94'), ('three', '0.94'), ('five', '0.92'), ('several', '0.90'), ('six', '0.88'), ('ten', '0.88'), ('few', '0.86'), ('seven', '0.83'), ('fifty', '0.82')]
# rnn:  [('two', '1.00'), ('five', '0.98'), ('three', '0.98'), ('four', '0.97'), ('six', '0.97'), ('pundits', '0.96'), ('85-degrees', '0.96'), ('hundred', '0.96'), ('smallpox', '0.96'), ('cotton', '0.96')]
# rnn:  [('needs', '0.82'), ('nominated', '0.80'), ('secesh', '0.80'), ('polyether', '0.80'), ("tug-o'-war", '0.80'), ('observer', '0.80'), ('emboldened', '0.80'), ('brazil', '0.79'), ('fertilizer', '0.79'), ('faith', '0.79')]
# Model saved in file: ./model/Word2Vec-tf-emb-rnn-nce-2.ckpt
# Average loss at step  4000 :  5.11029439962
# word2vec:  [('two', '1.00'), ('four', '0.94'), ('three', '0.94'), ('five', '0.92'), ('several', '0.90'), ('six', '0.88'), ('ten', '0.88'), ('few', '0.86'), ('seven', '0.83'), ('fifty', '0.82')]
# rnn:  [('two', '1.00'), ('three', '0.98'), ('several', '0.98'), ('four', '0.98'), ('five', '0.97'), ('six', '0.96'), ('contrasts', '0.96'), ('ten', '0.95'), ('seven', '0.94'), ('authoritatively', '0.94')]
# rnn:  [('eqn.', '0.66'), ('nominated', '0.65'), ("tug-o'-war", '0.65'), ('outfield', '0.64'), ('blue-draped', '0.64'), ('needs', '0.64'), ('spatial', '0.63'), ('butte', '0.63'), ('24-hr.', '0.63'), ('accompanist', '0.63')]
# Model saved in file: ./model/Word2Vec-tf-emb-rnn-nce-2.ckpt
# Average loss at step  6000 :  5.13685944343
# word2vec:  [('two', '1.00'), ('four', '0.94'), ('three', '0.94'), ('five', '0.92'), ('several', '0.90'), ('six', '0.88'), ('ten', '0.88'), ('few', '0.86'), ('seven', '0.83'), ('fifty', '0.82')]
# rnn:  [('two', '1.00'), ('three', '0.98'), ('five', '0.97'), ('six', '0.97'), ('contrasts', '0.97'), ('four', '0.97'), ('several', '0.96'), ('filles', '0.96'), ('shipbuilding', '0.96'), ('inshore', '0.96')]
# rnn:  [('trilled', '0.73'), ('directorate', '0.72'), ('waded', '0.71'), ('imperishable', '0.71'), ('bourn', '0.71'), ('contingencies', '0.71'), ('dabbing', '0.71'), ('fantasia', '0.71'), ('andersen', '0.71'), ('hemphill', '0.71')]
# Model saved in file: ./model/Word2Vec-tf-emb-rnn-nce-2.ckpt
# Average loss at step  8000 :  5.32368902624
# word2vec:  [('two', '1.00'), ('four', '0.94'), ('three', '0.94'), ('five', '0.92'), ('several', '0.90'), ('six', '0.88'), ('ten', '0.88'), ('few', '0.86'), ('seven', '0.83'), ('fifty', '0.82')]
# rnn:  [('two', '1.00'), ('three', '0.98'), ('several', '0.97'), ('four', '0.97'), ('five', '0.97'), ('six', '0.96'), ('contrasts', '0.95'), ('inshore', '0.95'), ('i-e', '0.95'), ('shipbuilding', '0.94')]
# rnn:  [('cotman', '0.64'), ('oscillation', '0.64'), ('trilled', '0.63'), ('bourn', '0.63'), ('350', '0.62'), ('directorate', '0.62'), ('baby-dear', '0.62'), ('blue-draped', '0.62'), ('normative', '0.62'), ('mistaking', '0.61')]
# Model saved in file: ./model/Word2Vec-tf-emb-rnn-nce-2.ckpt
# Average loss at step  10000 :  5.32356657887
# word2vec:  [('two', '1.00'), ('four', '0.94'), ('three', '0.94'), ('five', '0.92'), ('several', '0.90'), ('six', '0.88'), ('ten', '0.88'), ('few', '0.86'), ('seven', '0.83'), ('fifty', '0.82')]
# rnn:  [('two', '1.00'), ('three', '0.98'), ('four', '0.97'), ('several', '0.97'), ('five', '0.97'), ('six', '0.96'), ('soignee', '0.95'), ('beige', '0.94'), ('i-e', '0.94'), ('ten', '0.94')]
# rnn:  [('350', '0.70'), ('bourn', '0.69'), ('trilled', '0.69'), ('spatial', '0.69'), ('trinidad', '0.68'), ('blue-draped', '0.68'), ('cotman', '0.68'), ('dabbing', '0.68'), ('oscillation', '0.68'), ('knuckle-duster', '0.68')]
# Model saved in file: ./model/Word2Vec-tf-emb-rnn-nce-2.ckpt
# Average loss at step  12000 :  5.24458662593
# word2vec:  [('two', '1.00'), ('four', '0.94'), ('three', '0.94'), ('five', '0.92'), ('several', '0.90'), ('six', '0.88'), ('ten', '0.88'), ('few', '0.86'), ('seven', '0.83'), ('fifty', '0.82')]
# rnn:  [('two', '1.00'), ('three', '0.98'), ('four', '0.98'), ('several', '0.97'), ('five', '0.97'), ('six', '0.97'), ('soignee', '0.96'), ('other', '0.95'), ('remuneration', '0.95'), ('few', '0.95')]
# rnn:  [('350', '0.73'), ('rim-fires', '0.73'), ('life', '0.73'), ('blue-draped', '0.72'), ('antagonistic', '0.72'), ('bourn', '0.72'), ('rooney', '0.72'), ('exhilarating', '0.72'), ('mcbride', '0.72'), ('polyether', '0.72')]
# Model saved in file: ./model/Word2Vec-tf-emb-rnn-nce-2.ckpt
# Average loss at step  14000 :  5.21550120437
# word2vec:  [('two', '1.00'), ('four', '0.94'), ('three', '0.94'), ('five', '0.92'), ('several', '0.90'), ('six', '0.88'), ('ten', '0.88'), ('few', '0.86'), ('seven', '0.83'), ('fifty', '0.82')]
# rnn:  [('two', '1.00'), ('three', '0.98'), ('four', '0.98'), ('several', '0.97'), ('five', '0.97'), ('six', '0.96'), ('soignee', '0.95'), ('few', '0.94'), ('ten', '0.94'), ('seven', '0.94')]
# rnn:  [('myriad', '0.71'), ('wiles', '0.71'), ('bourn', '0.70'), ('diathermy', '0.70'), ('exhilarating', '0.70'), ('aborigine', '0.70'), ('dabbing', '0.70'), ('oscillation', '0.69'), ("bull's-eyes", '0.69'), ('hansen', '0.69')]
# Model saved in file: ./model/Word2Vec-tf-emb-rnn-nce-2.ckpt
# Average loss at step  16000 :  5.1596674211
# word2vec:  [('two', '1.00'), ('four', '0.94'), ('three', '0.94'), ('five', '0.92'), ('several', '0.90'), ('six', '0.88'), ('ten', '0.88'), ('few', '0.86'), ('seven', '0.83'), ('fifty', '0.82')]
# rnn:  [('two', '1.00'), ('three', '0.98'), ('five', '0.97'), ('four', '0.97'), ('six', '0.97'), ('several', '0.96'), ('few', '0.95'), ('contrasts', '0.95'), ('twenty', '0.95'), ('pundits', '0.94')]
# rnn:  [('bourn', '0.72'), ('myriad', '0.72'), ('blue-draped', '0.72'), ('exhilarating', '0.71'), ('aborigine', '0.71'), ('battery', '0.71'), ('350', '0.71'), ('appeals', '0.71'), ('winehead', '0.71'), ('russians', '0.70')]
# Model saved in file: ./model/Word2Vec-tf-emb-rnn-nce-2.ckpt
# Average loss at step  18000 :  5.22663887417
# word2vec:  [('two', '1.00'), ('four', '0.94'), ('three', '0.94'), ('five', '0.92'), ('several', '0.90'), ('six', '0.88'), ('ten', '0.88'), ('few', '0.86'), ('seven', '0.83'), ('fifty', '0.82')]
# rnn:  [('two', '1.00'), ('three', '0.98'), ('several', '0.97'), ('four', '0.97'), ('five', '0.97'), ('six', '0.95'), ('soignee', '0.94'), ('ten', '0.94'), ('few', '0.94'), ('seven', '0.94')]
# rnn:  [('aborigine', '0.68'), ('blue-draped', '0.68'), ('350', '0.67'), ('myriad', '0.67'), ('fabrics', '0.67'), ('appeals', '0.67'), ('life', '0.66'), ('bourn', '0.66'), ('exhilarating', '0.66'), ('decisional', '0.66')]
# Model saved in file: ./model/Word2Vec-tf-emb-rnn-nce-2.ckpt
# Average loss at step  20000 :  5.17604005933
# word2vec:  [('two', '1.00'), ('four', '0.94'), ('three', '0.94'), ('five', '0.92'), ('several', '0.90'), ('six', '0.88'), ('ten', '0.88'), ('few', '0.86'), ('seven', '0.83'), ('fifty', '0.82')]
# rnn:  [('two', '1.00'), ('three', '0.98'), ('several', '0.98'), ('four', '0.97'), ('five', '0.97'), ('six', '0.96'), ('ten', '0.95'), ('filles', '0.95'), ('twenty', '0.95'), ('contrasts', '0.94')]
# rnn:  [('blue-draped', '0.78'), ('cotman', '0.77'), ('350', '0.77'), ('rim-fires', '0.76'), ('scanty', '0.76'), ('antibiotic', '0.76'), ('dabbing', '0.76'), ('exhilarating', '0.76'), ('thermostatics', '0.76'), ('aborigine', '0.76')]
# Model saved in file: ./model/Word2Vec-tf-emb-rnn-nce-2.ckpt
# Average loss at step  22000 :  5.26679822528
# word2vec:  [('two', '1.00'), ('four', '0.94'), ('three', '0.94'), ('five', '0.92'), ('several', '0.90'), ('six', '0.88'), ('ten', '0.88'), ('few', '0.86'), ('seven', '0.83'), ('fifty', '0.82')]
# rnn:  [('two', '1.00'), ('three', '0.99'), ('four', '0.97'), ('five', '0.97'), ('several', '0.96'), ('six', '0.95'), ('ten', '0.95'), ('contrasts', '0.94'), ('few', '0.94'), ('marylanders', '0.94')]
# rnn:  [('myriad', '0.69'), ('dabbing', '0.69'), ('blue-draped', '0.68'), ('niccolo', '0.68'), ('blockading', '0.68'), ('exhilarating', '0.68'), ('russians', '0.68'), ('x-tru-coat', '0.68'), ('wiles', '0.68'), ('anti-submarine', '0.68')]
# Model saved in file: ./model/Word2Vec-tf-emb-rnn-nce-2.ckpt
# Average loss at step  24000 :  5.1048759135
# word2vec:  [('two', '1.00'), ('four', '0.94'), ('three', '0.94'), ('five', '0.92'), ('several', '0.90'), ('six', '0.88'), ('ten', '0.88'), ('few', '0.86'), ('seven', '0.83'), ('fifty', '0.82')]
# rnn:  [('two', '1.00'), ('three', '0.98'), ('four', '0.98'), ('five', '0.97'), ('several', '0.97'), ('six', '0.95'), ('ten', '0.94'), ('few', '0.94'), ('contrasts', '0.94'), ('pontissara', '0.94')]
# rnn:  [("tug-o'-war", '0.72'), ('350', '0.71'), ('anemia', '0.71'), ('spatial', '0.71'), ('appeals', '0.71'), ('invite', '0.70'), ('omelet', '0.70'), ('directorate', '0.70'), ('skirting', '0.70'), ('handgun', '0.70')]
# Model saved in file: ./model/Word2Vec-tf-emb-rnn-nce-2.ckpt
# Average loss at step  26000 :  5.1777247684
# word2vec:  [('two', '1.00'), ('four', '0.94'), ('three', '0.94'), ('five', '0.92'), ('several', '0.90'), ('six', '0.88'), ('ten', '0.88'), ('few', '0.86'), ('seven', '0.83'), ('fifty', '0.82')]
# rnn:  [('two', '1.00'), ('three', '0.98'), ('four', '0.97'), ('five', '0.97'), ('several', '0.97'), ('six', '0.96'), ('twenty', '0.95'), ('ten', '0.94'), ('contrasts', '0.93'), ('85-degrees', '0.93')]
# rnn:  [('cotman', '0.62'), ('blockading', '0.62'), ('smallness', '0.62'), ('wordy', '0.61'), ('dividend', '0.61'), ('thruways', '0.61'), ('waded', '0.61'), ('by-product', '0.61'), ('macbeth', '0.61'), ('descendant', '0.61')]
# Model saved in file: ./model/Word2Vec-tf-emb-rnn-nce-2.ckpt
# Average loss at step  28000 :  5.21790479457
# word2vec:  [('two', '1.00'), ('four', '0.94'), ('three', '0.94'), ('five', '0.92'), ('several', '0.90'), ('six', '0.88'), ('ten', '0.88'), ('few', '0.86'), ('seven', '0.83'), ('fifty', '0.82')]
# rnn:  [('two', '1.00'), ('three', '0.99'), ('several', '0.98'), ('four', '0.98'), ('five', '0.97'), ('six', '0.97'), ('sleep-wakefulness', '0.95'), ('twenty', '0.95'), ('contrasts', '0.95'), ('triumphant', '0.95')]
# rnn:  [('myriad', '0.73'), ('blockading', '0.71'), ('trilled', '0.70'), ('lurching', '0.69'), ('aborigine', '0.69'), ('exhilarating', '0.69'), ('incarnation', '0.69'), ('directorate', '0.69'), ('dabbing', '0.69'), ('russians', '0.69')]
# Model saved in file: ./model/Word2Vec-tf-emb-rnn-nce-2.ckpt
# Average loss at step  30000 :  5.187290681
# word2vec:  [('two', '1.00'), ('four', '0.94'), ('three', '0.94'), ('five', '0.92'), ('several', '0.90'), ('six', '0.88'), ('ten', '0.88'), ('few', '0.86'), ('seven', '0.83'), ('fifty', '0.82')]
# rnn:  [('two', '1.00'), ('three', '0.98'), ('four', '0.98'), ('several', '0.97'), ('five', '0.97'), ('six', '0.95'), ('contrasts', '0.95'), ('twenty', '0.94'), ('ten', '0.94'), ('triumphant', '0.93')]
# rnn:  [('oscillation', '0.75'), ('trilled', '0.74'), ('blockading', '0.74'), ('ileum', '0.74'), ('fantasia', '0.74'), ('bourn', '0.74'), ('preliminary', '0.74'), ('wordy', '0.73'), ('aborigine', '0.73'), ('350', '0.73')]
# Model saved in file: ./model/Word2Vec-tf-emb-rnn-nce-2.ckpt
# Average loss at step  32000 :  5.21975869107
# word2vec:  [('two', '1.00'), ('four', '0.94'), ('three', '0.94'), ('five', '0.92'), ('several', '0.90'), ('six', '0.88'), ('ten', '0.88'), ('few', '0.86'), ('seven', '0.83'), ('fifty', '0.82')]
# rnn:  [('two', '1.00'), ('three', '0.98'), ('several', '0.98'), ('four', '0.98'), ('five', '0.97'), ('six', '0.96'), ('contrasts', '0.95'), ('sleep-wakefulness', '0.95'), ('remuneration', '0.94'), ('twenty', '0.94')]
# rnn:  [('myriad', '0.79'), ('atheistic', '0.77'), ('bourn', '0.76'), ('exhilarating', '0.76'), ('wiles', '0.76'), ('aborigine', '0.76'), ('350', '0.76'), ('blue-draped', '0.75'), ('appeals', '0.75'), ('ileum', '0.75')]
# Model saved in file: ./model/Word2Vec-tf-emb-rnn-nce-2.ckpt
# Average loss at step  34000 :  5.24099171317
# word2vec:  [('two', '1.00'), ('four', '0.94'), ('three', '0.94'), ('five', '0.92'), ('several', '0.90'), ('six', '0.88'), ('ten', '0.88'), ('few', '0.86'), ('seven', '0.83'), ('fifty', '0.82')]
# rnn:  [('two', '1.00'), ('three', '0.98'), ('four', '0.98'), ('several', '0.97'), ('five', '0.97'), ('six', '0.96'), ('twenty', '0.95'), ('sleep-wakefulness', '0.95'), ('few', '0.94'), ('triumphant', '0.94')]
# rnn:  [('wiles', '0.75'), ('savoyards', '0.75'), ('brain', '0.74'), ('niccolo', '0.74'), ('myriad', '0.74'), ('briefed', '0.74'), ('bludgeon', '0.73'), ('blockading', '0.73'), ('directorate', '0.73'), ('thruways', '0.73')]
# Model saved in file: ./model/Word2Vec-tf-emb-rnn-nce-2.ckpt
# Average loss at step  36000 :  5.14771624589
# word2vec:  [('two', '1.00'), ('four', '0.94'), ('three', '0.94'), ('five', '0.92'), ('several', '0.90'), ('six', '0.88'), ('ten', '0.88'), ('few', '0.86'), ('seven', '0.83'), ('fifty', '0.82')]
# rnn:  [('two', '1.00'), ('three', '0.98'), ('several', '0.98'), ('four', '0.98'), ('five', '0.97'), ('six', '0.97'), ('sleep-wakefulness', '0.97'), ('twenty', '0.95'), ('few', '0.95'), ('triumphant', '0.95')]
# rnn:  [('myriad', '0.78'), ('blockading', '0.78'), ('dilapidated', '0.78'), ('blue-draped', '0.77'), ('directorate', '0.77'), ('thrive', '0.76'), ('platoon', '0.76'), ('buckle', '0.76'), ('do-it-yourself', '0.76'), ('chants', '0.76')]
# Model saved in file: ./model/Word2Vec-tf-emb-rnn-nce-2.ckpt
# Average loss at step  38000 :  5.15100987124
# word2vec:  [('two', '1.00'), ('four', '0.94'), ('three', '0.94'), ('five', '0.92'), ('several', '0.90'), ('six', '0.88'), ('ten', '0.88'), ('few', '0.86'), ('seven', '0.83'), ('fifty', '0.82')]
# rnn:  [('two', '1.00'), ('three', '0.98'), ('four', '0.97'), ('several', '0.97'), ('five', '0.97'), ('six', '0.95'), ('ten', '0.94'), ('soignee', '0.94'), ('few', '0.93'), ('seven', '0.93')]
# rnn:  [('savoyards', '0.76'), ('350', '0.76'), ('sympathetic', '0.75'), ('going-over', '0.75'), ('battery', '0.75'), ('target', '0.75'), ('exhilarating', '0.75'), ('isles', '0.75'), ('preliminary', '0.75'), ('bourn', '0.75')]
# Model saved in file: ./model/Word2Vec-tf-emb-rnn-nce-2.ckpt
# Average loss at step  40000 :  5.12349073803
# word2vec:  [('two', '1.00'), ('four', '0.94'), ('three', '0.94'), ('five', '0.92'), ('several', '0.90'), ('six', '0.88'), ('ten', '0.88'), ('few', '0.86'), ('seven', '0.83'), ('fifty', '0.82')]
# rnn:  [('two', '1.00'), ('three', '0.99'), ('four', '0.98'), ('several', '0.97'), ('five', '0.97'), ('six', '0.96'), ('sleep-wakefulness', '0.95'), ('few', '0.94'), ('ten', '0.94'), ('filles', '0.94')]
# rnn:  [('wiles', '0.73'), ('1879', '0.73'), ('savoyards', '0.72'), ('thruways', '0.72'), ('niccolo', '0.72'), ('directorate', '0.72'), ('blockading', '0.72'), ('wayward', '0.72'), ('sequoia', '0.72'), ('myriad', '0.71')]
# Model saved in file: ./model/Word2Vec-tf-emb-rnn-nce-2.ckpt
# Average loss at step  42000 :  5.31575422001
# word2vec:  [('two', '1.00'), ('four', '0.94'), ('three', '0.94'), ('five', '0.92'), ('several', '0.90'), ('six', '0.88'), ('ten', '0.88'), ('few', '0.86'), ('seven', '0.83'), ('fifty', '0.82')]
# rnn:  [('two', '1.00'), ('three', '0.98'), ('several', '0.98'), ('four', '0.97'), ('five', '0.97'), ('six', '0.96'), ('ten', '0.94'), ('sleep-wakefulness', '0.94'), ('few', '0.93'), ('twenty', '0.93')]
# rnn:  [('wordy', '0.67'), ('ileum', '0.67'), ('slips', '0.66'), ('presentation', '0.66'), ('blue-draped', '0.66'), ('aborigine', '0.66'), ('laundered', '0.66'), ('punishable', '0.66'), ('350', '0.66'), ('southfield', '0.66')]
# Model saved in file: ./model/Word2Vec-tf-emb-rnn-nce-2.ckpt
# epouch done...
# Average loss at step  44000 :  5.42036924398
# word2vec:  [('two', '1.00'), ('four', '0.94'), ('three', '0.94'), ('five', '0.92'), ('several', '0.90'), ('six', '0.88'), ('ten', '0.88'), ('few', '0.86'), ('seven', '0.83'), ('fifty', '0.82')]
# rnn:  [('two', '1.00'), ('three', '0.98'), ('four', '0.98'), ('five', '0.97'), ('several', '0.97'), ('six', '0.96'), ('few', '0.95'), ('pundits', '0.95'), ('soignee', '0.95'), ('ten', '0.94')]
# rnn:  [('savoyards', '0.70'), ("tug-o'-war", '0.70'), ('directorate', '0.69'), ('thruways', '0.69'), ('ainu', '0.69'), ('presentation', '0.68'), ("building's", '0.68'), ('creator', '0.67'), ('unambiguity', '0.67'), ('dividend', '0.67')]
# Model saved in file: ./model/Word2Vec-tf-emb-rnn-nce-2.ckpt
# Average loss at step  46000 :  5.3550092752
# word2vec:  [('two', '1.00'), ('four', '0.94'), ('three', '0.94'), ('five', '0.92'), ('several', '0.90'), ('six', '0.88'), ('ten', '0.88'), ('few', '0.86'), ('seven', '0.83'), ('fifty', '0.82')]
# rnn:  [('two', '1.00'), ('three', '0.98'), ('several', '0.97'), ('four', '0.97'), ('five', '0.97'), ('six', '0.96'), ('contrasts', '0.95'), ('pundits', '0.94'), ('ten', '0.94'), ('twenty', '0.94')]
# rnn:  [('process', '0.71'), ('buckle', '0.71'), ('presentation', '0.71'), ('decisional', '0.71'), ('point', '0.70'), ('anemia', '0.70'), ('problem', '0.70'), ('annum', '0.70'), ('slips', '0.70'), ('stride', '0.70')]
# Model saved in file: ./model/Word2Vec-tf-emb-rnn-nce-2.ckpt
# Average loss at step  48000 :  5.29455674613
# word2vec:  [('two', '1.00'), ('four', '0.94'), ('three', '0.94'), ('five', '0.92'), ('several', '0.90'), ('six', '0.88'), ('ten', '0.88'), ('few', '0.86'), ('seven', '0.83'), ('fifty', '0.82')]
# rnn:  [('two', '1.00'), ('three', '0.98'), ('four', '0.97'), ('five', '0.97'), ('several', '0.96'), ('six', '0.95'), ('ten', '0.94'), ('soignee', '0.94'), ('inshore', '0.94'), ('few', '0.94')]
# rnn:  [('directorate', '0.70'), ("tug-o'-war", '0.69'), ('thruways', '0.68'), ('eqn.', '0.67'), ('savoyards', '0.67'), ('perinetti', '0.67'), ('belted', '0.67'), ('tai', '0.67'), ('toll', '0.67'), ('decisional', '0.67')]
# Model saved in file: ./model/Word2Vec-tf-emb-rnn-nce-2.ckpt
# Average loss at step  50000 :  5.31146876359
# word2vec:  [('two', '1.00'), ('four', '0.94'), ('three', '0.94'), ('five', '0.92'), ('several', '0.90'), ('six', '0.88'), ('ten', '0.88'), ('few', '0.86'), ('seven', '0.83'), ('fifty', '0.82')]
# rnn:  [('two', '1.00'), ('three', '0.98'), ('four', '0.97'), ('five', '0.97'), ('several', '0.96'), ('six', '0.96'), ('smallpox', '0.95'), ('ten', '0.94'), ('mollified', '0.94'), ('twenty', '0.94')]
# rnn:  [('directorate', '0.78'), ('strata', '0.77'), ('going-over', '0.76'), ('ruddiness', '0.76'), ('entrant', '0.76'), ('russians', '0.75'), ('airdrops', '0.75'), ('battery', '0.75'), ('holystones', '0.75'), ('dynamo', '0.75')]
# Model saved in file: ./model/Word2Vec-tf-emb-rnn-nce-2.ckpt
# Average loss at step  52000 :  5.40912244546
# word2vec:  [('two', '1.00'), ('four', '0.94'), ('three', '0.94'), ('five', '0.92'), ('several', '0.90'), ('six', '0.88'), ('ten', '0.88'), ('few', '0.86'), ('seven', '0.83'), ('fifty', '0.82')]
# rnn:  [('two', '1.00'), ('three', '0.98'), ('four', '0.97'), ('five', '0.97'), ('several', '0.97'), ('six', '0.96'), ('twenty', '0.95'), ('ten', '0.94'), ('soignee', '0.94'), ('fifty', '0.94')]
# rnn:  [('bourn', '0.63'), ('dividend', '0.61'), ('thruways', '0.61'), ('normative', '0.60'), ('cotman', '0.60'), ("thet's", '0.60'), ('airdrops', '0.60'), ('condenser', '0.60'), ('trilled', '0.59'), ('350', '0.59')]
# Model saved in file: ./model/Word2Vec-tf-emb-rnn-nce-2.ckpt
# Average loss at step  54000 :  5.3300586102
# word2vec:  [('two', '1.00'), ('four', '0.94'), ('three', '0.94'), ('five', '0.92'), ('several', '0.90'), ('six', '0.88'), ('ten', '0.88'), ('few', '0.86'), ('seven', '0.83'), ('fifty', '0.82')]
# rnn:  [('two', '1.00'), ('three', '0.98'), ('four', '0.96'), ('several', '0.96'), ('five', '0.96'), ('six', '0.94'), ('contrasts', '0.93'), ('seven', '0.93'), ('other', '0.93'), ('sleep-wakefulness', '0.93')]
# rnn:  [('ileum', '0.71'), ('blue-draped', '0.70'), ('bourn', '0.70'), ("mid-1960's", '0.69'), ('350', '0.69'), ('earrings', '0.69'), ('exhilarating', '0.69'), ('s-d', '0.69'), ('trilled', '0.69'), ('aborigine', '0.69')]
# Model saved in file: ./model/Word2Vec-tf-emb-rnn-nce-2.ckpt
# Average loss at step  56000 :  5.37563872516
# word2vec:  [('two', '1.00'), ('four', '0.94'), ('three', '0.94'), ('five', '0.92'), ('several', '0.90'), ('six', '0.88'), ('ten', '0.88'), ('few', '0.86'), ('seven', '0.83'), ('fifty', '0.82')]
# rnn:  [('two', '1.00'), ('three', '0.98'), ('four', '0.97'), ('five', '0.96'), ('several', '0.96'), ('six', '0.95'), ('few', '0.94'), ('soignee', '0.94'), ('ten', '0.94'), ('tahoe', '0.93')]
# rnn:  [('blue-draped', '0.62'), ('unambiguity', '0.62'), ('nominated', '0.61'), ('accompanist', '0.60'), ('methuselahs', '0.60'), ('s-d', '0.60'), ('thruways', '0.60'), ('smallness', '0.60'), ('decisional', '0.60'), ('gator', '0.60')]
# Model saved in file: ./model/Word2Vec-tf-emb-rnn-nce-2.ckpt
# Average loss at step  58000 :  5.37862443995
# word2vec:  [('two', '1.00'), ('four', '0.94'), ('three', '0.94'), ('five', '0.92'), ('several', '0.90'), ('six', '0.88'), ('ten', '0.88'), ('few', '0.86'), ('seven', '0.83'), ('fifty', '0.82')]
# rnn:  [('two', '1.00'), ('three', '0.98'), ('five', '0.97'), ('four', '0.97'), ('several', '0.96'), ('six', '0.95'), ('few', '0.94'), ('ten', '0.94'), ('nordmann', '0.94'), ('sleep-wakefulness', '0.94')]
# rnn:  [('bourn', '0.64'), ('foot-loose', '0.63'), ('hindoo', '0.63'), ('blue-draped', '0.62'), ('tai', '0.62'), ('bhoy', '0.62'), ('cries', '0.62'), ('appeals', '0.62'), ('rim-fires', '0.62'), ('dividend', '0.61')]
# Model saved in file: ./model/Word2Vec-tf-emb-rnn-nce-2.ckpt
# Average loss at step  60000 :  5.39929643416
# word2vec:  [('two', '1.00'), ('four', '0.94'), ('three', '0.94'), ('five', '0.92'), ('several', '0.90'), ('six', '0.88'), ('ten', '0.88'), ('few', '0.86'), ('seven', '0.83'), ('fifty', '0.82')]
# rnn:  [('two', '1.00'), ('three', '0.98'), ('four', '0.97'), ('five', '0.97'), ('several', '0.96'), ('sleep-wakefulness', '0.96'), ('thousand', '0.95'), ('soignee', '0.95'), ('six', '0.95'), ('grains', '0.94')]
# rnn:  [('heyday', '0.58'), ('thruways', '0.57'), ('tai', '0.57'), ('eqn.', '0.57'), ('lavatory', '0.57'), ('1,212', '0.57'), ('rewritten', '0.57'), ("tug-o'-war", '0.57'), ('imposes', '0.56'), ('nominated', '0.56')]
# Model saved in file: ./model/Word2Vec-tf-emb-rnn-nce-2.ckpt
# Average loss at step  62000 :  5.38428771222
# word2vec:  [('two', '1.00'), ('four', '0.94'), ('three', '0.94'), ('five', '0.92'), ('several', '0.90'), ('six', '0.88'), ('ten', '0.88'), ('few', '0.86'), ('seven', '0.83'), ('fifty', '0.82')]
# rnn:  [('two', '1.00'), ('three', '0.98'), ('several', '0.97'), ('sleep-wakefulness', '0.97'), ('four', '0.96'), ('five', '0.96'), ('six', '0.95'), ('contrasts', '0.93'), ('mannerism', '0.93'), ('few', '0.93')]
# rnn:  [('bourn', '0.66'), ('built-detergent', '0.66'), ('flyaway', '0.65'), ('cotman', '0.65'), ('ileum', '0.65'), ('waded', '0.65'), ('airdrops', '0.65'), ('dividend', '0.65'), ('rim-fires', '0.64'), ('blue-draped', '0.64')]
# Model saved in file: ./model/Word2Vec-tf-emb-rnn-nce-2.ckpt
# Average loss at step  64000 :  5.42914368761
# word2vec:  [('two', '1.00'), ('four', '0.94'), ('three', '0.94'), ('five', '0.92'), ('several', '0.90'), ('six', '0.88'), ('ten', '0.88'), ('few', '0.86'), ('seven', '0.83'), ('fifty', '0.82')]
# rnn:  [('two', '1.00'), ('three', '0.98'), ('four', '0.97'), ('several', '0.97'), ('five', '0.96'), ('six', '0.94'), ('few', '0.94'), ('ten', '0.94'), ('omaha', '0.93'), ('other', '0.93')]
# rnn:  [('bourn', '0.63'), ('rooney', '0.61'), ("thet's", '0.61'), ('airdrops', '0.61'), ('smallness', '0.61'), ('robustness', '0.61'), ('rim-fires', '0.61'), ('valuations', '0.60'), ('built-detergent', '0.60'), ('wrinkles', '0.60')]
# Model saved in file: ./model/Word2Vec-tf-emb-rnn-nce-2.ckpt
# Average loss at step  66000 :  5.39081443012
# word2vec:  [('two', '1.00'), ('four', '0.94'), ('three', '0.94'), ('five', '0.92'), ('several', '0.90'), ('six', '0.88'), ('ten', '0.88'), ('few', '0.86'), ('seven', '0.83'), ('fifty', '0.82')]
# rnn:  [('two', '1.00'), ('three', '0.98'), ('five', '0.97'), ('four', '0.97'), ('several', '0.95'), ('six', '0.95'), ('ten', '0.94'), ('few', '0.94'), ('mollified', '0.93'), ('smallpox', '0.93')]
# rnn:  [('rim-fires', '0.68'), ('blue-draped', '0.67'), ('thrive', '0.67'), ('slips', '0.66'), ('s-d', '0.66'), ('toll', '0.66'), ('valuations', '0.66'), ('laundered', '0.66'), ('unambiguity', '0.65'), ('aspiring', '0.65')]
# Model saved in file: ./model/Word2Vec-tf-emb-rnn-nce-2.ckpt
# Average loss at step  68000 :  5.41400280738
# word2vec:  [('two', '1.00'), ('four', '0.94'), ('three', '0.94'), ('five', '0.92'), ('several', '0.90'), ('six', '0.88'), ('ten', '0.88'), ('few', '0.86'), ('seven', '0.83'), ('fifty', '0.82')]
# rnn:  [('two', '1.00'), ('three', '0.98'), ('four', '0.97'), ('several', '0.97'), ('five', '0.96'), ('six', '0.95'), ('sleep-wakefulness', '0.94'), ('seven', '0.94'), ('few', '0.94'), ('obverse', '0.94')]
# rnn:  [('foot-loose', '0.70'), ('sorrentino', '0.69'), ('drains', '0.69'), ('confines', '0.68'), ('theodosian', '0.68'), ('emotionalism', '0.68'), ('suspension', '0.68'), ('arch-heretic', '0.67'), ('underlying', '0.67'), ('first-hand', '0.67')]
# Model saved in file: ./model/Word2Vec-tf-emb-rnn-nce-2.ckpt
# Average loss at step  70000 :  5.29025564456
# word2vec:  [('two', '1.00'), ('four', '0.94'), ('three', '0.94'), ('five', '0.92'), ('several', '0.90'), ('six', '0.88'), ('ten', '0.88'), ('few', '0.86'), ('seven', '0.83'), ('fifty', '0.82')]
# rnn:  [('two', '1.00'), ('three', '0.98'), ('five', '0.97'), ('four', '0.97'), ('several', '0.96'), ('six', '0.95'), ('sleep-wakefulness', '0.95'), ('thousand', '0.94'), ('few', '0.93'), ('ten', '0.93')]
# rnn:  [('350', '0.65'), ('polyether', '0.65'), ('bourn', '0.65'), ('concessionaires', '0.64'), ('airdrops', '0.64'), ('blue-draped', '0.64'), ('telescoping', '0.64'), ('pecked', '0.64'), ('appeals', '0.64'), ('cotman', '0.64')]
# Model saved in file: ./model/Word2Vec-tf-emb-rnn-nce-2.ckpt
# Average loss at step  72000 :  5.25303515446
# word2vec:  [('two', '1.00'), ('four', '0.94'), ('three', '0.94'), ('five', '0.92'), ('several', '0.90'), ('six', '0.88'), ('ten', '0.88'), ('few', '0.86'), ('seven', '0.83'), ('fifty', '0.82')]
# rnn:  [('two', '1.00'), ('three', '0.98'), ('several', '0.97'), ('five', '0.97'), ('four', '0.97'), ('six', '0.96'), ('sleep-wakefulness', '0.96'), ('ten', '0.94'), ('fifty', '0.94'), ('thousand', '0.94')]
# rnn:  [('bourn', '0.61'), ('cotman', '0.59'), ('airdrops', '0.58'), ('waded', '0.58'), ('dividend', '0.58'), ('thruways', '0.58'), ('blue-draped', '0.58'), ('hambric', '0.58'), ('unambiguity', '0.58'), ('trilled', '0.58')]
# Model saved in file: ./model/Word2Vec-tf-emb-rnn-nce-2.ckpt
# Average loss at step  74000 :  5.29253751171
# word2vec:  [('two', '1.00'), ('four', '0.94'), ('three', '0.94'), ('five', '0.92'), ('several', '0.90'), ('six', '0.88'), ('ten', '0.88'), ('few', '0.86'), ('seven', '0.83'), ('fifty', '0.82')]
# rnn:  [('two', '1.00'), ('three', '0.99'), ('five', '0.97'), ('four', '0.97'), ('several', '0.96'), ('six', '0.96'), ('few', '0.95'), ('smallpox', '0.95'), ('den', '0.94'), ('ten', '0.94')]
# rnn:  [('first-hand', '0.57'), ('seafarers', '0.57'), ('mass-building', '0.57'), ('1,212', '0.56'), ('foot-loose', '0.56'), ('flyaway', '0.56'), ("whitman's", '0.55'), ('1819', '0.55'), ('aeration', '0.55'), ('spangled', '0.55')]
# Model saved in file: ./model/Word2Vec-tf-emb-rnn-nce-2.ckpt
# Average loss at step  76000 :  5.23264501667
# word2vec:  [('two', '1.00'), ('four', '0.94'), ('three', '0.94'), ('five', '0.92'), ('several', '0.90'), ('six', '0.88'), ('ten', '0.88'), ('few', '0.86'), ('seven', '0.83'), ('fifty', '0.82')]
# rnn:  [('two', '1.00'), ('three', '0.98'), ('four', '0.97'), ('five', '0.97'), ('several', '0.97'), ('six', '0.95'), ('sleep-wakefulness', '0.95'), ('ten', '0.95'), ('fifty', '0.94'), ('thousand', '0.94')]
# rnn:  [('directorate', '0.75'), ('polyether', '0.75'), ('contretemps', '0.75'), ('rim-fires', '0.75'), ('baby-dear', '0.74'), ('windfall', '0.74'), ('re-creation', '0.74'), ('dabbing', '0.74'), ('chocolate', '0.74'), ('s-d', '0.74')]
# Model saved in file: ./model/Word2Vec-tf-emb-rnn-nce-2.ckpt
# Average loss at step  78000 :  5.20666988719
# word2vec:  [('two', '1.00'), ('four', '0.94'), ('three', '0.94'), ('five', '0.92'), ('several', '0.90'), ('six', '0.88'), ('ten', '0.88'), ('few', '0.86'), ('seven', '0.83'), ('fifty', '0.82')]
# rnn:  [('two', '1.00'), ('three', '0.98'), ('four', '0.97'), ('several', '0.97'), ('five', '0.96'), ('six', '0.95'), ('ten', '0.94'), ('nordmann', '0.94'), ('sleep-wakefulness', '0.94'), ('seven', '0.94')]
# rnn:  [('elusive', '0.65'), ('directorate', '0.65'), ('dividend', '0.64'), ('overtaxed', '0.64'), ('thruways', '0.63'), ('makings', '0.63'), ('shuttled', '0.63'), ('bourn', '0.63'), ('hindoo', '0.63'), ('compounding', '0.63')]
# Model saved in file: ./model/Word2Vec-tf-emb-rnn-nce-2.ckpt
# Average loss at step  80000 :  5.29271519578
# word2vec:  [('two', '1.00'), ('four', '0.94'), ('three', '0.94'), ('five', '0.92'), ('several', '0.90'), ('six', '0.88'), ('ten', '0.88'), ('few', '0.86'), ('seven', '0.83'), ('fifty', '0.82')]
# rnn:  [('two', '1.00'), ('three', '0.98'), ('five', '0.97'), ('several', '0.97'), ('four', '0.97'), ('thousand', '0.96'), ('six', '0.96'), ('ten', '0.95'), ('few', '0.95'), ('obverse', '0.94')]
# rnn:  [('modulated', '0.65'), ("ailey's", '0.65'), ("green's", '0.65'), ('shuttled', '0.65'), ('directorate', '0.64'), ('chagrin', '0.64'), ('precociously', '0.64'), ('top-tang', '0.64'), ('recopied', '0.64'), ('1,419,833', '0.64')]
# Model saved in file: ./model/Word2Vec-tf-emb-rnn-nce-2.ckpt
# Average loss at step  82000 :  5.2107354027
# word2vec:  [('two', '1.00'), ('four', '0.94'), ('three', '0.94'), ('five', '0.92'), ('several', '0.90'), ('six', '0.88'), ('ten', '0.88'), ('few', '0.86'), ('seven', '0.83'), ('fifty', '0.82')]
# rnn:  [('two', '1.00'), ('three', '0.98'), ('five', '0.96'), ('four', '0.96'), ('several', '0.95'), ('six', '0.95'), ('thousand', '0.94'), ('few', '0.94'), ('ten', '0.94'), ('filles', '0.94')]
# rnn:  [('thruways', '0.60'), ('wiles', '0.59'), ('chronicles', '0.59'), ('crimes', '0.59'), ('conductor', '0.59'), ('savoyards', '0.59'), ('neat', '0.59'), ('eros', '0.58'), ('brain', '0.58'), ('elapse', '0.58')]
# Model saved in file: ./model/Word2Vec-tf-emb-rnn-nce-2.ckpt
# Average loss at step  84000 :  5.34516104746
# word2vec:  [('two', '1.00'), ('four', '0.94'), ('three', '0.94'), ('five', '0.92'), ('several', '0.90'), ('six', '0.88'), ('ten', '0.88'), ('few', '0.86'), ('seven', '0.83'), ('fifty', '0.82')]
# rnn:  [('two', '1.00'), ('three', '0.98'), ('four', '0.97'), ('several', '0.97'), ('five', '0.97'), ('six', '0.95'), ('thousand', '0.95'), ('ten', '0.95'), ('sleep-wakefulness', '0.95'), ('few', '0.94')]
# rnn:  [('drains', '0.57'), ('robustness', '0.56'), ('conventionality', '0.56'), ('thrive', '0.56'), ('discriminating', '0.55'), ('$1,450,000,000', '0.55'), ('reconditioning', '0.55'), ('enright', '0.55'), ('bureaucratization', '0.55'), ('sliced', '0.55')]
# Model saved in file: ./model/Word2Vec-tf-emb-rnn-nce-2.ckpt
# Average loss at step  86000 :  5.36280719066
# word2vec:  [('two', '1.00'), ('four', '0.94'), ('three', '0.94'), ('five', '0.92'), ('several', '0.90'), ('six', '0.88'), ('ten', '0.88'), ('few', '0.86'), ('seven', '0.83'), ('fifty', '0.82')]
# rnn:  [('two', '1.00'), ('three', '0.98'), ('four', '0.97'), ('several', '0.96'), ('five', '0.96'), ('six', '0.94'), ('few', '0.94'), ('ten', '0.94'), ('thousand', '0.93'), ('nordmann', '0.93')]
# rnn:  [('rim-fires', '0.66'), ('blue-draped', '0.66'), ('exhilarating', '0.65'), ('polyether', '0.64'), ('communicated', '0.63'), ('bone-weary', '0.63'), ('myriad', '0.63'), ('blockading', '0.63'), ('michilimackinac', '0.63'), ('telescoping', '0.63')]
# Model saved in file: ./model/Word2Vec-tf-emb-rnn-nce-2.ckpt
# Average loss at step  88000 :  5.29253289223
# word2vec:  [('two', '1.00'), ('four', '0.94'), ('three', '0.94'), ('five', '0.92'), ('several', '0.90'), ('six', '0.88'), ('ten', '0.88'), ('few', '0.86'), ('seven', '0.83'), ('fifty', '0.82')]
# rnn:  [('two', '1.00'), ('three', '0.98'), ('five', '0.97'), ('four', '0.97'), ('several', '0.97'), ('six', '0.96'), ('nordmann', '0.95'), ('ten', '0.95'), ('fifty', '0.94'), ('forty', '0.94')]
# rnn:  [('polyether', '0.76'), ('archipelago', '0.75'), ('dostoevsky', '0.75'), ('eqn.', '0.75'), ('anemia', '0.74'), ('wider', '0.74'), ('haggard', '0.74'), ('computation', '0.74'), ('globe', '0.74'), ('gator', '0.74')]
# Model saved in file: ./model/Word2Vec-tf-emb-rnn-nce-2.ckpt
# Average loss at step  90000 :  5.36955066109
# word2vec:  [('two', '1.00'), ('four', '0.94'), ('three', '0.94'), ('five', '0.92'), ('several', '0.90'), ('six', '0.88'), ('ten', '0.88'), ('few', '0.86'), ('seven', '0.83'), ('fifty', '0.82')]
# rnn:  [('two', '1.00'), ('three', '0.98'), ('several', '0.97'), ('five', '0.97'), ('four', '0.97'), ('six', '0.95'), ('sleep-wakefulness', '0.95'), ('obverse', '0.94'), ('nine', '0.94'), ('fifty', '0.94')]
# rnn:  [('polyether', '0.69'), ('bone-weary', '0.68'), ('cute', '0.68'), ('spaces', '0.68'), ('laundered', '0.68'), ('catastrophes', '0.68'), ('dostoevsky', '0.68'), ('mistaking', '0.68'), ('dilapidated', '0.67'), ('concessionaires', '0.67')]
# Model saved in file: ./model/Word2Vec-tf-emb-rnn-nce-2.ckpt
# Average loss at step  92000 :  5.33225366426
# word2vec:  [('two', '1.00'), ('four', '0.94'), ('three', '0.94'), ('five', '0.92'), ('several', '0.90'), ('six', '0.88'), ('ten', '0.88'), ('few', '0.86'), ('seven', '0.83'), ('fifty', '0.82')]
# rnn:  [('two', '1.00'), ('three', '0.98'), ('four', '0.96'), ('several', '0.96'), ('five', '0.96'), ('few', '0.95'), ('six', '0.95'), ('seven', '0.94'), ('ten', '0.94'), ('dispose', '0.94')]
# rnn:  [('communicated', '0.57'), ('aborigine', '0.57'), ('heyday', '0.57'), ('myriad', '0.56'), ('1,212', '0.56'), ('computation', '0.56'), ('polyether', '0.56'), ('smoky', '0.56'), ('robustness', '0.56'), ('life', '0.56')]
# Model saved in file: ./model/Word2Vec-tf-emb-rnn-nce-2.ckpt
# Average loss at step  94000 :  5.21542173362
# word2vec:  [('two', '1.00'), ('four', '0.94'), ('three', '0.94'), ('five', '0.92'), ('several', '0.90'), ('six', '0.88'), ('ten', '0.88'), ('few', '0.86'), ('seven', '0.83'), ('fifty', '0.82')]
# rnn:  [('two', '1.00'), ('three', '0.98'), ('several', '0.98'), ('four', '0.97'), ('five', '0.97'), ('six', '0.96'), ('sleep-wakefulness', '0.96'), ('ten', '0.95'), ('thousand', '0.95'), ('nordmann', '0.95')]
# rnn:  [('rooney', '0.70'), ('dilapidated', '0.69'), ('chocolate', '0.69'), ('hotham', '0.69'), ('polyether', '0.68'), ('myriad', '0.68'), ('lawyer', '0.68'), ('unambiguity', '0.68'), ('reflector', '0.68'), ('dostoevsky', '0.68')]
# Model saved in file: ./model/Word2Vec-tf-emb-rnn-nce-2.ckpt
# Average loss at step  96000 :  5.22625909674
# word2vec:  [('two', '1.00'), ('four', '0.94'), ('three', '0.94'), ('five', '0.92'), ('several', '0.90'), ('six', '0.88'), ('ten', '0.88'), ('few', '0.86'), ('seven', '0.83'), ('fifty', '0.82')]
# rnn:  [('two', '1.00'), ('three', '0.98'), ('five', '0.97'), ('four', '0.97'), ('several', '0.97'), ('six', '0.96'), ('85-degrees', '0.95'), ('smallpox', '0.95'), ('thousand', '0.95'), ('forty', '0.95')]
# rnn:  [('laundered', '0.64'), ('dividend', '0.64'), ('cute', '0.63'), ('smallness', '0.63'), ('grit', '0.63'), ("vidal's", '0.63'), ('dostoevsky', '0.62'), ('accompanist', '0.62'), ('five-day', '0.62'), ('blue-draped', '0.62')]
# Model saved in file: ./model/Word2Vec-tf-emb-rnn-nce-2.ckpt
# Average loss at step  98000 :  5.33193769872
# word2vec:  [('two', '1.00'), ('four', '0.94'), ('three', '0.94'), ('five', '0.92'), ('several', '0.90'), ('six', '0.88'), ('ten', '0.88'), ('few', '0.86'), ('seven', '0.83'), ('fifty', '0.82')]
# rnn:  [('two', '1.00'), ('three', '0.98'), ('four', '0.97'), ('several', '0.96'), ('five', '0.95'), ('few', '0.94'), ('inshore', '0.94'), ('ten', '0.93'), ('obverse', '0.93'), ('frequency-independent', '0.93')]
# rnn:  [('concessionaires', '0.64'), ('rehearsals', '0.63'), ('cute', '0.62'), ('350', '0.62'), ('dostoevsky', '0.62'), ('spaces', '0.62'), ('polyether', '0.61'), ('heyday', '0.61'), ('laborer', '0.61'), ('flicks', '0.61')]
# Model saved in file: ./model/Word2Vec-tf-emb-rnn-nce-2.ckpt
# Average loss at step  100000 :  5.30146306443
# word2vec:  [('two', '1.00'), ('four', '0.94'), ('three', '0.94'), ('five', '0.92'), ('several', '0.90'), ('six', '0.88'), ('ten', '0.88'), ('few', '0.86'), ('seven', '0.83'), ('fifty', '0.82')]
# rnn:  [('two', '1.00'), ('three', '0.98'), ('four', '0.97'), ('several', '0.96'), ('five', '0.95'), ('few', '0.94'), ('soignee', '0.94'), ('delhi', '0.94'), ('ten', '0.94'), ('seven', '0.94')]
# rnn:  [('wiles', '0.60'), ('savoyards', '0.60'), ('thruways', '0.60'), ('wakeful', '0.59'), ('confines', '0.59'), ('bourn', '0.59'), ('transitions', '0.59'), ('synchronous', '0.59'), ('gala', '0.59'), ('conductor', '0.59')]
# Model saved in file: ./model/Word2Vec-tf-emb-rnn-nce-2.ckpt
# Average loss at step  102000 :  5.29984271264
# word2vec:  [('two', '1.00'), ('four', '0.94'), ('three', '0.94'), ('five', '0.92'), ('several', '0.90'), ('six', '0.88'), ('ten', '0.88'), ('few', '0.86'), ('seven', '0.83'), ('fifty', '0.82')]
# rnn:  [('two', '1.00'), ('three', '0.99'), ('four', '0.97'), ('five', '0.97'), ('several', '0.97'), ('six', '0.96'), ('ten', '0.95'), ('sleep-wakefulness', '0.94'), ('few', '0.94'), ('fifty', '0.94')]
# rnn:  [('anti-submarine', '0.71'), ('rooney', '0.71'), ('englishman', '0.71'), ('overtaxed', '0.70'), ('thrive', '0.70'), ('ailey', '0.69'), ('sliced', '0.69'), ('blockading', '0.69'), ('dilapidated', '0.69'), ('bone-weary', '0.69')]
# Model saved in file: ./model/Word2Vec-tf-emb-rnn-nce-2.ckpt
# Average loss at step  104000 :  5.29060818064
# word2vec:  [('two', '1.00'), ('four', '0.94'), ('three', '0.94'), ('five', '0.92'), ('several', '0.90'), ('six', '0.88'), ('ten', '0.88'), ('few', '0.86'), ('seven', '0.83'), ('fifty', '0.82')]
# rnn:  [('two', '1.00'), ('three', '0.98'), ('four', '0.97'), ('five', '0.96'), ('several', '0.96'), ('six', '0.96'), ('seven', '0.95'), ('few', '0.95'), ('ten', '0.94'), ('40', '0.94')]
# rnn:  [('foot-loose', '0.62'), ('prolongs', '0.62'), ('psithyrus', '0.61'), ('recopied', '0.61'), ('drains', '0.61'), ('robustness', '0.61'), ('1,212', '0.60'), ('diathermy', '0.60'), ('underlying', '0.60'), ('riddle', '0.60')]
# Model saved in file: ./model/Word2Vec-tf-emb-rnn-nce-2.ckpt
# Average loss at step  106000 :  5.274722785
# word2vec:  [('two', '1.00'), ('four', '0.94'), ('three', '0.94'), ('five', '0.92'), ('several', '0.90'), ('six', '0.88'), ('ten', '0.88'), ('few', '0.86'), ('seven', '0.83'), ('fifty', '0.82')]
# rnn:  [('two', '1.00'), ('three', '0.98'), ('four', '0.96'), ('five', '0.96'), ('several', '0.95'), ('six', '0.94'), ('ten', '0.94'), ('fifty', '0.94'), ('soignee', '0.93'), ('few', '0.93')]
# rnn:  [('smallness', '0.63'), ('rehearsals', '0.62'), ('flicks', '0.62'), ('polyether', '0.61'), ('dostoevsky', '0.61'), ('laundered', '0.61'), ('concessionaires', '0.61'), ('bomber', '0.61'), ('enfield', '0.61'), ('rooney', '0.60')]
# Model saved in file: ./model/Word2Vec-tf-emb-rnn-nce-2.ckpt
# Average loss at step  108000 :  5.33282994485
# word2vec:  [('two', '1.00'), ('four', '0.94'), ('three', '0.94'), ('five', '0.92'), ('several', '0.90'), ('six', '0.88'), ('ten', '0.88'), ('few', '0.86'), ('seven', '0.83'), ('fifty', '0.82')]
# rnn:  [('two', '1.00'), ('three', '0.99'), ('five', '0.97'), ('four', '0.97'), ('several', '0.96'), ('six', '0.96'), ('ten', '0.95'), ('nordmann', '0.95'), ('few', '0.95'), ('fifty', '0.95')]
# rnn:  [('deliberate', '0.73'), ('richness', '0.73'), ('dilapidated', '0.72'), ('smallness', '0.72'), ('overtaxed', '0.72'), ('advertising', '0.72'), ('350', '0.72'), ('englishman', '0.72'), ('hemphill', '0.72'), ('diluted', '0.72')]
# Model saved in file: ./model/Word2Vec-tf-emb-rnn-nce-2.ckpt
# Average loss at step  110000 :  5.28547286546
# word2vec:  [('two', '1.00'), ('four', '0.94'), ('three', '0.94'), ('five', '0.92'), ('several', '0.90'), ('six', '0.88'), ('ten', '0.88'), ('few', '0.86'), ('seven', '0.83'), ('fifty', '0.82')]
# rnn:  [('two', '1.00'), ('three', '0.98'), ('four', '0.97'), ('five', '0.97'), ('several', '0.96'), ('six', '0.95'), ('thousand', '0.95'), ('ten', '0.95'), ('40', '0.94'), ('nordmann', '0.94')]
# rnn:  [('foot-loose', '0.64'), ('overtaxed', '0.63'), ('semi-circle', '0.63'), ('dostoevsky', '0.63'), ('blockading', '0.63'), ('dunkirk', '0.63'), ('dilapidated', '0.63'), ('myriad', '0.62'), ('hindoo', '0.62'), ('drones', '0.62')]
# Model saved in file: ./model/Word2Vec-tf-emb-rnn-nce-2.ckpt
# Average loss at step  112000 :  5.32967161071
# word2vec:  [('two', '1.00'), ('four', '0.94'), ('three', '0.94'), ('five', '0.92'), ('several', '0.90'), ('six', '0.88'), ('ten', '0.88'), ('few', '0.86'), ('seven', '0.83'), ('fifty', '0.82')]
# rnn:  [('two', '1.00'), ('three', '0.99'), ('four', '0.98'), ('five', '0.97'), ('several', '0.97'), ('six', '0.96'), ('ten', '0.95'), ('sleep-wakefulness', '0.95'), ('nordmann', '0.94'), ('fifty', '0.94')]
# rnn:  [('dilapidated', '0.65'), ('thrive', '0.65'), ('s-d', '0.65'), ('overtaxed', '0.64'), ('anti-submarine', '0.64'), ('blue-draped', '0.64'), ('blockading', '0.63'), ('polyether', '0.63'), ('dostoevsky', '0.63'), ('merit', '0.63')]
# Model saved in file: ./model/Word2Vec-tf-emb-rnn-nce-2.ckpt
# Average loss at step  114000 :  5.27618174517
# word2vec:  [('two', '1.00'), ('four', '0.94'), ('three', '0.94'), ('five', '0.92'), ('several', '0.90'), ('six', '0.88'), ('ten', '0.88'), ('few', '0.86'), ('seven', '0.83'), ('fifty', '0.82')]
# rnn:  [('two', '1.00'), ('three', '0.98'), ('four', '0.97'), ('several', '0.97'), ('five', '0.96'), ('six', '0.94'), ('ten', '0.94'), ('nordmann', '0.94'), ('seven', '0.93'), ('obverse', '0.93')]
# rnn:  [('dividend', '0.65'), ('deteriorates', '0.65'), ('concessionaires', '0.65'), ('dilapidated', '0.65'), ('polyether', '0.65'), ('350', '0.65'), ('laborer', '0.64'), ('computation', '0.64'), ('hotham', '0.64'), ('refunds', '0.64')]
# Model saved in file: ./model/Word2Vec-tf-emb-rnn-nce-2.ckpt
# Average loss at step  116000 :  5.26977753103
# word2vec:  [('two', '1.00'), ('four', '0.94'), ('three', '0.94'), ('five', '0.92'), ('several', '0.90'), ('six', '0.88'), ('ten', '0.88'), ('few', '0.86'), ('seven', '0.83'), ('fifty', '0.82')]
# rnn:  [('two', '1.00'), ('three', '0.98'), ('four', '0.97'), ('five', '0.97'), ('several', '0.96'), ('six', '0.96'), ('ten', '0.95'), ('filles', '0.94'), ('few', '0.94'), ('fifty', '0.94')]
# rnn:  [('blue-draped', '0.71'), ('dostoevsky', '0.70'), ('hemphill', '0.70'), ('heyday', '0.70'), ('polyether', '0.70'), ('dilapidated', '0.68'), ('hambric', '0.68'), ('gator', '0.68'), ('septa', '0.68'), ('diluted', '0.68')]
# Model saved in file: ./model/Word2Vec-tf-emb-rnn-nce-2.ckpt
# Average loss at step  118000 :  5.2698156935
# word2vec:  [('two', '1.00'), ('four', '0.94'), ('three', '0.94'), ('five', '0.92'), ('several', '0.90'), ('six', '0.88'), ('ten', '0.88'), ('few', '0.86'), ('seven', '0.83'), ('fifty', '0.82')]
# rnn:  [('two', '1.00'), ('three', '0.99'), ('four', '0.97'), ('several', '0.97'), ('five', '0.97'), ('few', '0.95'), ('ten', '0.95'), ('six', '0.95'), ('seven', '0.94'), ('soignee', '0.94')]
# rnn:  [('heyday', '0.61'), ('skip', '0.60'), ('wiles', '0.60'), ('communicated', '0.59'), ('hambric', '0.59'), ('polyether', '0.59'), ('computation', '0.59'), ('bourn', '0.59'), ('robustness', '0.59'), ('350', '0.58')]
# Model saved in file: ./model/Word2Vec-tf-emb-rnn-nce-2.ckpt
# Average loss at step  120000 :  5.14318139458
# word2vec:  [('two', '1.00'), ('four', '0.94'), ('three', '0.94'), ('five', '0.92'), ('several', '0.90'), ('six', '0.88'), ('ten', '0.88'), ('few', '0.86'), ('seven', '0.83'), ('fifty', '0.82')]
# rnn:  [('two', '1.00'), ('three', '0.98'), ('several', '0.97'), ('four', '0.97'), ('five', '0.97'), ('six', '0.96'), ('few', '0.95'), ('forty', '0.94'), ('ten', '0.94'), ('seven', '0.94')]
# rnn:  [('directorate', '0.73'), ('dividend', '0.71'), ('hallucinations', '0.71'), ('co-workers', '0.71'), ('pickins', '0.70'), ('macbeth', '0.70'), ('conspiracy', '0.70'), ('savoyards', '0.70'), ('0.85%', '0.70'), ('rhythmically', '0.70')]
# Model saved in file: ./model/Word2Vec-tf-emb-rnn-nce-2.ckpt
# Average loss at step  122000 :  4.9287352792
# word2vec:  [('two', '1.00'), ('four', '0.94'), ('three', '0.94'), ('five', '0.92'), ('several', '0.90'), ('six', '0.88'), ('ten', '0.88'), ('few', '0.86'), ('seven', '0.83'), ('fifty', '0.82')]
# rnn:  [('two', '1.00'), ('three', '0.98'), ('five', '0.96'), ('four', '0.96'), ('few', '0.95'), ('several', '0.95'), ('six', '0.95'), ('ten', '0.93'), ('thousand', '0.93'), ('smallpox', '0.93')]
# rnn:  [('maynard', '0.68'), ('not-a', '0.67'), ('woodcock', '0.67'), ("verloop's", '0.67'), ('disregarded', '0.67'), ('eighteen', '0.67'), ('blue-draped', '0.67'), ('reputations', '0.67'), ('wwrl', '0.67'), ('indoctrinated', '0.67')]
# Model saved in file: ./model/Word2Vec-tf-emb-rnn-nce-2.ckpt
# Average loss at step  124000 :  4.99792782366
# word2vec:  [('two', '1.00'), ('four', '0.94'), ('three', '0.94'), ('five', '0.92'), ('several', '0.90'), ('six', '0.88'), ('ten', '0.88'), ('few', '0.86'), ('seven', '0.83'), ('fifty', '0.82')]
# rnn:  [('two', '1.00'), ('three', '0.98'), ('four', '0.97'), ('five', '0.96'), ('several', '0.96'), ('few', '0.95'), ('delhi', '0.95'), ('brumidi-costaggini', '0.94'), ('six', '0.94'), ('pertinence', '0.94')]
# rnn:  [('thruways', '0.67'), ('cotman', '0.66'), ('dividend', '0.66'), ('trilled', '0.65'), ('macbeth', '0.64'), ('wiles', '0.64'), ('contretemps', '0.64'), ('waded', '0.64'), ('unambiguity', '0.64'), ('dilapidated', '0.64')]
# Model saved in file: ./model/Word2Vec-tf-emb-rnn-nce-2.ckpt
# Average loss at step  126000 :  4.9229165678
# word2vec:  [('two', '1.00'), ('four', '0.94'), ('three', '0.94'), ('five', '0.92'), ('several', '0.90'), ('six', '0.88'), ('ten', '0.88'), ('few', '0.86'), ('seven', '0.83'), ('fifty', '0.82')]
# rnn:  [('two', '1.00'), ('three', '0.98'), ('four', '0.96'), ('several', '0.96'), ('five', '0.96'), ('few', '0.95'), ('six', '0.94'), ('ten', '0.93'), ('seven', '0.93'), ('fifty', '0.93')]
# rnn:  [('merit', '0.66'), ('englishman', '0.65'), ('waded', '0.65'), ('fabrics', '0.65'), ('thruways', '0.65'), ('advertising', '0.64'), ('itching', '0.64'), ('phony', '0.64'), ('device', '0.64'), ('propaganda', '0.64')]
# Model saved in file: ./model/Word2Vec-tf-emb-rnn-nce-2.ckpt
# Average loss at step  128000 :  5.04956760669
# word2vec:  [('two', '1.00'), ('four', '0.94'), ('three', '0.94'), ('five', '0.92'), ('several', '0.90'), ('six', '0.88'), ('ten', '0.88'), ('few', '0.86'), ('seven', '0.83'), ('fifty', '0.82')]
# rnn:  [('two', '1.00'), ('three', '0.98'), ('four', '0.97'), ('five', '0.96'), ('several', '0.96'), ('six', '0.95'), ('few', '0.95'), ('ten', '0.94'), ('fifty', '0.94'), ('forty', '0.94')]
# rnn:  [('biwa', '0.59'), ('crawford', '0.59'), ('childbirth', '0.59'), ('carmichael', '0.59'), ('prepackaged', '0.59'), ('realness', '0.59'), ('modish', '0.59'), ('staggeringly', '0.59'), ('blue-black', '0.58'), ('climax', '0.58')]
# Model saved in file: ./model/Word2Vec-tf-emb-rnn-nce-2.ckpt
# Average loss at step  130000 :  5.03418681598
# word2vec:  [('two', '1.00'), ('four', '0.94'), ('three', '0.94'), ('five', '0.92'), ('several', '0.90'), ('six', '0.88'), ('ten', '0.88'), ('few', '0.86'), ('seven', '0.83'), ('fifty', '0.82')]
# rnn:  [('two', '1.00'), ('three', '0.98'), ('several', '0.97'), ('four', '0.96'), ('five', '0.96'), ('few', '0.96'), ('six', '0.95'), ('ten', '0.94'), ('fifty', '0.94'), ('soignee', '0.94')]
# rnn:  [('reflector', '0.73'), ('anemia', '0.72'), ('flicks', '0.72'), ('dostoevsky', '0.71'), ('consumptive', '0.71'), ('wrecked', '0.71'), ('derision', '0.71'), ('diluted', '0.71'), ('structure', '0.71'), ('position', '0.71')]
# Model saved in file: ./model/Word2Vec-tf-emb-rnn-nce-2.ckpt
# Average loss at step  132000 :  4.96999555564
# word2vec:  [('two', '1.00'), ('four', '0.94'), ('three', '0.94'), ('five', '0.92'), ('several', '0.90'), ('six', '0.88'), ('ten', '0.88'), ('few', '0.86'), ('seven', '0.83'), ('fifty', '0.82')]
# rnn:  [('two', '1.00'), ('three', '0.98'), ('five', '0.96'), ('four', '0.96'), ('few', '0.96'), ('several', '0.95'), ('six', '0.95'), ('ten', '0.94'), ('forty', '0.94'), ('fifty', '0.94')]
# ...
# Model saved in file: ./model/Word2Vec-tf-emb-rnn-nce-2.ckpt
# Average loss at step  156000 :  5.28819899976
# word2vec:  [('two', '1.00'), ('four', '0.94'), ('three', '0.94'), ('five', '0.92'), ('several', '0.90'), ('six', '0.88'), ('ten', '0.88'), ('few', '0.86'), ('seven', '0.83'), ('fifty', '0.82')]
# rnn:  [('two', '1.00'), ('three', '0.98'), ('several', '0.97'), ('four', '0.96'), ('five', '0.96'), ('few', '0.95'), ('delhi', '0.95'), ('soignee', '0.94'), ('seven', '0.94'), ('ten', '0.94')]
# rnn:  [('cotman', '0.68'), ('thermostatics', '0.68'), ('thruways', '0.67'), ('thirty-three', '0.67'), ('trilled', '0.66'), ('contretemps', '0.66'), ('wiles', '0.66'), ('centrifugation', '0.66'), ('indoor', '0.66'), ('1879', '0.66')]
# Model saved in file: ./model/Word2Vec-tf-emb-rnn-nce-2.ckpt
# Average loss at step  158000 :  5.16915150237
# word2vec:  [('two', '1.00'), ('four', '0.94'), ('three', '0.94'), ('five', '0.92'), ('several', '0.90'), ('six', '0.88'), ('ten', '0.88'), ('few', '0.86'), ('seven', '0.83'), ('fifty', '0.82')]
# rnn:  [('two', '1.00'), ('three', '0.98'), ('four', '0.97'), ('several', '0.97'), ('five', '0.96'), ('six', '0.94'), ('filles', '0.94'), ('soignee', '0.94'), ('ten', '0.93'), ('seven', '0.93')]
# rnn:  [('gator', '0.55'), ('anisotropy', '0.55'), ('depersonalized', '0.54'), ('kc.', '0.54'), ('wordy', '0.54'), ('trilled', '0.54'), ('dividend', '0.54'), ('thruways', '0.54'), ('theater-going', '0.54'), ('eight-week', '0.54')]
# Model saved in file: ./model/Word2Vec-tf-emb-rnn-nce-2.ckpt
# Average loss at step  160000 :  5.13829437554
# word2vec:  [('two', '1.00'), ('four', '0.94'), ('three', '0.94'), ('five', '0.92'), ('several', '0.90'), ('six', '0.88'), ('ten', '0.88'), ('few', '0.86'), ('seven', '0.83'), ('fifty', '0.82')]
# rnn:  [('two', '1.00'), ('three', '0.98'), ('four', '0.97'), ('several', '0.96'), ('five', '0.96'), ('soignee', '0.94'), ('few', '0.94'), ('ten', '0.94'), ('six', '0.93'), ('seven', '0.93')]
# rnn:  [('diathermy', '0.65'), ('bourn', '0.64'), ('trinidad', '0.64'), ('decisional', '0.64'), ('fantasia', '0.63'), ('cotman', '0.63'), ('overloaded', '0.63'), ('deteriorates', '0.63'), ('thruways', '0.63'), ('dabbing', '0.63')]
# Model saved in file: ./model/Word2Vec-tf-emb-rnn-nce-2.ckpt
# Average loss at step  162000 :  5.12900520861
# word2vec:  [('two', '1.00'), ('four', '0.94'), ('three', '0.94'), ('five', '0.92'), ('several', '0.90'), ('six', '0.88'), ('ten', '0.88'), ('few', '0.86'), ('seven', '0.83'), ('fifty', '0.82')]
# rnn:  [('two', '1.00'), ('three', '0.98'), ('four', '0.97'), ('several', '0.96'), ('five', '0.96'), ('six', '0.95'), ('soignee', '0.94'), ('obverse', '0.93'), ('filles', '0.93'), ('few', '0.93')]
# rnn:  [('decisional', '0.61'), ('thruways', '0.61'), ('punishable', '0.61'), ('pathologist', '0.60'), ('blue-draped', '0.60'), ('embattled', '0.59'), ("beethoven's", '0.59'), ('cotman', '0.59'), ('gator', '0.59'), ('pietism', '0.59')]
# Model saved in file: ./model/Word2Vec-tf-emb-rnn-nce-2.ckpt
# Average loss at step  164000 :  5.18131585395
# word2vec:  [('two', '1.00'), ('four', '0.94'), ('three', '0.94'), ('five', '0.92'), ('several', '0.90'), ('six', '0.88'), ('ten', '0.88'), ('few', '0.86'), ('seven', '0.83'), ('fifty', '0.82')]
# rnn:  [('two', '1.00'), ('three', '0.99'), ('several', '0.97'), ('four', '0.97'), ('five', '0.96'), ('six', '0.95'), ('filles', '0.94'), ('few', '0.94'), ('ten', '0.94'), ('obverse', '0.94')]
# rnn:  [('myriad', '0.71'), ('diathermy', '0.71'), ('cotman', '0.70'), ('350', '0.70'), ('hotham', '0.69'), ('overtaxed', '0.69'), ('wiles', '0.69'), ('adore', '0.68'), ('directorate', '0.68'), ('auditorium', '0.68')]
# Model saved in file: ./model/Word2Vec-tf-emb-rnn-nce-2.ckpt
# Average loss at step  166000 :  5.15784042418
# word2vec:  [('two', '1.00'), ('four', '0.94'), ('three', '0.94'), ('five', '0.92'), ('several', '0.90'), ('six', '0.88'), ('ten', '0.88'), ('few', '0.86'), ('seven', '0.83'), ('fifty', '0.82')]
# rnn:  [('two', '1.00'), ('three', '0.98'), ('several', '0.97'), ('four', '0.96'), ('five', '0.95'), ('six', '0.94'), ('few', '0.94'), ('soignee', '0.93'), ('filles', '0.93'), ('forty', '0.93')]
# rnn:  [('blockading', '0.76'), ('savoyards', '0.76'), ('thruways', '0.75'), ('myriad', '0.75'), ('russians', '0.74'), ('smallness', '0.74'), ('1879', '0.74'), ('waded', '0.74'), ('directorate', '0.74'), ('dualism', '0.74')]
# Model saved in file: ./model/Word2Vec-tf-emb-rnn-nce-2.ckpt
# Average loss at step  168000 :  5.1924482435
# word2vec:  [('two', '1.00'), ('four', '0.94'), ('three', '0.94'), ('five', '0.92'), ('several', '0.90'), ('six', '0.88'), ('ten', '0.88'), ('few', '0.86'), ('seven', '0.83'), ('fifty', '0.82')]
# rnn:  [('two', '1.00'), ('three', '0.98'), ('four', '0.97'), ('several', '0.97'), ('five', '0.95'), ('soignee', '0.94'), ('ten', '0.94'), ('seven', '0.94'), ('obverse', '0.94'), ('few', '0.93')]
# rnn:  [('blacksmith', '0.62'), ('fantasia', '0.61'), ('deteriorates', '0.61'), ('trinidad', '0.61'), ('michilimackinac', '0.60'), ('cotman', '0.60'), ('improbably', '0.60'), ('diathermy', '0.60'), ('hambric', '0.60'), ('overloaded', '0.60')]
# Model saved in file: ./model/Word2Vec-tf-emb-rnn-nce-2.ckpt
# Average loss at step  170000 :  5.09382726777
# word2vec:  [('two', '1.00'), ('four', '0.94'), ('three', '0.94'), ('five', '0.92'), ('several', '0.90'), ('six', '0.88'), ('ten', '0.88'), ('few', '0.86'), ('seven', '0.83'), ('fifty', '0.82')]
# rnn:  [('two', '1.00'), ('three', '0.98'), ('four', '0.97'), ('five', '0.96'), ('several', '0.96'), ('few', '0.95'), ('six', '0.95'), ('soignee', '0.94'), ('ten', '0.94'), ('delhi', '0.94')]
# rnn:  [('thruways', '0.55'), ('cotman', '0.54'), ('feller', '0.53'), ('decisional', '0.53'), ('fantasia', '0.53'), ('dilapidated', '0.53'), ('dabbing', '0.53'), ('anti-submarine', '0.53'), ('bourn', '0.52'), ('wiles', '0.52')]
# Model saved in file: ./model/Word2Vec-tf-emb-rnn-nce-2.ckpt
# Average loss at step  172000 :  5.14794557595
# word2vec:  [('two', '1.00'), ('four', '0.94'), ('three', '0.94'), ('five', '0.92'), ('several', '0.90'), ('six', '0.88'), ('ten', '0.88'), ('few', '0.86'), ('seven', '0.83'), ('fifty', '0.82')]
# rnn:  [('two', '1.00'), ('three', '0.98'), ('four', '0.96'), ('several', '0.96'), ('five', '0.96'), ('few', '0.94'), ('six', '0.94'), ('soignee', '0.94'), ('ten', '0.93'), ('filles', '0.93')]
# rnn:  [('1879', '0.66'), ('wiles', '0.66'), ('thruways', '0.66'), ('blockading', '0.66'), ("hodges'", '0.65'), ('artistry', '0.65'), ('anti-submarine', '0.65'), ('sliced', '0.65'), ('wayward', '0.64'), ('public-limit', '0.64')]
# Model saved in file: ./model/Word2Vec-tf-emb-rnn-nce-2.ckpt
# Average loss at step  174000 :  5.21212950635
# word2vec:  [('two', '1.00'), ('four', '0.94'), ('three', '0.94'), ('five', '0.92'), ('several', '0.90'), ('six', '0.88'), ('ten', '0.88'), ('few', '0.86'), ('seven', '0.83'), ('fifty', '0.82')]
# rnn:  [('two', '1.00'), ('three', '0.98'), ('several', '0.97'), ('four', '0.97'), ('five', '0.96'), ('six', '0.94'), ('few', '0.94'), ('obverse', '0.94'), ('soignee', '0.94'), ('seven', '0.93')]
# rnn:  [('dilapidated', '0.69'), ('blockading', '0.69'), ('cinema', '0.69'), ('anti-submarine', '0.69'), ('1879', '0.69'), ('myriad', '0.68'), ('cotman', '0.68'), ('thruways', '0.68'), ('sisk', '0.68'), ('laundered', '0.68')]
# Model saved in file: ./model/Word2Vec-tf-emb-rnn-nce-2.ckpt
# Average loss at step  176000 :  5.13355975997
# word2vec:  [('two', '1.00'), ('four', '0.94'), ('three', '0.94'), ('five', '0.92'), ('several', '0.90'), ('six', '0.88'), ('ten', '0.88'), ('few', '0.86'), ('seven', '0.83'), ('fifty', '0.82')]
# rnn:  [('two', '1.00'), ('three', '0.98'), ('four', '0.97'), ('several', '0.97'), ('five', '0.96'), ('sleep-wakefulness', '0.95'), ('six', '0.95'), ('ten', '0.93'), ('filles', '0.93'), ('fifty', '0.93')]
# rnn:  [('chants', '0.73'), ('blacksmith', '0.73'), ('anti-submarine', '0.72'), ('commence', '0.72'), ('sisk', '0.71'), ('1879', '0.71'), ('myriad', '0.71'), ('overtaxed', '0.71'), ('rooney', '0.71'), ('thrive', '0.71')]
# Model saved in file: ./model/Word2Vec-tf-emb-rnn-nce-2.ckpt
# Average loss at step  178000 :  5.19360021567
# word2vec:  [('two', '1.00'), ('four', '0.94'), ('three', '0.94'), ('five', '0.92'), ('several', '0.90'), ('six', '0.88'), ('ten', '0.88'), ('few', '0.86'), ('seven', '0.83'), ('fifty', '0.82')]
# rnn:  [('two', '1.00'), ('three', '0.99'), ('four', '0.98'), ('several', '0.98'), ('sleep-wakefulness', '0.97'), ('five', '0.96'), ('seven', '0.95'), ('soignee', '0.94'), ('six', '0.94'), ('filles', '0.94')]
# rnn:  [('myriad', '0.77'), ('blacksmith', '0.77'), ('hotham', '0.77'), ('ailey', '0.75'), ('michilimackinac', '0.75'), ('prowl', '0.74'), ('polyether', '0.74'), ('chants', '0.74'), ('rooney', '0.74'), ('experimenting', '0.74')]
# Model saved in file: ./model/Word2Vec-tf-emb-rnn-nce-2.ckpt
# Average loss at step  180000 :  5.16539548457
# word2vec:  [('two', '1.00'), ('four', '0.94'), ('three', '0.94'), ('five', '0.92'), ('several', '0.90'), ('six', '0.88'), ('ten', '0.88'), ('few', '0.86'), ('seven', '0.83'), ('fifty', '0.82')]
# rnn:  [('two', '1.00'), ('three', '0.98'), ('four', '0.96'), ('five', '0.96'), ('several', '0.96'), ('six', '0.95'), ('few', '0.94'), ('ten', '0.93'), ('fifty', '0.93'), ('forty', '0.93')]
# rnn:  [('fantasia', '0.59'), ('blockading', '0.59'), ('pathologist', '0.58'), ('wiles', '0.58'), ('offstage', '0.58'), ('improbably', '0.58'), ("beethoven's", '0.58'), ('blacksmith', '0.58'), ('cotman', '0.58'), ('thruways', '0.58')]
# Model saved in file: ./model/Word2Vec-tf-emb-rnn-nce-2.ckpt
# Average loss at step  182000 :  5.0945359453
# word2vec:  [('two', '1.00'), ('four', '0.94'), ('three', '0.94'), ('five', '0.92'), ('several', '0.90'), ('six', '0.88'), ('ten', '0.88'), ('few', '0.86'), ('seven', '0.83'), ('fifty', '0.82')]
# rnn:  [('two', '1.00'), ('three', '0.98'), ('four', '0.96'), ('several', '0.96'), ('five', '0.96'), ('sleep-wakefulness', '0.95'), ('six', '0.94'), ('fifty', '0.93'), ('soignee', '0.93'), ('few', '0.93')]
# rnn:  [('1,212', '0.71'), ('artistry', '0.71'), ('boosted', '0.71'), ('fixture', '0.70'), ('anti-submarine', '0.70'), ('chants', '0.70'), ('vacuuming', '0.70'), ('diathermy', '0.70'), ("young's", '0.70'), ('implacable', '0.70')]
# Model saved in file: ./model/Word2Vec-tf-emb-rnn-nce-2.ckpt
# Average loss at step  184000 :  5.06570885968
# word2vec:  [('two', '1.00'), ('four', '0.94'), ('three', '0.94'), ('five', '0.92'), ('several', '0.90'), ('six', '0.88'), ('ten', '0.88'), ('few', '0.86'), ('seven', '0.83'), ('fifty', '0.82')]
# rnn:  [('two', '1.00'), ('three', '0.99'), ('four', '0.97'), ('several', '0.97'), ('five', '0.97'), ('six', '0.95'), ('fifty', '0.95'), ('few', '0.94'), ('ten', '0.94'), ('seven', '0.94')]
# rnn:  [('waded', '0.62'), ('thrive', '0.61'), ('deacon', '0.60'), ('gator', '0.60'), ('thruways', '0.60'), ('hymn', '0.60'), ('dividend', '0.60'), ('overtaxed', '0.59'), ('sexes', '0.59'), ('cotman', '0.59')]
# Model saved in file: ./model/Word2Vec-tf-emb-rnn-nce-2.ckpt
# Average loss at step  186000 :  5.26360342705
# word2vec:  [('two', '1.00'), ('four', '0.94'), ('three', '0.94'), ('five', '0.92'), ('several', '0.90'), ('six', '0.88'), ('ten', '0.88'), ('few', '0.86'), ('seven', '0.83'), ('fifty', '0.82')]
# rnn:  [('two', '1.00'), ('three', '0.98'), ('four', '0.97'), ('five', '0.97'), ('several', '0.97'), ('six', '0.95'), ('few', '0.95'), ('fifty', '0.94'), ('ten', '0.94'), ('smallpox', '0.94')]
# rnn:  [('thruways', '0.68'), ('blacksmith', '0.68'), ('gator', '0.68'), ('dividend', '0.68'), ('auditorium', '0.67'), ('ever-expanding', '0.67'), ('chants', '0.67'), ('polyether', '0.67'), ('soldiery', '0.67'), ('rooney', '0.67')]
# Model saved in file: ./model/Word2Vec-tf-emb-rnn-nce-2.ckpt
# epouch done...
# Average loss at step  188000 :  5.30382599366
# word2vec:  [('two', '1.00'), ('four', '0.94'), ('three', '0.94'), ('five', '0.92'), ('several', '0.90'), ('six', '0.88'), ('ten', '0.88'), ('few', '0.86'), ('seven', '0.83'), ('fifty', '0.82')]
# rnn:  [('two', '1.00'), ('three', '0.99'), ('four', '0.98'), ('several', '0.98'), ('five', '0.98'), ('six', '0.96'), ('seven', '0.96'), ('fifty', '0.96'), ('recent', '0.96'), ('forty', '0.96')]
# rnn:  [('blockading', '0.73'), ('proponents', '0.73'), ("young's", '0.73'), ('lubell', '0.72'), ('gentlemen', '0.72'), ('freshman', '0.72'), ('perpetuation', '0.72'), ('pretexts', '0.72'), ('thaw', '0.72'), ('assumptions', '0.72')]
# Model saved in file: ./model/Word2Vec-tf-emb-rnn-nce-2.ckpt
# Average loss at step  190000 :  5.26740000141
# word2vec:  [('two', '1.00'), ('four', '0.94'), ('three', '0.94'), ('five', '0.92'), ('several', '0.90'), ('six', '0.88'), ('ten', '0.88'), ('few', '0.86'), ('seven', '0.83'), ('fifty', '0.82')]
# rnn:  [('two', '1.00'), ('three', '0.98'), ('four', '0.97'), ('several', '0.97'), ('five', '0.97'), ('six', '0.95'), ('seven', '0.95'), ('few', '0.94'), ('ten', '0.94'), ('fifty', '0.94')]
# rnn:  [('realness', '0.61'), ('directorate', '0.61'), ("building's", '0.60'), ('secluded', '0.60'), ('perpetuation', '0.60'), ('soldiery', '0.59'), ('conventionality', '0.59'), ("hodges'", '0.59'), ('contractors', '0.59'), ('ainu', '0.59')]
# Model saved in file: ./model/Word2Vec-tf-emb-rnn-nce-2.ckpt
# Average loss at step  192000 :  5.29597154319
# word2vec:  [('two', '1.00'), ('four', '0.94'), ('three', '0.94'), ('five', '0.92'), ('several', '0.90'), ('six', '0.88'), ('ten', '0.88'), ('few', '0.86'), ('seven', '0.83'), ('fifty', '0.82')]
# rnn:  [('two', '1.00'), ('three', '0.98'), ('four', '0.96'), ('several', '0.96'), ('five', '0.96'), ('six', '0.95'), ('nine', '0.95'), ('forty', '0.94'), ('fifty', '0.94'), ('seven', '0.94')]
# rnn:  [('directorate', '0.75'), ('thruways', '0.74'), ('adore', '0.73'), ('blockading', '0.73'), ('hotham', '0.73'), ('1879', '0.72'), ('inadvisable', '0.72'), ('fabrics', '0.72'), ('blacksmith', '0.72'), ("thet's", '0.72')]
# Model saved in file: ./model/Word2Vec-tf-emb-rnn-nce-2.ckpt
# Average loss at step  194000 :  5.24184018588
# word2vec:  [('two', '1.00'), ('four', '0.94'), ('three', '0.94'), ('five', '0.92'), ('several', '0.90'), ('six', '0.88'), ('ten', '0.88'), ('few', '0.86'), ('seven', '0.83'), ('fifty', '0.82')]
# rnn:  [('two', '1.00'), ('three', '0.98'), ('several', '0.97'), ('five', '0.97'), ('four', '0.96'), ('six', '0.95'), ('few', '0.95'), ('nine', '0.95'), ('forty', '0.95'), ('eight', '0.95')]
# rnn:  [('blockading', '0.65'), ('thruways', '0.65'), ('anti-submarine', '0.63'), ('directorate', '0.63'), ('quiz', '0.63'), ("building's", '0.63'), ('typewriters', '0.63'), ('enforcers', '0.63'), ('buckenham', '0.63'), ('dividend', '0.63')]
# Model saved in file: ./model/Word2Vec-tf-emb-rnn-nce-2.ckpt
# Average loss at step  196000 :  5.29801025784
# word2vec:  [('two', '1.00'), ('four', '0.94'), ('three', '0.94'), ('five', '0.92'), ('several', '0.90'), ('six', '0.88'), ('ten', '0.88'), ('few', '0.86'), ('seven', '0.83'), ('fifty', '0.82')]
# rnn:  [('two', '1.00'), ('three', '0.98'), ('four', '0.96'), ('several', '0.96'), ('five', '0.95'), ('forty', '0.94'), ('few', '0.94'), ('six', '0.94'), ('fifty', '0.93'), ('ten', '0.92')]
# rnn:  [('dabbing', '0.63'), ('dilapidated', '0.63'), ('enviably', '0.63'), ('exhilarating', '0.63'), ('unwaveringly', '0.63'), ('thruways', '0.63'), ('anti-submarine', '0.62'), ("beethoven's", '0.62'), ('0.85%', '0.62'), ('daly', '0.62')]
# Model saved in file: ./model/Word2Vec-tf-emb-rnn-nce-2.ckpt
# Average loss at step  198000 :  5.2924768337
# word2vec:  [('two', '1.00'), ('four', '0.94'), ('three', '0.94'), ('five', '0.92'), ('several', '0.90'), ('six', '0.88'), ('ten', '0.88'), ('few', '0.86'), ('seven', '0.83'), ('fifty', '0.82')]
# rnn:  [('two', '1.00'), ('three', '0.98'), ('four', '0.97'), ('five', '0.97'), ('several', '0.96'), ('six', '0.95'), ('forty', '0.95'), ('recent', '0.95'), ('fifty', '0.95'), ('seven', '0.95')]
# rnn:  [('enforcers', '0.59'), ("anyone's", '0.58'), ('kimmell', '0.58'), ('organization-position', '0.58'), ('sexes', '0.57'), ('coolers', '0.57'), ('scattergun', '0.57'), ('sierras', '0.57'), ('lard', '0.57'), ('delicately', '0.57')]
# Model saved in file: ./model/Word2Vec-tf-emb-rnn-nce-2.ckpt

# %%
with tf.Session(graph=graph) as session:
    saver.restore(session, MODEL)
    
    feed_dict={inputs: [[words_dict['two']], [words_dict['new']], [words_dict['funny']]], input_lengths: [1, 1, 1]}
    
    index_eval = index.eval(feed_dict=feed_dict)
    rnn_outputs_eval = rnn_outputs.eval(feed_dict=feed_dict)
    rnn_final_state_eval = rnn_final_state.eval(feed_dict=feed_dict)
    print("index:\n", index_eval)
    print("rnn_output:\n", rnn_outputs_eval)
    print("rnn_final:\n", rnn_final_state_eval)

# %%
with tf.Session(graph=graph) as session:
    #saver.restore(session, MODEL)
    embeddings_saver.restore(session, WORDS2VEC_MODEL)
    final_embeddings = embeddings.eval()

from sklearn.preprocessing import normalize
normalize(final_embeddings, norm='l2', axis=1, copy=False)

words_vec = {}
for i in range(final_embeddings.shape[0]):
    words_vec[inv_words_dict[i]] = final_embeddings[i]
  
words_vec2 = {}
with tf.Session(graph=graph) as session:
    saver.restore(session, MODEL)
    
    for key in words_vec.keys():
        feed_dict = {inputs: [[words_dict[key]]], input_lengths: [1]}
        words_vec2[key] = normalize(rnn_final_state.eval(feed_dict), norm='l2', copy=True)[0]

# %%
def sent2Context(sent):
    with tf.Session(graph=graph) as session:
        saver.restore(session, MODEL)
        feed_dict = {inputs: [[words_dict[word] for word in sent]], input_lengths: ([len(sent)])}
        context_pred = context.eval(feed_dict)
        print(rnn_final_state.eval(feed_dict))
        return [inv_words_dict[i] for i in context_pred.argsort()[0][::-1][:10]]
    
def twoWords2Vec(sent):
    with tf.Session(graph=graph) as session:
        saver.restore(session, MODEL)
        feed_dict = {inputs: [[words_dict[word] for word in sent]], input_lengths: ([len(sent)])}
        return normalize(rnn_final_state.eval(feed_dict), norm='l2', copy=True)[0]

# %%
print(twoWords2Vec(['run', 'faster']))

# %%
#print(cloestWord(twoWords2Vec(['run', 'faster'])))
#print(cloestWord(twoWords2Vec(['two', 'idiot'])))
#print(cloestWord(words_vec['two']))
#print(cloestWord(words_vec['but']))
#print(cloestWord(words_vec['man']))


#print(cloestWord(words_vec2['two'], words_vec2))
#print(cloestWord(words_vec2['but'], words_vec2))
#print(cloestWord(words_vec2['man'], words_vec2))

print(cloestWord(words_vec2['two'], words_vec2))
print(cloestWord(words_vec2['however'], words_vec2))
print(cloestWord(words_vec2['man'], words_vec2))

#print(cloestWord(twoWords2Vec(['but']), words_vec2))
#print(cloestWord(twoWords2Vec(['man']), words_vec2))
#print(cloestWord(twoWords2Vec(['two'])))
"""
def rnn_out(sent):
    with tf.Session(graph=graph) as session:
        saver.restore(session, MODEL)
        feed_dict = {inputs: [[words_dict[word] for word in sent]], input_lengths: ([len(sent)])}
        print('rnn_inputs: ', rnn_inputs.eval(feed_dict))
        print('rnn_outputs: ', rnn_outputs.eval(feed_dict))
        print('rnn_final_state:', rnn_final_state.eval(feed_dict))

rnn_out(['two'])
rnn_out(['three'])
words_vec['two']
"""

# %%
WORDS2VEC_MODEL = './model/brown-Words2Vec.ckpt'

graph2 = tf.Graph()

with graph2.as_default():
    embeddings2 = tf.Variable(
            tf.random_uniform([VOCABULAY_SIZE, DIMENSION], -1.0, 1.0), name='Words2Vec')
    embeddings_saver2 = tf.train.Saver({'Words2Vec': embeddings2})

# %%
with tf.Session(graph=graph2) as session2:
    embeddings_saver2.restore(session2, WORDS2VEC_MODEL)
    final_embeddings2 = embeddings2.eval()
    
final_embeddings2 = normalize(final_embeddings2, norm='l2', axis=1, copy=True)

words_vec3 = {}
for i in range(final_embeddings2.shape[0]):
    words_vec3[inv_words_dict[i]] = final_embeddings2[i]

# %%
print(cloestWord(words_vec3['two'], words_vec3))
print(cloestWord(words_vec3['however'], words_vec3))
print(cloestWord(words_vec3['man'], words_vec3))

# %%
print(words_dict['five'])
print(inv_words_dict[334])
